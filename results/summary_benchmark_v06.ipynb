# %%
import pandas as pd
pd.set_option('display.max_columns', 30, 'display.width', 1000, 'display.max_rows',1000)

dff = pd.read_json('results.json')
v06_columns = [c for c in dff.columns if 'v06' in c]

dataset_version_06_df = dff[v06_columns].T.sort_values("best score", ascending=False)
dataset_version_06_df_summary = dataset_version_06_df[['best score', 'best time', 'Mean Absolute Error Accuracy', 'Mean Squared Error Accuracy', 'R square Accuracy', 'Root Mean Squared Error', 'best run date','best method','best is shared', "suboptimal"]]
dataset_version_06_df_summary
# Out:
#                                         best score   best time Mean Absolute Error Accuracy Mean Squared Error Accuracy R square Accuracy Root Mean Squared Error               best run date                                        best method best is shared  suboptimal
# knn (v06)                                 0.719049    0.017916                 41436.366725            3173733520.36068          0.719049            56335.899037  2022-11-21 18:05:21.585382                                      random search           True     pending
# catboost (v06)                            0.715606   12.256545                 43622.749758           3212635545.386724          0.715606            56680.115961                         NaN                                      random search            NaN     pending
# ...

# %%
dataset_version_06_df
# Out:
#                                         Mean Absolute Error Accuracy Mean Squared Error Accuracy R square Accuracy Root Mean Squared Error                                            _method                                            _params    _score _train time                                        best method                                        best params best score   best time                        date                   first run random_state   run_env  suboptimal               best run date                                      silver method                                      silver params             silver run date silver score silver time best is shared
# ...

# %%
dataset_version_06_df_1_vs_2 = dataset_version_06_df[['best score', 'best time', 'silver score', 'silver time', 'best method','silver method','best is shared']]
dataset_version_06_df_1_vs_2
# Out:
#                                         best score   best time silver score silver time                                        best method                                      silver method best is shared
# knn (v06)                                 0.719049    0.017916     0.719049    0.018388                                      random search                                      random search           True
# catboost (v06)                            0.715606   12.256545          NaN         NaN                                      random search                                                NaN            NaN
# light gradient boosting (v06)             0.706735   15.043873     0.578218    0.685734                                      random search                                      random search            NaN
# ...

# %%
dataset_version_06_df_1_vs_2b = dataset_version_06_df[['best score', 'best time', 'silver score', 'silver time', 'best params','silver params','best is shared']]
dataset_version_06_df_1_vs_2b
# Out:
#                                         best score   best time silver score silver time                                        best params                                      silver params best is shared
# knn (v06)                                 0.719049    0.017916     0.719049    0.018388  {'model__algorithm': 'brute', 'model__leaf_siz...  {'model__algorithm': 'brute', 'model__leaf_siz...           True
# catboost (v06)                            0.715606   12.256545          NaN         NaN  {'model__depth': 8, 'model__l2_leaf_reg': 1, '...                                                NaN            NaN
# light gradient boosting (v06)             0.706735   15.043873     0.578218    0.685734  {'model__boosting_type': 'dart', 'model__colsa...  {'model__boosting_type': 'gbdt', 'model__colsa...            NaN
# ...
