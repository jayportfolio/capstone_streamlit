# %%
import pandas as pd

dff = pd.read_json('results.json')
v06_columns = [c for c in dff.columns if 'v06' in c]

dataset_version_06_df = dff[v06_columns].T.sort_values("best score", ascending=False)
dataset_version_06_df_summary = dataset_version_06_df[['best score', 'best time', 'Mean Absolute Error Accuracy', 'Mean Squared Error Accuracy', 'R square Accuracy', 'Root Mean Squared Error', 'best run date','best method','best is shared', "suboptimal"]]
dataset_version_06_df_summary
# Out:
#                                 best score   best time  \
# knn - random search (v06)         0.719103    0.041981
# catboost (v06)                    0.715606   12.256545
# light gradient boosting (v06)     0.706735   15.043873
# xg boost (v06)                    0.687611   11.474795
# random forest (v06)               0.666175    2.392598
# decision tree (v06)               0.573885    0.057369
# neural network (v06)              0.556696  312.991321
# decision tree - (v06)             0.524696         NaN
# linear regression (ridge) (v06)     0.4569     0.13149
#
#                                 Mean Absolute Error Accuracy  \
# knn - random search (v06)                       41435.715578
# catboost (v06)                                  43622.749758
# light gradient boosting (v06)                   44080.972643
# xg boost (v06)                                  45988.280765
# random forest (v06)                             48257.442864
# decision tree (v06)                             54372.291042
# neural network (v06)                            424575.27788
# decision tree - (v06)                           57094.069341
# linear regression (ridge) (v06)                 63601.874995
#
#                                 Mean Squared Error Accuracy R square Accuracy  \
# knn - random search (v06)                  3173381332.25707           0.71908
# catboost (v06)                            3212635545.386724          0.715606
# light gradient boosting (v06)             3312839956.633489          0.706735
# xg boost (v06)                            3528869693.681411          0.687611
# random forest (v06)                       3771022259.944156          0.666175
# decision tree (v06)                       4813572167.815049          0.573885
# neural network (v06)                    191488099337.006012        -15.951241
# decision tree - (v06)                     5369228892.195786          0.524696
# linear regression (ridge) (v06)           6135076718.216859            0.4569
#
#                                 Root Mean Squared Error  \
# knn - random search (v06)                  56332.773163
# catboost (v06)                             56680.115961
# light gradient boosting (v06)              57557.275445
# xg boost (v06)                             59404.290196
# random forest (v06)                        61408.649716
# decision tree (v06)                        69379.911846
# neural network (v06)                      437593.532101
# decision tree - (v06)                      73275.022294
# linear regression (ridge) (v06)            78326.730547
#
#                                               best run date  \
# knn - random search (v06)                               NaN
# catboost (v06)                                          NaN
# light gradient boosting (v06)    2022-11-16 13:59:52.612654
# xg boost (v06)                                          NaN
# random forest (v06)                                     NaN
# decision tree (v06)              2022-11-15 22:58:42.493872
# neural network (v06)             2000-01-01 17:09:59.063570
# decision tree - (v06)                                   NaN
# linear regression (ridge) (v06)  2022-11-15 22:31:23.866429
#
#                                                                        best method  \
# knn - random search (v06)                                                      NaN
# catboost (v06)                                                       random search
# light gradient boosting (v06)                                        random search
# xg boost (v06)                                                       random search
# random forest (v06)                                                  random search
# decision tree (v06)                                                  random search
# neural network (v06)             random search [input11, d^20-500-500-20-5, den...
# decision tree - (v06)                                       random search-no scale
# linear regression (ridge) (v06)                                      random search
#
#                                 best is shared  suboptimal
# knn - random search (v06)                  NaN  suboptimal
# catboost (v06)                             NaN     pending
# light gradient boosting (v06)              NaN     pending
# xg boost (v06)                             NaN     pending
# random forest (v06)                        NaN     pending
# decision tree (v06)                        NaN     pending
# neural network (v06)                       NaN  suboptimal
# decision tree - (v06)                      NaN         NaN
# linear regression (ridge) (v06)            NaN     pending

# %%
dataset_version_06_df
# Out:
#                                 Mean Absolute Error Accuracy  \
# knn - random search (v06)                       41435.715578
# catboost (v06)                                  43622.749758
# light gradient boosting (v06)                   44080.972643
# xg boost (v06)                                  45988.280765
# random forest (v06)                             48257.442864
# decision tree (v06)                             54372.291042
# neural network (v06)                            424575.27788
# decision tree - (v06)                           57094.069341
# linear regression (ridge) (v06)                 63601.874995
#
#                                 Mean Squared Error Accuracy R square Accuracy  \
# knn - random search (v06)                  3173381332.25707           0.71908
# catboost (v06)                            3212635545.386724          0.715606
# light gradient boosting (v06)             3312839956.633489          0.706735
# xg boost (v06)                            3528869693.681411          0.687611
# random forest (v06)                       3771022259.944156          0.666175
# decision tree (v06)                       4813572167.815049          0.573885
# neural network (v06)                    191488099337.006012        -15.951241
# decision tree - (v06)                     5369228892.195786          0.524696
# linear regression (ridge) (v06)           6135076718.216859            0.4569
#
#                                 Root Mean Squared Error  \
# knn - random search (v06)                  56332.773163
# catboost (v06)                             56680.115961
# light gradient boosting (v06)              57557.275445
# xg boost (v06)                             59404.290196
# random forest (v06)                        61408.649716
# decision tree (v06)                        69379.911846
# neural network (v06)                      437593.532101
# decision tree - (v06)                      73275.022294
# linear regression (ridge) (v06)            78326.730547
#
#                                                                         _method  \
# knn - random search (v06)                                                   NaN
# catboost (v06)                                                    random search
# light gradient boosting (v06)                                     random search
# xg boost (v06)                                                    random search
# random forest (v06)                                               random search
# decision tree (v06)                                               random search
# neural network (v06)              simplest findable model + normalise, MSE loss
# decision tree - (v06)                                    random search-no scale
# linear regression (ridge) (v06)                                   random search
#
#                                                                            _params  \
# knn - random search (v06)        {'model__algorithm': 'ball_tree', 'model__leaf...
# catboost (v06)                   {'model__depth': 8, 'model__l2_leaf_reg': 1, '...
# light gradient boosting (v06)    {'model__boosting_type': 'dart', 'model__colsa...
# xg boost (v06)                   {'model__booster': 'dart', 'model__early_stopp...
# random forest (v06)              {'model__bootstrap': True, 'model__ccp_alpha':...
# decision tree (v06)              {'model__ccp_alpha': 5, 'model__criterion': 'f...
# neural network (v06)                                                 not available
# decision tree - (v06)            {'model__ccp_alpha': 1, 'model__criterion': 'a...
# linear regression (ridge) (v06)  {'model__alpha': 0.001, 'model__copy_X': False...
#
#                                     _score _train time  \
# knn - random search (v06)          0.71908     0.01772
# catboost (v06)                    0.715606   12.256545
# light gradient boosting (v06)     0.706735   15.043873
# xg boost (v06)                    0.687611   11.474795
# random forest (v06)               0.666175    2.392598
# decision tree (v06)               0.573885    0.057369
# neural network (v06)            -15.951241         999
# decision tree - (v06)             0.524696   63.259539
# linear regression (ridge) (v06)     0.4569     0.13149
#
#                                                                        best method  \
# knn - random search (v06)                                                      NaN
# catboost (v06)                                                       random search
# light gradient boosting (v06)                                        random search
# xg boost (v06)                                                       random search
# random forest (v06)                                                  random search
# decision tree (v06)                                                  random search
# neural network (v06)             random search [input11, d^20-500-500-20-5, den...
# decision tree - (v06)                                       random search-no scale
# linear regression (ridge) (v06)                                      random search
#
#                                                                        best params  \
# knn - random search (v06)        {'model__algorithm': 'auto', 'model__leaf_size...
# catboost (v06)                   {'model__depth': 8, 'model__l2_leaf_reg': 1, '...
# light gradient boosting (v06)    {'model__boosting_type': 'dart', 'model__colsa...
# xg boost (v06)                   {'model__booster': 'dart', 'model__early_stopp...
# random forest (v06)              {'model__bootstrap': True, 'model__ccp_alpha':...
# decision tree (v06)              {'model__ccp_alpha': 5, 'model__criterion': 'f...
# neural network (v06)             {'model__batch_size': 100, 'model__epochs': 50...
# decision tree - (v06)                                       MULTIPLE PARAM OPTIONS
# linear regression (ridge) (v06)  {'model__alpha': 0.001, 'model__copy_X': False...
#
#                                  ... random_state   run_env  suboptimal  \
# knn - random search (v06)        ...          101  gradient  suboptimal
# catboost (v06)                   ...          101  gradient     pending
# light gradient boosting (v06)    ...          101  gradient     pending
# xg boost (v06)                   ...          101  gradient     pending
# random forest (v06)              ...          101  gradient     pending
# decision tree (v06)              ...          101  gradient     pending
# neural network (v06)             ...          101     local  suboptimal
# decision tree - (v06)            ...          101       NaN         NaN
# linear regression (ridge) (v06)  ...          101  gradient     pending
#
#                                               best run date  \
# knn - random search (v06)                               NaN
# catboost (v06)                                          NaN
# light gradient boosting (v06)    2022-11-16 13:59:52.612654
# xg boost (v06)                                          NaN
# random forest (v06)                                     NaN
# decision tree (v06)              2022-11-15 22:58:42.493872
# neural network (v06)             2000-01-01 17:09:59.063570
# decision tree - (v06)                                   NaN
# linear regression (ridge) (v06)  2022-11-15 22:31:23.866429
#
#                                                                  silver method  \
# knn - random search (v06)                                                  NaN
# catboost (v06)                                                             NaN
# light gradient boosting (v06)                                    random search
# xg boost (v06)                                                             NaN
# random forest (v06)                                                        NaN
# decision tree (v06)                                              random search
# neural network (v06)             simplest findable model + normalise, MSE loss
# decision tree - (v06)                                                      NaN
# linear regression (ridge) (v06)                                  random search
#
#                                                                      silver params  \
# knn - random search (v06)                                                      NaN
# catboost (v06)                                                                 NaN
# light gradient boosting (v06)    {'model__boosting_type': 'gbdt', 'model__colsa...
# xg boost (v06)                                                                 NaN
# random forest (v06)                                                            NaN
# decision tree (v06)              {'model__ccp_alpha': 0.1, 'model__criterion': ...
# neural network (v06)                                                 not available
# decision tree - (v06)                                                          NaN
# linear regression (ridge) (v06)  {'model__alpha': 0.01, 'model__copy_X': False,...
#
#                                             silver run date silver score  \
# knn - random search (v06)                               NaN          NaN
# catboost (v06)                                          NaN          NaN
# light gradient boosting (v06)    2022-11-16 13:49:11.580931     0.578218
# xg boost (v06)                                          NaN          NaN
# random forest (v06)                                     NaN          NaN
# decision tree (v06)              2022-11-15 22:55:37.091879     0.555486
# neural network (v06)             2022-11-20 00:35:55.108414   -15.258654
# decision tree - (v06)                                   NaN          NaN
# linear regression (ridge) (v06)  2022-11-15 21:55:55.839453       0.4569
#
#                                 silver time best is shared
# knn - random search (v06)               NaN            NaN
# catboost (v06)                          NaN            NaN
# light gradient boosting (v06)      0.685734            NaN
# xg boost (v06)                          NaN            NaN
# random forest (v06)                     NaN            NaN
# decision tree (v06)                 0.01893            NaN
# neural network (v06)                    999            NaN
# decision tree - (v06)                   NaN            NaN
# linear regression (ridge) (v06)    0.017527            NaN
#
# [9 rows x 24 columns]

# %%
dataset_version_06_df_1_vs_2 = dataset_version_06_df[['best score', 'best time', 'silver score', 'silver time', 'best method','silver method','best is shared']]
dataset_version_06_df_1_vs_2
# Out:
#                                 best score   best time silver score  \
# knn - random search (v06)         0.719103    0.041981          NaN
# catboost (v06)                    0.715606   12.256545          NaN
# light gradient boosting (v06)     0.706735   15.043873     0.578218
# xg boost (v06)                    0.687611   11.474795          NaN
# random forest (v06)               0.666175    2.392598          NaN
# decision tree (v06)               0.573885    0.057369     0.555486
# neural network (v06)              0.556696  312.991321   -15.258654
# decision tree - (v06)             0.524696         NaN          NaN
# linear regression (ridge) (v06)     0.4569     0.13149       0.4569
#
#                                 silver time  \
# knn - random search (v06)               NaN
# catboost (v06)                          NaN
# light gradient boosting (v06)      0.685734
# xg boost (v06)                          NaN
# random forest (v06)                     NaN
# decision tree (v06)                 0.01893
# neural network (v06)                    999
# decision tree - (v06)                   NaN
# linear regression (ridge) (v06)    0.017527
#
#                                                                        best method  \
# knn - random search (v06)                                                      NaN
# catboost (v06)                                                       random search
# light gradient boosting (v06)                                        random search
# xg boost (v06)                                                       random search
# random forest (v06)                                                  random search
# decision tree (v06)                                                  random search
# neural network (v06)             random search [input11, d^20-500-500-20-5, den...
# decision tree - (v06)                                       random search-no scale
# linear regression (ridge) (v06)                                      random search
#
#                                                                  silver method  \
# knn - random search (v06)                                                  NaN
# catboost (v06)                                                             NaN
# light gradient boosting (v06)                                    random search
# xg boost (v06)                                                             NaN
# random forest (v06)                                                        NaN
# decision tree (v06)                                              random search
# neural network (v06)             simplest findable model + normalise, MSE loss
# decision tree - (v06)                                                      NaN
# linear regression (ridge) (v06)                                  random search
#
#                                 best is shared
# knn - random search (v06)                  NaN
# catboost (v06)                             NaN
# light gradient boosting (v06)              NaN
# xg boost (v06)                             NaN
# random forest (v06)                        NaN
# decision tree (v06)                        NaN
# neural network (v06)                       NaN
# decision tree - (v06)                      NaN
# linear regression (ridge) (v06)            NaN

# %%
dataset_version_06_df_1_vs_2b = dataset_version_06_df[['best score', 'best time', 'silver score', 'silver time', 'best params','silver params','best is shared']]
dataset_version_06_df_1_vs_2b
# Out:
#                                 best score   best time silver score  \
# knn - random search (v06)         0.719103    0.041981          NaN
# catboost (v06)                    0.715606   12.256545          NaN
# light gradient boosting (v06)     0.706735   15.043873     0.578218
# xg boost (v06)                    0.687611   11.474795          NaN
# random forest (v06)               0.666175    2.392598          NaN
# decision tree (v06)               0.573885    0.057369     0.555486
# neural network (v06)              0.556696  312.991321   -15.258654
# decision tree - (v06)             0.524696         NaN          NaN
# linear regression (ridge) (v06)     0.4569     0.13149       0.4569
#
#                                 silver time  \
# knn - random search (v06)               NaN
# catboost (v06)                          NaN
# light gradient boosting (v06)      0.685734
# xg boost (v06)                          NaN
# random forest (v06)                     NaN
# decision tree (v06)                 0.01893
# neural network (v06)                    999
# decision tree - (v06)                   NaN
# linear regression (ridge) (v06)    0.017527
#
#                                                                        best params  \
# knn - random search (v06)        {'model__algorithm': 'auto', 'model__leaf_size...
# catboost (v06)                   {'model__depth': 8, 'model__l2_leaf_reg': 1, '...
# light gradient boosting (v06)    {'model__boosting_type': 'dart', 'model__colsa...
# xg boost (v06)                   {'model__booster': 'dart', 'model__early_stopp...
# random forest (v06)              {'model__bootstrap': True, 'model__ccp_alpha':...
# decision tree (v06)              {'model__ccp_alpha': 5, 'model__criterion': 'f...
# neural network (v06)             {'model__batch_size': 100, 'model__epochs': 50...
# decision tree - (v06)                                       MULTIPLE PARAM OPTIONS
# linear regression (ridge) (v06)  {'model__alpha': 0.001, 'model__copy_X': False...
#
#                                                                      silver params  \
# knn - random search (v06)                                                      NaN
# catboost (v06)                                                                 NaN
# light gradient boosting (v06)    {'model__boosting_type': 'gbdt', 'model__colsa...
# xg boost (v06)                                                                 NaN
# random forest (v06)                                                            NaN
# decision tree (v06)              {'model__ccp_alpha': 0.1, 'model__criterion': ...
# neural network (v06)                                                 not available
# decision tree - (v06)                                                          NaN
# linear regression (ridge) (v06)  {'model__alpha': 0.01, 'model__copy_X': False,...
#
#                                 best is shared
# knn - random search (v06)                  NaN
# catboost (v06)                             NaN
# light gradient boosting (v06)              NaN
# xg boost (v06)                             NaN
# random forest (v06)                        NaN
# decision tree (v06)                        NaN
# neural network (v06)                       NaN
# decision tree - (v06)                      NaN
# linear regression (ridge) (v06)            NaN
