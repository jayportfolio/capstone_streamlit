# %%
import pandas as pd
pd.set_option('display.max_columns', 30, 'display.width', 1000, 'display.max_rows',1000)

dff = pd.read_json('results.json')
v06_columns = [c for c in dff.columns if 'v06' in c]

dataset_version_06_df = dff[v06_columns].T.sort_values("best score", ascending=False)
dataset_version_06_df_summary = dataset_version_06_df[['best score', 'best time', 'Mean Absolute Error Accuracy', 'Mean Squared Error Accuracy', 'R square Accuracy', 'Root Mean Squared Error', 'best run date','best method','best is shared', "suboptimal"]]
dataset_version_06_df_summary
# Out:
#                                         best score   best time Mean Absolute Error Accuracy Mean Squared Error Accuracy R square Accuracy Root Mean Squared Error               best run date                                        best method best is shared  suboptimal
# xg boost (tree) (v06)                     0.727132  134.174901                 41210.351288           3082428096.006462          0.727132            55519.619019  2022-12-07 09:43:37.103009                                      random search          False     pending
# knn (v06)                                 0.719049    0.017916                 41531.119915           3218096364.819358          0.715122            56728.267776  2022-11-21 18:05:21.585382                                      random search          False  suboptimal
# catboost (v06)                            0.715606   12.256545                 51000.047694           4301362532.917062          0.619227            65584.773636  1999-11-13 15:26:55.706567                                      random search          False  suboptimal
# light gradient boosting (v06)             0.706735   15.043873                 44080.972643           3312839956.633489          0.706735            57557.275445  2022-11-16 13:59:52.612654                                      random search           True  suboptimal
# xg boost (v06)                            0.687611   11.474795                 45988.280765           3528869693.681411          0.687611            59404.290196                         NaN                                      random search            NaN     pending
# decision tree (v06)                       0.616727    0.133738                   56888.9238           5206013958.612971          0.539144             72152.71276  2022-12-11 13:59:57.993851                                      random search          False  suboptimal
# neural network m11 mega (v06)             0.612318     2569.45                 56035.854723           4929943923.096645          0.563583            70213.559396  2022-11-29 12:57:16.459719         loss=2833.6 valloss=4034.41 stop=619/1000           False  suboptimal
# neural network m12 mega (v06)             0.594032      813.27                 54967.975952           4807033830.676171          0.574463             69332.77602  2022-11-29 17:08:44.480482  loss=4386.51 valloss=4438.8 +valsplit=0.1 stop...          False  suboptimal
# random forest (v06)                       0.585876    1.769856                 59011.811654           5222204044.135122          0.537711            72264.818855  2022-12-11 12:04:23.528125                                      random search          False  suboptimal
# neural network m05 rec deep (v06)         0.580348       604.9                 59357.533817           5470834738.338646          0.515701            73965.091349  2022-11-29 11:41:39.682217         loss=4908.71 valloss=4603.08 stop=214/500           False  suboptimal
# neural network (v06)                      0.556696  312.991321                 66710.702966           6646858211.119819          0.411595            81528.266332  2000-01-01 17:09:59.063570  random search [input11, d^20-500-500-20-5, den...            NaN  suboptimal
# neural network m03 2 layers+wider (v06)   0.549647      275.71                 64376.517431           6268024253.295089          0.445131            79170.854822  2022-11-29 10:13:10.517896  mse +epochs=500 +learn=0.003 +loss=5229.047851...          False  suboptimal
# neural network m01 simple (v06)           0.541221        36.2                  80597.58465           9313930610.003286          0.175496            96508.707431  2022-11-29 09:13:15.856770  recommended simple model/mse +norm +epochs=50 ...          False  suboptimal
# neural network simplified (v06)           0.540642         999                 59373.052887           5531509335.791807           0.51033            74374.117378  2022-11-20 20:03:40.645221          recommended simple model + normalise, mse          False  suboptimal
# decision tree - (v06)                     0.524696         NaN                 57094.069341           5369228892.195786          0.524696            73275.022294                         NaN                             random search-no scale            NaN         NaN
# neural network m04 3 layers+wider (v06)   0.520933      395.14                 64421.234531           6266407942.292152          0.445274            79160.646424  2022-11-29 11:21:09.812732          loss=5415.7 valloss=5095.94 stop=166/500           False  suboptimal
# neural network m02 two layers (v06)       0.516773      112.54                 64363.094125           6262090339.685114          0.445656            79133.370582  2022-11-29 09:31:18.853517  mse +norm +epochs=50 +learn=0.003 +endloss=578...          False  suboptimal
# linear regression (ridge) (v06)             0.4569     0.28695                 63603.059705            6135206763.74439          0.456889            78327.560691  2022-12-03 19:20:52.874336                                      random search          False  suboptimal

# %%
dataset_version_06_df
# Out:
#                                         Mean Absolute Error Accuracy Mean Squared Error Accuracy R square Accuracy Root Mean Squared Error                                            _method                                            _params    _score _train time best is shared                                        best method                                        best params               best run date best score   best time                        date                   first run random_state   run_env                                      silver method                                      silver params             silver run date silver score silver time  suboptimal
# xg boost (tree) (v06)                                   41210.351288           3082428096.006462          0.727132            55519.619019                                      random search  {'model__booster': 'dart', 'model__colsample_b...  0.727132  134.174901          False                                      random search  {'model__booster': 'dart', 'model__colsample_b...  2022-12-07 09:43:37.103009   0.727132  134.174901  2022-12-07 09:43:37.103009  2022-12-03 00:21:25.848148          101  gradient                                      random search  {'model__booster': 'dart', 'model__colsample_b...  2022-12-03 00:21:25.790717     0.725989  217.285686     pending
# knn (v06)                                               41531.119915           3218096364.819358          0.715122            56728.267776                                      random search  {'model__algorithm': 'ball_tree', 'model__leaf...  0.715122    0.090606          False                                      random search  {'model__algorithm': 'brute', 'model__leaf_siz...  2022-11-21 18:05:21.585382   0.719049    0.017916  2022-12-07 09:04:23.321690  2022-11-21 17:07:32.229750          101  gradient                                      random search  {'model__algorithm': 'brute', 'model__leaf_siz...  2022-11-21 17:07:32.228547     0.719049    0.018388  suboptimal
# catboost (v06)                                          51000.047694           4301362532.917062          0.619227            65584.773636                          random search(no dummies)  {'depth': 15, 'l2_leaf_reg': 1, 'learning_rate...  0.619227         999          False                                      random search  {'model__depth': 8, 'model__l2_leaf_reg': 1, '...  1999-11-13 15:26:55.706567   0.715606   12.256545  2022-12-07 09:56:18.413405  2022-11-13 00:13:48.870697          101  gradient                          random search(no dummies)  {'depth': 15, 'l2_leaf_reg': 1, 'learning_rate...  2022-12-03 16:27:55.193043     0.619227         999  suboptimal
# light gradient boosting (v06)                           44080.972643           3312839956.633489          0.706735            57557.275445                                      random search  {'model__boosting_type': 'dart', 'model__colsa...  0.706735  111.222566           True                                      random search  {'model__boosting_type': 'dart', 'model__colsa...  2022-11-16 13:59:52.612654   0.706735   15.043873  2022-12-07 10:31:45.923050  2022-11-16 13:49:11.581923          101  gradient                                      random search  {'model__boosting_type': 'dart', 'model__colsa...  2022-12-07 10:31:45.923050     0.706735  111.222566  suboptimal
# xg boost (v06)                                          45988.280765           3528869693.681411          0.687611            59404.290196                                      random search  {'model__booster': 'dart', 'model__early_stopp...  0.687611   11.474795            NaN                                      random search  {'model__booster': 'dart', 'model__early_stopp...                         NaN   0.687611   11.474795  2022-11-14 09:42:14.670928  2022-11-06 22:13:02.393884          101  gradient                                                NaN                                                NaN                         NaN          NaN         NaN     pending
# decision tree (v06)                                       56888.9238           5206013958.612971          0.539144             72152.71276                                      random search  {'model__ccp_alpha': 0.1, 'model__criterion': ...  0.539144     0.06554          False                                      random search  {'model__ccp_alpha': 0.0, 'model__criterion': ...  2022-12-11 13:59:57.993851   0.616727    0.133738  2022-12-11 14:03:58.545518  2022-12-11 13:59:58.016969          101  gradient                                      random search  {'model__ccp_alpha': 0.1, 'model__criterion': ...  2022-12-11 14:03:58.545518     0.539144     0.06554  suboptimal
# neural network m11 mega (v06)                           56035.854723           4929943923.096645          0.563583            70213.559396  loss=5.26e+09 valloss=4.98e+09 +valsplit=0.1 s...                      mse +epochs=400 +learn=0.0003  0.563583      619.04          False         loss=2833.6 valloss=4034.41 stop=619/1000                       mse +epochs=1000 +learn=3e-05  2022-11-29 12:57:16.459719   0.612318     2569.45  2022-12-04 10:03:27.888378  2022-11-29 12:57:16.462242          101  gradient  loss=5.26e+09 valloss=4.98e+09 +valsplit=0.1 s...                      mse +epochs=400 +learn=0.0003  2022-12-04 10:03:27.888378     0.563583      619.04  suboptimal
# neural network m12 mega (v06)                           54967.975952           4807033830.676171          0.574463             69332.77602  loss=4.95e+09 valloss=4.83e+09 +valsplit=0.1 +...                      mse +epochs=400 +learn=0.0003  0.574463      701.19          False  loss=4386.51 valloss=4438.8 +valsplit=0.1 stop...                      mse +epochs=400 +learn=0.0003  2022-11-29 17:08:44.480482   0.594032      813.27  2022-12-07 15:08:22.867761  2022-11-29 14:57:19.333225          101  gradient        loss=3205.55 valloss=4148.49 stop=540/1000                      mse +epochs=1000 +learn=0.0003  2022-11-29 14:57:19.331629      0.59056     1714.15  suboptimal
# random forest (v06)                                     59011.811654           5222204044.135122          0.537711            72264.818855                                      random search  {'model__bootstrap': True, 'model__ccp_alpha':...  0.537711    1.119174          False                                      random search  {'model__bootstrap': True, 'model__ccp_alpha':...  2022-12-11 12:04:23.528125   0.585876    1.769856  2022-12-11 13:52:21.223251  2022-12-11 12:04:23.529045          101  gradient                                      random search  {'model__bootstrap': True, 'model__ccp_alpha':...  2022-12-11 13:02:31.973811     0.584706  286.298005  suboptimal
# neural network m05 rec deep (v06)                       59357.533817           5470834738.338646          0.515701            73965.091349  loss=5.68e+09 valloss=5.61e+09 +valsplit=0.1 s...                      mse +epochs=500 +learn=0.0003  0.515701      817.31          False         loss=4908.71 valloss=4603.08 stop=214/500                       mse +epochs=500 +learn=0.0003  2022-11-29 11:41:39.682217   0.580348       604.9  2022-12-04 09:04:41.398760  2022-11-29 11:41:39.687521          101  gradient          loss=4913.25 valloss=4700.2 stop=197/500                       mse +epochs=500 +learn=0.0003  2022-11-29 12:04:25.727274     0.564694      524.81  suboptimal
# neural network (v06)                                    66710.702966           6646858211.119819          0.411595            81528.266332          recommended simple model + normalise, mse                                      not available  0.411595         999            NaN  random search [input11, d^20-500-500-20-5, den...  {'model__batch_size': 100, 'model__epochs': 50...  2000-01-01 17:09:59.063570   0.556696  312.991321  2022-11-20 14:54:25.454237  2022-11-11 01:20:17.647823          101  gradient                quite simple model + normalise, mse                                      not available  2022-11-20 13:46:58.237840     0.471666         999  suboptimal
# neural network m03 2 layers+wider (v06)                 64376.517431           6268024253.295089          0.445131            79170.854822  loss=6.52e+09 valloss=6.54e+09 +valsplit=0.1 s...                      mse +epochs=500 +learn=0.0003  0.445131     1582.25          False  mse +epochs=500 +learn=0.003 +loss=5229.047851...  mse +epochs=500 +learn=0.003 +loss=5229.047851...  2022-11-29 10:13:10.517896   0.549647      275.71  2022-12-04 06:56:27.034049  2022-11-29 09:50:03.166282          101  gradient  mse +norm +epochs=500 +learn=0.003 +stop=154 +...  mse +norm +epochs=500 +learn=0.003 +stop=154 +...  2022-11-29 09:50:03.096053     0.540557      343.65  suboptimal
# neural network m01 simple (v06)                          80597.58465           9313930610.003286          0.175496            96508.707431       loss=9.56e+09 valloss=9.57e+09 +valsplit=0.1                        mse +epochs=50 +learn=0.003  0.175496      272.81          False  recommended simple model/mse +norm +epochs=50 ...  recommended simple model/mse +norm +epochs=50 ...  2022-11-29 09:13:15.856770   0.541221        36.2  2022-12-03 22:12:21.042705  2022-11-29 09:04:10.848693          101  gradient  recommended simple model/mse +norm +epochs=50 ...  recommended simple model/mse +norm +epochs=50 ...  2022-11-29 09:06:27.904880      0.53227      104.31  suboptimal
# neural network simplified (v06)                         59373.052887           5531509335.791807           0.51033            74374.117378  recommended simple model/mse +norm +epochs=300...  recommended simple model/mse +norm +epochs=300...   0.51033         999          False          recommended simple model + normalise, mse          recommended simple model + normalise, mse  2022-11-20 20:03:40.645221   0.540642         999  2022-11-21 17:56:15.332238  2022-11-20 15:01:27.968593          101  gradient  recommended simple model/mse +norm +epochs=300...  recommended simple model/mse +norm +epochs=300...  2022-11-21 17:56:15.332238      0.51033         999  suboptimal
# decision tree - (v06)                                   57094.069341           5369228892.195786          0.524696            73275.022294                             random search-no scale  {'model__ccp_alpha': 1, 'model__criterion': 'a...  0.524696   63.259539            NaN                             random search-no scale                             MULTIPLE PARAM OPTIONS                         NaN   0.524696         NaN  2022-11-09 16:52:04.477662  2022-11-09 14:33:34.674335          101       NaN                                                NaN                                                NaN                         NaN          NaN         NaN         NaN
# neural network m04 3 layers+wider (v06)                 64421.234531           6266407942.292152          0.445274            79160.646424  loss=6.55e+09 valloss=6.54e+09 +valsplit=0.1 s...                       mse +epochs=500 +learn=0.003  0.445274       221.2          False          loss=5415.7 valloss=5095.94 stop=166/500                        mse +epochs=500 +learn=0.003  2022-11-29 11:21:09.812732   0.520933      395.14  2022-12-04 06:38:01.102023  2022-11-29 11:21:09.825167          101  gradient  loss=6.55e+09 valloss=6.54e+09 +valsplit=0.1 s...                       mse +epochs=500 +learn=0.003  2022-12-04 06:38:01.102023     0.445274       221.2  suboptimal
# neural network m02 two layers (v06)                     64363.094125           6262090339.685114          0.445656            79133.370582  loss=6.53e+09 valloss=6.54e+09 +valsplit=0.1 s...                       mse +epochs=500 +learn=0.003  0.445656      216.54          False  mse +norm +epochs=50 +learn=0.003 +endloss=578...  mse +norm +epochs=50 +learn=0.003 +endloss=578...  2022-11-29 09:31:18.853517   0.516773      112.54  2022-12-04 05:30:29.106844  2022-11-29 09:31:18.858404          101  gradient  mse +norm +epochs=500 +learn=0.003 +stop=32 +e...  mse +norm +epochs=500 +learn=0.003 +stop=32 +e...  2022-11-29 09:35:17.501089     0.505803       71.81  suboptimal
# linear regression (ridge) (v06)                         63603.059705            6135206763.74439          0.456889            78327.560691                                      random search  {'model__alpha': 0.001, 'model__copy_X': False...  0.456889    0.019823          False                                      random search  {'model__alpha': 1e-05, 'model__copy_X': False...  2022-12-03 19:20:52.874336     0.4569     0.28695  2022-12-07 08:12:32.333127  2022-11-15 21:02:22.079702          101  gradient                                      random search  {'model__alpha': 0.0001, 'model__copy_X': Fals...  2022-12-03 19:28:37.848562       0.4569    0.244021  suboptimal

# %%
dataset_version_06_df_1_vs_2 = dataset_version_06_df[['best score', 'best time', 'silver score', 'silver time', 'best method','silver method','best is shared']]
dataset_version_06_df_1_vs_2
# Out:
#                                         best score   best time silver score silver time                                        best method                                      silver method best is shared
# xg boost (tree) (v06)                     0.727132  134.174901     0.725989  217.285686                                      random search                                      random search          False
# knn (v06)                                 0.719049    0.017916     0.719049    0.018388                                      random search                                      random search          False
# catboost (v06)                            0.715606   12.256545     0.619227         999                                      random search                          random search(no dummies)          False
# light gradient boosting (v06)             0.706735   15.043873     0.706735  111.222566                                      random search                                      random search           True
# xg boost (v06)                            0.687611   11.474795          NaN         NaN                                      random search                                                NaN            NaN
# decision tree (v06)                       0.616727    0.133738     0.539144     0.06554                                      random search                                      random search          False
# neural network m11 mega (v06)             0.612318     2569.45     0.563583      619.04         loss=2833.6 valloss=4034.41 stop=619/1000   loss=5.26e+09 valloss=4.98e+09 +valsplit=0.1 s...          False
# neural network m12 mega (v06)             0.594032      813.27      0.59056     1714.15  loss=4386.51 valloss=4438.8 +valsplit=0.1 stop...        loss=3205.55 valloss=4148.49 stop=540/1000           False
# random forest (v06)                       0.585876    1.769856     0.584706  286.298005                                      random search                                      random search          False
# neural network m05 rec deep (v06)         0.580348       604.9     0.564694      524.81         loss=4908.71 valloss=4603.08 stop=214/500           loss=4913.25 valloss=4700.2 stop=197/500           False
# neural network (v06)                      0.556696  312.991321     0.471666         999  random search [input11, d^20-500-500-20-5, den...                quite simple model + normalise, mse            NaN
# neural network m03 2 layers+wider (v06)   0.549647      275.71     0.540557      343.65  mse +epochs=500 +learn=0.003 +loss=5229.047851...  mse +norm +epochs=500 +learn=0.003 +stop=154 +...          False
# neural network m01 simple (v06)           0.541221        36.2      0.53227      104.31  recommended simple model/mse +norm +epochs=50 ...  recommended simple model/mse +norm +epochs=50 ...          False
# neural network simplified (v06)           0.540642         999      0.51033         999          recommended simple model + normalise, mse  recommended simple model/mse +norm +epochs=300...          False
# decision tree - (v06)                     0.524696         NaN          NaN         NaN                             random search-no scale                                                NaN            NaN
# neural network m04 3 layers+wider (v06)   0.520933      395.14     0.445274       221.2          loss=5415.7 valloss=5095.94 stop=166/500   loss=6.55e+09 valloss=6.54e+09 +valsplit=0.1 s...          False
# neural network m02 two layers (v06)       0.516773      112.54     0.505803       71.81  mse +norm +epochs=50 +learn=0.003 +endloss=578...  mse +norm +epochs=500 +learn=0.003 +stop=32 +e...          False
# linear regression (ridge) (v06)             0.4569     0.28695       0.4569    0.244021                                      random search                                      random search          False

# %%
dataset_version_06_df_1_vs_2b = dataset_version_06_df[['best score', 'best time', 'silver score', 'silver time', 'best params','silver params','best is shared']]
dataset_version_06_df_1_vs_2b
# Out:
#                                         best score   best time silver score silver time                                        best params                                      silver params best is shared
# xg boost (tree) (v06)                     0.727132  134.174901     0.725989  217.285686  {'model__booster': 'dart', 'model__colsample_b...  {'model__booster': 'dart', 'model__colsample_b...          False
# knn (v06)                                 0.719049    0.017916     0.719049    0.018388  {'model__algorithm': 'brute', 'model__leaf_siz...  {'model__algorithm': 'brute', 'model__leaf_siz...          False
# catboost (v06)                            0.715606   12.256545     0.619227         999  {'model__depth': 8, 'model__l2_leaf_reg': 1, '...  {'depth': 15, 'l2_leaf_reg': 1, 'learning_rate...          False
# light gradient boosting (v06)             0.706735   15.043873     0.706735  111.222566  {'model__boosting_type': 'dart', 'model__colsa...  {'model__boosting_type': 'dart', 'model__colsa...           True
# xg boost (v06)                            0.687611   11.474795          NaN         NaN  {'model__booster': 'dart', 'model__early_stopp...                                                NaN            NaN
# decision tree (v06)                       0.616727    0.133738     0.539144     0.06554  {'model__ccp_alpha': 0.0, 'model__criterion': ...  {'model__ccp_alpha': 0.1, 'model__criterion': ...          False
# neural network m11 mega (v06)             0.612318     2569.45     0.563583      619.04                      mse +epochs=1000 +learn=3e-05                      mse +epochs=400 +learn=0.0003          False
# neural network m12 mega (v06)             0.594032      813.27      0.59056     1714.15                      mse +epochs=400 +learn=0.0003                     mse +epochs=1000 +learn=0.0003          False
# random forest (v06)                       0.585876    1.769856     0.584706  286.298005  {'model__bootstrap': True, 'model__ccp_alpha':...  {'model__bootstrap': True, 'model__ccp_alpha':...          False
# neural network m05 rec deep (v06)         0.580348       604.9     0.564694      524.81                      mse +epochs=500 +learn=0.0003                      mse +epochs=500 +learn=0.0003          False
# neural network (v06)                      0.556696  312.991321     0.471666         999  {'model__batch_size': 100, 'model__epochs': 50...                                      not available            NaN
# neural network m03 2 layers+wider (v06)   0.549647      275.71     0.540557      343.65  mse +epochs=500 +learn=0.003 +loss=5229.047851...  mse +norm +epochs=500 +learn=0.003 +stop=154 +...          False
# neural network m01 simple (v06)           0.541221        36.2      0.53227      104.31  recommended simple model/mse +norm +epochs=50 ...  recommended simple model/mse +norm +epochs=50 ...          False
# neural network simplified (v06)           0.540642         999      0.51033         999          recommended simple model + normalise, mse  recommended simple model/mse +norm +epochs=300...          False
# decision tree - (v06)                     0.524696         NaN          NaN         NaN                             MULTIPLE PARAM OPTIONS                                                NaN            NaN
# neural network m04 3 layers+wider (v06)   0.520933      395.14     0.445274       221.2                       mse +epochs=500 +learn=0.003                       mse +epochs=500 +learn=0.003          False
# neural network m02 two layers (v06)       0.516773      112.54     0.505803       71.81  mse +norm +epochs=50 +learn=0.003 +endloss=578...  mse +norm +epochs=500 +learn=0.003 +stop=32 +e...          False
# linear regression (ridge) (v06)             0.4569     0.28695       0.4569    0.244021  {'model__alpha': 1e-05, 'model__copy_X': False...  {'model__alpha': 0.0001, 'model__copy_X': Fals...          False
