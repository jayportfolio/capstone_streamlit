# %%
import pandas as pd

dff = pd.read_json('results.json')
v06_columns = [c for c in dff.columns if 'v06' in c]
dataset_version_06_df = dff[v06_columns].T.sort_values("Score", ascending=False)
dataset_version_06_df
# Out:
#                                                    Mean Absolute Error Accuracy  \
# knn - random search (v06)                                          41436.192102
# xg boost - random search (v06)                                     42558.373711
# decision tree - random search (v06)                                58238.093361
# neural network - grid search [input64, norm, de...                 59354.382142
# linear regression (ridge) - random search (v06)                    63603.318764
#
#                                                    Mean Squared Error Accuracy  \
# knn - random search (v06)                                     3173217184.14441
# xg boost - random search (v06)                               3230445866.732875
# decision tree - random search (v06)                           5668783177.55937
# neural network - grid search [input64, norm, de...            5684315555.45259
# linear regression (ridge) - random search (v06)              6135244428.758685
#
# ...

# %%
dataset_version_06_df[['Score', 'date', 'Mean Absolute Error Accuracy', 'Mean Squared Error Accuracy', 'R square Accuracy', 'Root Mean Squared Error', 'Training Time']]
# Out:
#                                                        Score  \
# knn - random search (v06)                           0.719095
# xg boost - random search (v06)                      0.714029
# decision tree - random search (v06)                 0.498178
# neural network - grid search [input64, norm, de...  0.496803
# linear regression (ridge) - random search (v06)     0.456885
#
#                                                                           date  \
# knn - random search (v06)                           2022-11-06 22:02:46.047968
# xg boost - random search (v06)                      2022-11-06 22:13:02.391528
# decision tree - random search (v06)                 2022-11-06 22:09:00.900366
# neural network - grid search [input64, norm, de...  2022-11-06 22:30:24.182036
# linear regression (ridge) - random search (v06)     2022-11-06 21:55:01.847359
#
#                                                    Mean Absolute Error Accuracy  \
# ...
