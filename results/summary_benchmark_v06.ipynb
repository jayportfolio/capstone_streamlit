# %%
import pandas as pd

dff = pd.read_json('results.json')
v06_columns = [c for c in dff.columns if 'v06' in c]

dataset_version_06_df = dff[v06_columns].T.sort_values("_score", ascending=False)
dataset_version_06_df_summary = dataset_version_06_df[['_score', "suboptimal", 'date', 'Mean Absolute Error Accuracy', 'Mean Squared Error Accuracy', 'R square Accuracy', 'Root Mean Squared Error', '_train time','best is shared']]
dataset_version_06_df_summary
# Out:
#                                                       _score  suboptimal  \
# knn - random search (v06)                            0.71908  suboptimal
# catboost - random search (v06)                      0.715606     pending
# xg boost - random search (v06)                      0.687611     pending
# random forest - random search (v06)                 0.666175     pending
# neural network - random search [input11, d^20-5...  0.606696     pending
# decision tree - random search (v06)                 0.602139     pending
# decision tree - random search-no scale (v06)        0.524696         NaN
# neural network - grid search [input64, norm, de...  0.496803     pending
# linear regression (ridge) - random search (v06)       0.4569     pending
# decision tree - random search-no scale|no dummi...  0.234333         NaN
#
#                                                                           date  \
# knn - random search (v06)                           2022-11-14 11:04:06.340350
# ...

# %%
dataset_version_06_df
# Out:
#                                                    Mean Absolute Error Accuracy  \
# knn - random search (v06)                                          41435.715578
# catboost - random search (v06)                                     43622.749758
# xg boost - random search (v06)                                     45988.280765
# random forest - random search (v06)                                48257.442864
# neural network - random search [input11, d^20-5...                 52689.052345
# decision tree - random search (v06)                                50514.334353
# decision tree - random search-no scale (v06)                       57094.069341
# neural network - grid search [input64, norm, de...                 59354.382142
# linear regression (ridge) - random search (v06)                    63601.874995
# decision tree - random search-no scale|no dummi...                 75835.380467
#
#                                                    Mean Squared Error Accuracy  \
# ...
