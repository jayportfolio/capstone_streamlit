# %%
import pandas as pd

dff = pd.read_json('results.json')
v06_columns = [c for c in dff.columns if 'v06' in c]

dataset_version_06_df = dff[v06_columns].T.sort_values("_score", ascending=False)
dataset_version_06_df_summary = dataset_version_06_df[['_score', "suboptimal", 'date', 'Mean Absolute Error Accuracy', 'Mean Squared Error Accuracy', 'R square Accuracy', 'Root Mean Squared Error', '_train time','_method','best is shared']]
dataset_version_06_df_summary
# Out:
#                                    _score  suboptimal  \
# knn - random search (v06)         0.71908  suboptimal
# catboost (v06)                   0.715606     pending
# xg boost (v06)                   0.687611     pending
# random forest (v06)              0.666175     pending
# neural network (v06)             0.598304     pending
# decision tree - (v06)            0.524696         NaN
# linear regression (ridge) (v06)  0.456885     pending
# decision tree (v06)              0.234333         NaN
#
#                                                        date  \
# knn - random search (v06)        2022-11-14 11:04:06.340350
# catboost (v06)                   2022-11-13 15:26:55.706567
# xg boost (v06)                   2022-11-14 09:42:14.670928
# random forest (v06)              2022-11-13 21:42:14.657419
# neural network (v06)             2022-11-14 17:09:59.063570
# decision tree - (v06)            2022-11-09 16:52:04.477662
# ...

# %%
dataset_version_06_df
# Out:
#                                 Mean Absolute Error Accuracy  \
# knn - random search (v06)                       41435.715578
# catboost (v06)                                  43622.749758
# xg boost (v06)                                  45988.280765
# random forest (v06)                             48257.442864
# neural network (v06)                             53239.05208
# decision tree - (v06)                           57094.069341
# linear regression (ridge) (v06)                 63603.299582
# decision tree (v06)                             75835.380467
#
#                                 Mean Squared Error Accuracy R square Accuracy  \
# knn - random search (v06)                  3173381332.25707           0.71908
# catboost (v06)                            3212635545.386724          0.715606
# xg boost (v06)                            3528869693.681411          0.687611
# random forest (v06)                       3771022259.944156          0.666175
# ...
