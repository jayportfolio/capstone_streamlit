# %%
import pandas as pd

summary_by_score = pd.read_json('results.json').T.sort_values("_score", ascending=False)
summary_by_score_df = pd.DataFrame(summary_by_score)
#print(summary_by_score_df.columns)
summary_by_score_df
# Out:
#                                                    Mean Absolute Error Accuracy  \
# xg boost - random search (v11)                                     42603.011667
# knn - random search (v06)                                          41435.715578
# catboost - random search (v06)                                     43622.749758
# xg boost - random search (v10)                                     43382.001905
# xg boost - random search (v05)                                     42229.001752
# xg boost - random search (v09)                                     43377.724245
# xg boost - random search (v06)                                     45988.280765
# xg boost - random search (v02)                                     45160.157667
# random forest - random search (v06)                                48257.442864
# xg boost - basic (v02)                                             48536.519056
# random forest - random search (v10)                                 49941.97226
# ...

# %%
pd.DataFrame(pd.read_json('results.json').T.sort_values("date", ascending=False)[['_score','date']])
# Out:
#                                                       _score  \
# linear regression (ridge) - random search (v06)     0.456885
# neural network - random search [input11, d^20-5...  0.598304
# knn - random search (v06)                            0.71908
# xg boost - random search (v06)                      0.687611
# random forest - random search (v06)                 0.666175
# decision tree - random search (v06)                 0.602139
# catboost - random search (v06)                      0.715606
# decision tree - random search-no scale (v06)        0.524696
# decision tree - random search-no scale|no dummi...  0.234333
# linear regression (ridge) - random search (v10)     0.470785
# random forest - random search (v10)                 0.647421
# decision tree - random search (v10)                 0.558257
# neural network - random search [i64,norm,d64^6,...  0.533579
# xg boost - random search (v11)                      0.721019
# ...

# %%
summary_by_mse = pd.read_json('results.json').T.sort_values("Mean Squared Error Accuracy", ascending=True)
pd.DataFrame(summary_by_mse)
# Out:
#                                                    Mean Absolute Error Accuracy  \
# xg boost - random search (v11)                                     42603.011667
# knn - random search (v06)                                          41436.192102
# xg boost - random search (v05)                                     42229.001752
# xg boost - random search (v10)                                     43382.001905
# xg boost - random search (v09)                                     43377.724245
# xg boost - random search (v03) ALT                                 43722.210759
# xg boost - random search (v02)                                     45160.157667
# xg boost - random search (v02) [ORIG]                              48536.519056
# xg boost - basic (v02)                                             48536.519056
# random forest - random search (v10)                                 49941.97226
# random forest - random search (v06)                                50884.279358
# ...
