# %%
ALGORITHM = 'XG Boost'
ALGORITHM_DETAIL = 'random search'
DATA_DETAIL = []
#DATA_DETAIL = ['no scale','no dummies']
VERSION = '06'

RANDOM_STATE = 101
TRAINING_SIZE = 0.9

CROSS_VALIDATION_SCORING = 'r2'

# %%
from xgboost import XGBRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler

starter_pipe = Pipeline([
    #('mms', MinMaxScaler()),
    ('std_scaler', StandardScaler()),
    ('model', XGBRegressor(seed=20))
])

# %%
from sklearn.impute import SimpleImputer
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
import numpy as np
from pandas import DataFrame
import math
from termcolor import colored
from time import time
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
import seaborn as sns
import pickle

import json
from datetime import datetime
import matplotlib.pyplot as plt

with open('../../z_envs/_envs.json') as f:
    env_vars = json.loads(f.read())
print(env_vars)

try:
    import google.colab

    run_env = 'colab'
except:
    try:
        run_env = env_vars['notebook_environment']
    except:
        run_env = 'unknown'

use_gpu = env_vars.get('use_gpu', False)
debug_mode = env_vars.get('debug_mode', False)
quick_mode = env_vars.get('quick_mode', False)
OVERRIDE_CV = env_vars.get('quick_override_cv_splits', None) if quick_mode else None
OVERRIDE_N_ITER = env_vars.get('quick_override_n_iter', None) if quick_mode else None
OVERRIDE_JOBS = env_vars.get('quick_override_n_jobs', None) if quick_mode else None
#if quick_mode:OVERRIDE_CV, OVERRIDE_N_ITER = 2, 10

if run_env in ['colab', 'gradient', 'cloud']:
    cloud_run = True
    from functions_20221109 import set_csv_directory, get_columns
    from functions_modelling_20221109 import make_modelling_pipeline, tidy_dataset, preprocess, feature_engineer, create_train_test_data
    from functions_modelling_20221109 import get_cv_params, fit_model_with_cross_validation, get_best_estimator_average_time, get_results, update_results

    set_csv_directory('final_split')
else:
    cloud_run = False
    import sys
    import os

    module_path = os.path.abspath(os.path.join('..', '..', '..'))
    if module_path not in sys.path:
        #sys.path.append(module_path+"\\zfunctions")
        sys.path.append(module_path)

    from functions_20221109 import set_csv_directory, get_columns
    #from functions_20221109 import add_supplements, get_combined_dataset
    from functions_modelling_20221109 import make_modelling_pipeline, tidy_dataset, preprocess, feature_engineer, create_train_test_data
    from functions_modelling_20221109 import get_cv_params, fit_model_with_cross_validation, get_best_estimator_average_time, get_results, update_results
# Out:
# {'notebook_environment': 'local', 'use_gpu': False, 'debug_mode': False, 'quick_mode': True, 'quick_override_cv_splits': 2, 'quick_override_n_iter': 10, 'quick_override_n_jobs': 3}

# %%
#cutdown_rows = 1000
cutdown_rows = 0

LABEL = 'Price'

columns, booleans, floats, categories, custom, wildcard = get_columns(version=VERSION)

print(colored(f"features", "blue"), "-> ", columns)
columns.insert(0, LABEL)
print(colored(f"label", "green", None, ['bold']), "-> ", LABEL)
# Out:
# features ->  ['bedrooms', 'bathrooms', 'nearestStation', 'location.latitude', 'location.longitude', 'latitude_deviation', 'longitude_deviation', 'tenure.tenureType']
# label ->  Price

# %%
def get_source_dataframe(rows=cutdown_rows, folder_prefix='../../../'):
    retrieval_type = None

    filename = f'df_listings_v{VERSION}.csv'
    remote_pathname = f'https://raw.githubusercontent.com/jayportfolio/capstone_streamlit/main/data/final/{filename}'
    df_pathname_raw = folder_prefix + f'data/source/{filename}'
    df_pathname_tidy = folder_prefix + f'data/final/{filename}'

    if cloud_run:
        inDF = pd.read_csv(remote_pathname, on_bad_lines='error', index_col=0)
        retrieval_type = 'tidy'
        print('loaded data from', folder_prefix + remote_pathname)
    else:
        inDF = pd.read_csv(df_pathname_tidy, on_bad_lines='error', index_col=0)
        retrieval_type = 'tidy'
        print('loaded data from', df_pathname_tidy)

    if rows and rows > 0:
        inDF = inDF[:rows]
    return inDF, retrieval_type

# %%
df, retrieval_type = get_source_dataframe(folder_prefix='../../../')
df_orig = df.copy()

if retrieval_type != 'tidy':
    df = tidy_dataset(df, version=int(VERSION))
    df = feature_engineer(df, version=int(VERSION))

    df = df[columns]

print(df.shape)
# Out:
# loaded data from ../../../data/final/df_listings_v06.csv
# (46871, 9)

# %%
df.head(30)
# Out:
#              Price  bedrooms  bathrooms  nearestStation  location.latitude  \
# 14520525  550000.0       3.0        1.0        0.274316          51.529950
# 27953107  400000.0       2.0        2.0        0.305845          51.549390
# 33593487  579950.0       2.0        1.0        0.438045          51.447180
# 35271294  370000.0       2.0        1.0        0.399307          51.449568
# 35429088  599950.0       2.0        1.0        0.238187          51.577030
# 44749111  475000.0       2.0        1.0        0.410550          51.370050
# 46204665  435000.0       3.0        2.0        0.314779          51.539070
# 49020666  200000.0       1.0        1.0        0.875911          51.539959
# 49036279  275000.0       2.0        1.0        0.474368          51.541780
# 49303873  450000.0       3.0        2.0        0.577040          51.524880
# 52064391  349950.0       2.0        2.0        0.212734          51.470800
# 52187854  450000.0       1.0        1.0        0.446802          51.527199
# 52675628  490000.0       2.0        2.0        0.215040          51.501114
# 52845963  200000.0       2.0        1.0        0.650562          51.398040
# 52913496  220000.0       1.0        1.0        0.945991          51.539383
# 53609433  489995.0       1.0        1.0        0.087081          51.532620
# 53649578  284950.0       1.0        1.0        0.806597          51.479890
# 53938989  450000.0       2.0        1.0        0.775203          51.658287
# 54713232  332000.0       2.0        1.0        0.319226          51.612300
# 54904122  365000.0       2.0        1.0        0.260722          51.593595
# 54991934  430000.0       3.0        1.0        0.497268          51.528720
# 55043230  260000.0       1.0        1.0        0.384607          51.544430
# 55187658  430000.0       2.0        2.0        0.289033          51.507570
# 55531367  599950.0       2.0        1.0        0.406725          51.467410
# 55768232  550000.0       2.0        1.0        0.478349          51.472890
# 55805965  280000.0       2.0        1.0        0.742859          51.520910
# 55839051  599950.0       2.0        1.0        0.259168          51.579186
# 55940994  385000.0       2.0        2.0        0.403987          51.376930
# 56449305  380000.0       2.0        1.0        0.310271          51.600483
# 57221413  475000.0       3.0        2.0        0.409784          51.497260
#
#           location.longitude  latitude_deviation  longitude_deviation  \
# 14520525           -0.207020            0.030230             0.102600
# 27953107           -0.482600            0.049670             0.378180
# 33593487           -0.338770            0.052540             0.234350
# 35271294           -0.140154            0.050152             0.035734
# 35429088           -0.141230            0.077310             0.036810
# 44749111           -0.212410            0.129670             0.107990
# 46204665           -0.198935            0.039350             0.094515
# 49020666           -0.380863            0.040239             0.276443
# 49036279            0.037890            0.042060             0.142310
# 49303873            0.187200            0.025160             0.291620
# 52064391           -0.361820            0.028920             0.257400
# 52187854           -0.202898            0.027479             0.098478
# 52675628            0.026315            0.001394             0.130735
# 52845963           -0.076812            0.101680             0.027608
# 52913496           -0.382239            0.039663             0.277819
# 53609433           -0.107860            0.032900             0.003440
# 53649578           -0.078500            0.019830             0.025920
# 53938989           -0.207902            0.158567             0.103482
# 54713232           -0.119860            0.112580             0.015440
# 54904122            0.022046            0.093875             0.126466
# 54991934            0.039180            0.029000             0.143600
# 55043230            0.014500            0.044710             0.118920
# 55187658            0.078030            0.007850             0.182450
# 55531367           -0.079170            0.032310             0.025250
# 55768232           -0.078940            0.026830             0.025480
# 55805965            0.022680            0.021190             0.127100
# 55839051           -0.209020            0.079466             0.104600
# 55940994           -0.238870            0.122790             0.134450
# 56449305           -0.062096            0.100763             0.042324
# 57221413           -0.422530            0.002460             0.318110
#
#           tenure.tenureType
# 14520525          LEASEHOLD
# 27953107          LEASEHOLD
# 33593487           FREEHOLD
# 35271294          LEASEHOLD
# 35429088                NaN
# 44749111           FREEHOLD
# 46204665          LEASEHOLD
# 49020666          LEASEHOLD
# 49036279          LEASEHOLD
# 49303873           FREEHOLD
# 52064391          LEASEHOLD
# 52187854          LEASEHOLD
# 52675628                NaN
# 52845963          LEASEHOLD
# 52913496          LEASEHOLD
# 53609433          LEASEHOLD
# 53649578                NaN
# 53938989           FREEHOLD
# 54713232  SHARE_OF_FREEHOLD
# 54904122  SHARE_OF_FREEHOLD
# 54991934           FREEHOLD
# 55043230          LEASEHOLD
# 55187658          LEASEHOLD
# 55531367                NaN
# 55768232                NaN
# 55805965          LEASEHOLD
# 55839051          LEASEHOLD
# 55940994          LEASEHOLD
# 56449305           FREEHOLD
# 57221413           FREEHOLD

# %%
df.isnull().sum()
# Out:
# Price                     0
# bedrooms                  0
# bathrooms                 0
# nearestStation            0
# location.latitude         0
# location.longitude        0
# latitude_deviation        0
# longitude_deviation       0
# tenure.tenureType      2744
# dtype: int64

# %%
df.info()
df.describe()
df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46871 entries, 14520525 to 126181118
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                46871 non-null  float64
#  1   bedrooms             46871 non-null  float64
#  2   bathrooms            46871 non-null  float64
#  3   nearestStation       46871 non-null  float64
#  4   location.latitude    46871 non-null  float64
#  5   location.longitude   46871 non-null  float64
#  6   latitude_deviation   46871 non-null  float64
#  7   longitude_deviation  46871 non-null  float64
#  8   tenure.tenureType    44127 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 3.6+ MB
#                        count           mean            std            min  \
# Price                46871.0  425069.390775  107227.324906  100000.000000
# bedrooms             46871.0       1.992469       0.828837       1.000000
# bathrooms            46871.0       1.182074       0.409879       1.000000
# nearestStation       46871.0       0.438847       0.325942       0.000000
# location.latitude    46871.0      51.497049       0.077085      51.298317
# location.longitude   46871.0      -0.113269       0.156489      -0.498315
# latitude_deviation   46871.0       0.064317       0.042573       0.000000
# longitude_deviation  46871.0       0.124202       0.095607       0.000000
#
#                                25%            50%            75%  \
# Price                349950.000000  425000.000000  515000.000000
# bedrooms                  1.000000       2.000000       3.000000
# bathrooms                 1.000000       1.000000       1.000000
# nearestStation            0.227169       0.367971       0.559620
# location.latitude        51.438861      51.499977      51.556183
# location.longitude       -0.210796      -0.102230      -0.010343
# latitude_deviation        0.028876       0.058595       0.094362
# longitude_deviation       0.043560       0.098984       0.192684
#
#                                max
# Price                600000.000000
# bedrooms                  7.000000
# bathrooms                 5.000000
# nearestStation            7.197700
# location.latitude        51.683185
# location.longitude        0.279726
# latitude_deviation        0.201403
# longitude_deviation       0.393895

# %%
old_length = len(df)

df = preprocess(df, version=VERSION)

print(f"dataframe contract due to cleaning: {old_length} ==> {len(df)}")
old_length = len(df)

df.describe().T
# Out:
# dataframe contract due to cleaning: 46871 ==> 46871
#                        count           mean            std            min  \
# Price                46871.0  425069.390775  107227.324906  100000.000000
# bedrooms             46871.0       1.992469       0.828837       1.000000
# bathrooms            46871.0       1.182074       0.409879       1.000000
# nearestStation       46871.0       0.438847       0.325942       0.000000
# location.latitude    46871.0      51.497049       0.077085      51.298317
# location.longitude   46871.0      -0.113269       0.156489      -0.498315
# latitude_deviation   46871.0       0.064317       0.042573       0.000000
# longitude_deviation  46871.0       0.124202       0.095607       0.000000
#
#                                25%            50%            75%  \
# Price                349950.000000  425000.000000  515000.000000
# bedrooms                  1.000000       2.000000       3.000000
# bathrooms                 1.000000       1.000000       1.000000
# nearestStation            0.227169       0.367971       0.559620
# location.latitude        51.438861      51.499977      51.556183
# location.longitude       -0.210796      -0.102230      -0.010343
# latitude_deviation        0.028876       0.058595       0.094362
# longitude_deviation       0.043560       0.098984       0.192684
#
#                                max
# Price                600000.000000
# bedrooms                  7.000000
# bathrooms                 5.000000
# nearestStation            7.197700
# location.latitude        51.683185
# location.longitude        0.279726
# latitude_deviation        0.201403
# longitude_deviation       0.393895

# %%
df.isna().sum()
# Out:
# Price                     0
# bedrooms                  0
# bathrooms                 0
# nearestStation            0
# location.latitude         0
# location.longitude        0
# latitude_deviation        0
# longitude_deviation       0
# tenure.tenureType      2744
# dtype: int64

# %%
df = df.dropna()
print(f"{old_length} ==> {len(df)}")
old_length = len(df)
df.describe()
# Out:
# 46871 ==> 44127
#                Price      bedrooms    bathrooms  nearestStation  \
# count   44127.000000  44127.000000  44127.00000    44127.000000
# mean   425224.642373      1.990981      1.18134        0.438522
# std    107203.332660      0.827621      0.40893        0.324152
# min    100000.000000      1.000000      1.00000        0.000000
# 25%    349950.000000      1.000000      1.00000        0.227551
# 50%    425000.000000      2.000000      1.00000        0.368351
# 75%    515000.000000      3.000000      1.00000        0.559486
# max    600000.000000      7.000000      5.00000        7.197700
#
#        location.latitude  location.longitude  latitude_deviation  \
# count       44127.000000        44127.000000        44127.000000
# mean           51.496711           -0.113106            0.064544
# std             0.077267            0.155863            0.042583
# min            51.298317           -0.498315            0.000000
# 25%            51.438303           -0.210633            0.029023
# 50%            51.498780           -0.101910            0.058904
# 75%            51.556343           -0.010854            0.094620
# max            51.683185            0.279726            0.201403
#
#        longitude_deviation
# count         44127.000000
# mean              0.123699
# std               0.095220
# min               0.000000
# 25%               0.043551
# 50%               0.098750
# 75%               0.191727
# max               0.393895

# %%
X_train, X_test, y_train, y_test, X_train_index, X_test_index, y_train_index, y_test_index, df_features, df_labels = create_train_test_data(
    df,
    categories=categories,
    RANDOM_STATE=RANDOM_STATE, return_index=True,
    drop_nulls=True)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_train_index.shape, X_test_index.shape,
      y_train_index.shape, y_test_index.shape)
# Out:
# (39714, 11) (4413, 11) (39714, 1) (4413, 1) (39714, 1) (4413, 1) (39714, 1) (4413, 1)

# %%
#imputer = SimpleImputer(strategy='mean')
#imputer.fit(X_train[6])
#X_train[6] = imputer.transform(X_train[6])

# %%
fitted_graph_model = starter_pipe[-1]
default_model_params = fitted_graph_model.get_params()
default_model_params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None,
#  'seed': 20}

# %%
import sklearn

sklearn.metrics.get_scorer_names()
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'matthews_corrcoef',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'top_k_accuracy',
#  'v_measure_score']

# %%
# %timeit starter_pipe.fit(X_train, y_train)
# Out:
# 5.32 s ± 2.34 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
'''
Unused:
    # 'base_score': None,
    # 'callbacks': None,
    # 'colsample_bylevel': None,
    # 'colsample_bynode': None,
    # 'colsample_bytree': None,
    # 'enable_categorical': False,
    # 'eval_metric': None,
    # 'gpu_id': None,
    # 'grow_policy': None,
    # 'importance_type': None,
    # 'interaction_constraints': None,
    # 'max_bin': None,
    # 'max_cat_to_onehot': None,
    # 'max_leaves': None,
    ###'missing': nan,
    # 'monotone_constraints': None,
    # 'num_parallel_tree': None,
    # 'predictor': None,
    # 'random_state': None,
    # 'reg_alpha': None,
    # 'reg_lambda': None,
    # 'sampling_method': None,
    # 'scale_pos_weight': None,
    # 'tree_method': None,
    #'tree_method': ['auto', 'approx', 'hist', 'gpu_hist', 'exact'],
    # 'validate_parameters': None,

'''
# Out:
# "\nUnused:\n    # 'base_score': None,\n    # 'callbacks': None,\n    # 'colsample_bylevel': None,\n    # 'colsample_bynode': None,\n    # 'colsample_bytree': None,\n    # 'enable_categorical': False,\n    # 'eval_metric': None,\n    # 'gpu_id': None,\n    # 'grow_policy': None,\n    # 'importance_type': None,\n    # 'interaction_constraints': None,\n    # 'max_bin': None,\n    # 'max_cat_to_onehot': None,\n    # 'max_leaves': None,\n    ###'missing': nan,\n    # 'monotone_constraints': None,\n    # 'num_parallel_tree': None,\n    # 'predictor': None,\n    # 'random_state': None,\n    # 'reg_alpha': None,\n    # 'reg_lambda': None,\n    # 'sampling_method': None,\n    # 'scale_pos_weight': None,\n    # 'tree_method': None,\n    #'tree_method': ['auto', 'approx', 'hist', 'gpu_hist', 'exact'],\n    # 'validate_parameters': None,\n\n"

# %%
options_block = {

    'booster': ['gbtree', 'gblinear', 'dart'],
    # gbtree and dart use tree based models while gblinear uses linear functions.

    'n_estimators': [75, 50, 125, 100, 150],  #100, 1000],
    'early_stopping_rounds': [None],

    ### For Tree Booster
    'tree_method': ['auto', 'approx', 'hist'],  # pseudo optimsied, #, 'exact'], #, 'gpu_hist'],
    'learning_rate': [None],  # pseudo optimised, also 0.3. Others: 0.01, 0.1, 0.2, 0.3, 0.4],
    'gamma': [None, 1, 10, 100, 1000, 10000, 100000],
    'max_depth': [6, 1, 3, 10, 30],
    'min_child_weight': [1, 0.1, 0.5, 2, 5],  # None,
    'max_delta_step': [0, 0.3, 0.1, 0.01, 0.9, 2.5],  # None,
    'subsample': [1, 0, 0.1, 0.5],  # None,

    'objective': ['reg:squarederror', 'reg:squaredlogerror'],

    'n_jobs': 3,
    #'verbosity': 3 if debug_mode else 2 if quick_mode else 1 #  Valid values are 0 (silent), 1 (warning), 2 (info), 3 (debug).
    'verbosity': 2
}
if use_gpu:
    options_block['tree_method'].append('gpuhist')
    options_block['n_estimators'].extend([250, 300, 500, 750, 1000])
    options_block['gamma'].extend([1000000, 10000000])
    options_block['learning_rate'].extend([0.3, 0.01, 0.1, 0.2, 0.3, 0.4])
    options_block['early_stopping_rounds'].extend([1, 5, 10, 100])

param_options, cv, n_jobs, refit, n_iter, verbose = get_cv_params(options_block, debug_mode=debug_mode,
                                                                  override_cv=OVERRIDE_CV,
                                                                  override_niter=OVERRIDE_N_ITER,
                                                                  override_njobs=OVERRIDE_JOBS)


print("cv:",cv, "n_jobs:",n_jobs, "refit:",refit, "n_iter:",n_iter, "verbose:", verbose)
param_options
# Out:
# cv: 2 n_jobs: 3 refit: True n_iter: 10 verbose: 1
# {'model__booster': ['gbtree', 'gblinear', 'dart'],
#  'model__n_estimators': [75, 50, 125, 100, 150],
#  'model__early_stopping_rounds': [None],
#  'model__tree_method': ['auto', 'approx', 'hist'],
#  'model__learning_rate': [None],
#  'model__gamma': [None, 1, 10, 100, 1000, 10000, 100000],
#  'model__max_depth': [6, 1, 3, 10, 30],
#  'model__min_child_weight': [1, 0.1, 0.5, 2, 5],
#  'model__max_delta_step': [0, 0.3, 0.1, 0.01, 0.9, 2.5],
#  'model__subsample': [1, 0, 0.1, 0.5],
#  'model__objective': ['reg:squarederror', 'reg:squaredlogerror'],
#  'model__n_jobs': [3],
#  'model__verbosity': [2]}

# %%
def fit_model_with_cross_validation(gs, X_train, y_train, fits):
    pipe_start = time()
    cv_result = gs.fit(X_train, y_train)
    gs.fit(X_train, y_train)
    pipe_end = time()
    average_time = round((pipe_end - pipe_start) / (fits), 2)

    print(f"Total fit/CV time      : {int(pipe_end - pipe_start)} seconds   ({pipe_start} ==> {pipe_end})")
    print()
    print(
        f'average fit/score time = {round(cv_result.cv_results_["mean_fit_time"].mean(), 2)}s/{round(cv_result.cv_results_["mean_score_time"].mean(), 2)}s')
    print(
        f'max fit/score time     = {round(cv_result.cv_results_["mean_fit_time"].max(), 2)}s/{round(cv_result.cv_results_["mean_score_time"].max(), 2)}s')
    print(f'refit time             = {round(cv_result.refit_time_, 2)}s')

    #return cv_result, average_time, cv_result.refit_time_, len(cv_result.cv_results_["mean_fit_time"])
    return average_time, cv_result.refit_time_, len(cv_result.cv_results_["mean_fit_time"])


crossval_runner = RandomizedSearchCV(
    estimator=starter_pipe,
    param_distributions=param_options,
    cv=cv, n_jobs=n_jobs,  # get the AVX/AVX2 info if use n_jobs > 2
    verbose=verbose, scoring=CROSS_VALIDATION_SCORING,
    refit=refit,
    return_train_score=True,  #n_iter=n_iter,
    n_iter=n_iter,  # 1, #3
    #error_score='raise'
)

cv_average_fit_time, cv_best_model_fit_time, total_fits = fit_model_with_cross_validation(
    crossval_runner, X_train, y_train, fits=cv * n_iter)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# [15:19:17] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bylevel", "colsample_bynode", "colsample_bytree", "grow_policy", "interaction_constraints", "max_bin", "max_cat_to_onehot", "max_delta_step", "max_depth", "max_leaves", "min_child_weight", "monotone_constraints", "num_parallel_tree", "predictor", "sampling_method", "subsample", "tree_method" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:19:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:21] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:21] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:21] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:21] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:22] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:22] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:22] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:22] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:22] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:26] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:26] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:26] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:17] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:17] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:17] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:17] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:17] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:18] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:19] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:20] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:20] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:20] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:21] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:21] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:22] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:23] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:26] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:16] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bylevel", "colsample_bynode", "colsample_bytree", "grow_policy", "interaction_constraints", "max_bin", "max_cat_to_onehot", "max_delta_step", "max_depth", "max_leaves", "min_child_weight", "monotone_constraints", "num_parallel_tree", "predictor", "sampling_method", "subsample", "tree_method" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:19:21] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bylevel", "colsample_bynode", "colsample_bytree", "gamma", "grow_policy", "interaction_constraints", "max_bin", "max_cat_to_onehot", "max_delta_step", "max_depth", "max_leaves", "min_child_weight", "monotone_constraints", "num_parallel_tree", "predictor", "sampling_method", "subsample", "tree_method" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:19:24] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bylevel", "colsample_bynode", "colsample_bytree", "gamma", "grow_policy", "interaction_constraints", "max_bin", "max_cat_to_onehot", "max_delta_step", "max_depth", "max_leaves", "min_child_weight", "monotone_constraints", "num_parallel_tree", "predictor", "sampling_method", "subsample", "tree_method" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:19:27] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:27] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:27] INFO: ../src/data/simple_dmatrix.cc:102: Generating new Gradient Index.
# [15:19:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:27] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:27] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:30] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:30] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:30] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:30] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:30] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:30] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:32] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:32] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:32] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:34] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:34] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:35] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:35] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:35] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:35] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:35] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:35] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:42] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:43] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:43] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:43] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:43] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:44] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:44] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:46] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:46] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:47] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:47] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:49] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:49] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:50] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:50] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:51] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:51] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:52] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:52] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:53] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:53] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:54] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:54] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:56] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:56] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:58] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:19:58] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:34] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:34] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:36] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:36] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:42] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:43] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:47] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:48] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:49] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:50] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:51] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:52] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:55] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:56] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:56] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:58] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:01] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:03] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:05] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:07] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:07] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:09] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:34] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:34] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:34] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:35] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:35] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:42] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:42] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:43] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:43] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:46] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:49] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:49] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:50] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:51] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:52] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:53] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:54] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:57] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:57] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:19:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:19:58] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:00] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:01] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:02] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:03] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:04] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:05] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [15:20:07] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:20:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# ...
# [15:24:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:24] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:24] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:25] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:26] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:26] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:27] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:27] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:29] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:29] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:31] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:31] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:32] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:32] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:36] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:36] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:36] INFO: ../src/data/simple_dmatrix.cc:102: Generating new Gradient Index.
# [15:24:36] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:36] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:36] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:36] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:36] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:36] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:36] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:38] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:38] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:38] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:38] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:42] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:42] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:25] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:25] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:26] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:26] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:27] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:27] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:28] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:28] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:30] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:30] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:30] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:30] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:32] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:32] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:32] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:33] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:33] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:35] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:35] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:35] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:35] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:36] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:36] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:37] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:37] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:39] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:39] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:40] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:40] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:41] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:41] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:43] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:43] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:44] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:44] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:45] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:45] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:46] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:46] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:49] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:49] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:50] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:50] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:50] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:50] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:51] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:51] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:54] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:54] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:57] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:57] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:24:58] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:24:58] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:00] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:00] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:00] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:00] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:01] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:01] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:04] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:04] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:07] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:07] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:07] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:07] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:13] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:13] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:13] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:13] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:13] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:13] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:13] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:13] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:14] INFO: ../src/gbm/gbtree.cc:177: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [15:25:14] INFO: ../src/gbm/gbtree.cc:909: drop 0 trees, weight = 1
# [15:25:15] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bylevel", "colsample_bynode", "colsample_bytree", "grow_policy", "interaction_constraints", "max_bin", "max_cat_to_onehot", "max_delta_step", "max_depth", "max_leaves", "min_child_weight", "monotone_constraints", "num_parallel_tree", "predictor", "sampling_method", "subsample", "tree_method" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# Total fit/CV time      : 362 seconds   (1668266354.7620888 ==> 1668266717.6209865)
#
# average fit/score time = 22.3s/0.73s
# max fit/score time     = 104.93s/3.74s
# refit time             = 2.02s

# %%
crossval_runner.best_params_
starter_pipe
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('model',
#                  XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               gamma=0, gpu_id=-1, grow_policy='depthwise',
#                               importance_type=None, interaction_constraints='',
#                               learning_rate=0.300000012, max_bin=256,
#                               max_cat_to_onehot=4, max_delta_step=0,
#                               max_depth=6, max_leaves=0, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#                               predictor='auto', random_state=20, reg_alpha=0,
#                               reg_lambda=1, ...))])

# %%
best_estimator_pipe = crossval_runner.best_estimator_

if debug_mode:
    crossval_runner.cv_results_

# %%
cv_results_df = pd.DataFrame(crossval_runner.cv_results_).sort_values('rank_test_score')
cv_results_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4       9.563889      0.064068         0.080158        0.010709
# 7      11.721403      0.903682         0.106223        0.038681
# 3       8.851931      0.110082         0.098034        0.038396
# 6       5.419552      0.460319         0.120802        0.002997
# 0      26.511200      4.831953         1.601299        0.583066
# 2      11.779231      0.046484         0.035917        0.004754
# 8      25.307124      2.413786         1.386774        0.673284
# 9       6.020151      0.735595         0.045161        0.001311
# 1      12.898227      2.316418         0.092756        0.010321
# 5     104.929697      5.556754         3.744337        3.127294
#
#   param_model__verbosity param_model__tree_method param_model__subsample  \
# 4                      2                   approx                    0.1
# 7                      2                   approx                    0.5
# 3                      2                     hist                    0.1
# 6                      2                     hist                    0.1
# 0                      2                   approx                      1
# 2                      2                     auto                    0.1
# 8                      2                     hist                    0.5
# 9                      2                   approx                      1
# 1                      2                     auto                      0
# 5                      2                     hist                      0
#
#   param_model__objective param_model__n_jobs param_model__n_estimators  ...  \
# 4       reg:squarederror                   3                       100  ...
# 7       reg:squarederror                   3                       150  ...
# 3    reg:squaredlogerror                   3                       125  ...
# 6    reg:squaredlogerror                   3                        75  ...
# 0    reg:squaredlogerror                   3                        50  ...
# 2    reg:squaredlogerror                   3                       125  ...
# 8       reg:squarederror                   3                        50  ...
# 9       reg:squarederror                   3                       100  ...
# 1       reg:squarederror                   3                       150  ...
# 5    reg:squaredlogerror                   3                       125  ...
#
#                                               params split0_test_score  \
# 4  {'model__verbosity': 2, 'model__tree_method': ...          0.326760
# 7  {'model__verbosity': 2, 'model__tree_method': ...          0.326760
# 3  {'model__verbosity': 2, 'model__tree_method': ...        -14.410698
# 6  {'model__verbosity': 2, 'model__tree_method': ...        -14.744874
# 0  {'model__verbosity': 2, 'model__tree_method': ...        -15.796531
# 2  {'model__verbosity': 2, 'model__tree_method': ...        -15.810958
# 8  {'model__verbosity': 2, 'model__tree_method': ...        -15.816658
# 9  {'model__verbosity': 2, 'model__tree_method': ...        -15.819225
# 1  {'model__verbosity': 2, 'model__tree_method': ...        -15.819448
# 5  {'model__verbosity': 2, 'model__tree_method': ...        -15.819448
#
#   split1_test_score mean_test_score std_test_score rank_test_score  \
# 4          0.331287        0.329024       0.002264               1
# 7          0.331287        0.329024       0.002264               2
# 3        -14.204058      -14.307378       0.103320               3
# 6        -14.533433      -14.639154       0.105720               4
# 0        -15.569971      -15.683251       0.113280               5
# 2        -15.584189      -15.697573       0.113385               6
# 8        -15.589808      -15.703233       0.113425               7
# 9        -15.592338      -15.705781       0.113443               8
# 1        -15.592558      -15.706003       0.113445               9
# 5        -15.592558      -15.706003       0.113445               9
#
#   split0_train_score split1_train_score  mean_train_score  std_train_score
# 4           0.334323           0.325108          0.329715         0.004607
# 7           0.334323           0.325108          0.329715         0.004607
# 3         -14.204127         -14.410628        -14.307377         0.103251
# 6         -14.533483         -14.744823        -14.639153         0.105670
# 0         -15.569972         -15.796530        -15.683251         0.113279
# 2         -15.584191         -15.810956        -15.697573         0.113383
# 8         -15.589808         -15.816658        -15.703233         0.113425
# 9         -15.592338         -15.819225        -15.705781         0.113443
# 1         -15.592558         -15.819448        -15.706003         0.113445
# 5         -15.592558         -15.819448        -15.706003         0.113445
#
# [10 rows x 27 columns]

# %%
cv_results_df['params2'] = cv_results_df['params'].apply(lambda l: '/'.join([str(c) for c in l.values()]))

cv_columns = ['params2', 'rank_test_score', 'mean_test_score', 'mean_fit_time', 'mean_score_time', 'params']
# if 'Neural' not in ALGORITHM:
#     cv_columns.insert(2, 'mean_train_score')
cv_results_df_full_sorted = cv_results_df.sort_values('rank_test_score')[cv_columns].reset_index(drop=True)
cv_results_df_full_sorted
# Out:
#                                              params2  rank_test_score  \
# 0  2/approx/0.1/reg:squarederror/3/100/1/30/0.01/...                1
# 1  2/approx/0.5/reg:squarederror/3/150/5/10/0/Non...                2
# 2  2/hist/0.1/reg:squaredlogerror/3/125/2/30/0/No...                3
# 3  2/hist/0.1/reg:squaredlogerror/3/75/1/1/0.01/N...                4
# 4  2/approx/1/reg:squaredlogerror/3/50/2/3/0/None...                5
# 5  2/auto/0.1/reg:squaredlogerror/3/125/2/3/0/Non...                6
# 6  2/hist/0.5/reg:squarederror/3/50/0.5/3/2.5/Non...                7
# 7  2/approx/1/reg:squarederror/3/100/0.5/3/0.1/No...                8
# 8  2/auto/0/reg:squarederror/3/150/0.1/6/0.9/None...                9
# 9  2/hist/0/reg:squaredlogerror/3/125/0.1/30/0.3/...                9
#
#    mean_test_score  mean_fit_time  mean_score_time  \
# 0         0.329024       9.563889         0.080158
# 1         0.329024      11.721403         0.106223
# 2       -14.307378       8.851931         0.098034
# 3       -14.639154       5.419552         0.120802
# 4       -15.683251      26.511200         1.601299
# 5       -15.697573      11.779231         0.035917
# 6       -15.703233      25.307124         1.386774
# 7       -15.705781       6.020151         0.045161
# 8       -15.706003      12.898227         0.092756
# 9       -15.706003     104.929697         3.744337
#
#                                               params
# 0  {'model__verbosity': 2, 'model__tree_method': ...
# 1  {'model__verbosity': 2, 'model__tree_method': ...
# 2  {'model__verbosity': 2, 'model__tree_method': ...
# 3  {'model__verbosity': 2, 'model__tree_method': ...
# 4  {'model__verbosity': 2, 'model__tree_method': ...
# 5  {'model__verbosity': 2, 'model__tree_method': ...
# 6  {'model__verbosity': 2, 'model__tree_method': ...
# 7  {'model__verbosity': 2, 'model__tree_method': ...
# 8  {'model__verbosity': 2, 'model__tree_method': ...
# 9  {'model__verbosity': 2, 'model__tree_method': ...

# %%
cv_results_df_sorted = cv_results_df_full_sorted[cv_results_df_full_sorted['mean_test_score'] > -2]
if len(cv_results_df_sorted) != len(cv_results_df_full_sorted):
    print(-len(cv_results_df_sorted) + len(cv_results_df_full_sorted), "fits were total failures")
    total_fits = len(cv_results_df_sorted)
cv_results_df_sorted
# Out:
# 8 fits were total failures
#                                              params2  rank_test_score  \
# 0  2/approx/0.1/reg:squarederror/3/100/1/30/0.01/...                1
# 1  2/approx/0.5/reg:squarederror/3/150/5/10/0/Non...                2
#
#    mean_test_score  mean_fit_time  mean_score_time  \
# 0         0.329024       9.563889         0.080158
# 1         0.329024      11.721403         0.106223
#
#                                               params
# 0  {'model__verbosity': 2, 'model__tree_method': ...
# 1  {'model__verbosity': 2, 'model__tree_method': ...

# %%
def print_results(cross_validation_result):
    means = cross_validation_result.cv_results_['mean_test_score']
    stds = cross_validation_result.cv_results_['std_test_score']
    params = cross_validation_result.cv_results_['params']
    times = cross_validation_result.cv_results_['std_test_score']

    print("params:" + "/".join([c.replace("model__", "") for c in params[0].keys()]))
    print()
    for mean, std, param, time in zip(means, stds, params, times):
        #param2 = "/".join(list(param.values()))
        param2 = "/".join(list([str(c) for c in param.values()]))
        print(f'{round(mean, 3)} (+/-{round(std * 2, 3)}) in {round(time, 4)}s for {param2}')


if debug_mode:
    print_results(crossval_runner)

# %%
print('Best Index: ', crossval_runner.best_index_)
print('Best Score: ', crossval_runner.best_score_)
print('Best Params: ', crossval_runner.best_params_)
# Out:
# Best Index:  4
# Best Score:  0.3290238586304803
# Best Params:  {'model__verbosity': 2, 'model__tree_method': 'approx', 'model__subsample': 0.1, 'model__objective': 'reg:squarederror', 'model__n_jobs': 3, 'model__n_estimators': 100, 'model__min_child_weight': 1, 'model__max_depth': 30, 'model__max_delta_step': 0.01, 'model__learning_rate': None, 'model__gamma': None, 'model__early_stopping_rounds': None, 'model__booster': 'gblinear'}

# %%
y_pred = best_estimator_pipe.predict(X_test)

# %%
y_pred = y_pred.reshape((-1, 1))

R2 = r2_score(y_test, y_pred)
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = math.sqrt(MSE)
print('-' * 10 + ALGORITHM + '-' * 10)
print('R square Accuracy', R2)
print('Mean Absolute Error Accuracy', MAE)
print('Mean Squared Error Accuracy', MSE)
print('Root Mean Squared Error', RMSE)
# Out:
# ----------XG Boost----------
# R square Accuracy 0.33491158839511526
# Mean Absolute Error Accuracy 71740.57205982324
# Mean Squared Error Accuracy 7513108476.510005
# Root Mean Squared Error 86678.18916261464

# %%
if debug_mode:
    print(y_test_index.reshape((-1, 1)).shape);
    print(y_pred.reshape((-1, 1)).shape);
    print(y_test.shape);
    print(y_test_index.shape);
    print(y_pred.shape);
    print(y_test.shape)

# %%
compare = np.hstack((y_test_index, y_test, y_pred))
compare_df = DataFrame(compare, columns=['reference', 'actual', 'predicted'])
compare_df['difference'] = abs(compare_df['actual'] - compare_df['predicted'])
compare_df['diff 1 %'] = abs((compare_df['actual'] - compare_df['predicted']) / compare_df['actual'] * 100)
compare_df['diff 2 %'] = abs((compare_df['actual'] - compare_df['predicted']) / compare_df['predicted']) * 100
compare_df['reference'] = compare_df['reference'].astype(int)
compare_df.set_index('reference', inplace=True)
compare_df
# Out:
#              actual     predicted    difference   diff 1 %   diff 2 %
# reference
# 85490754   400000.0  394681.40625    5318.59375   1.329648   1.347566
# 119328242  369950.0  388533.71875   18583.71875   5.023306   4.783039
# 125716790  350000.0  430616.87500   80616.87500  23.033393  18.721253
# 122440040  549000.0  426210.62500  122789.37500  22.366006  28.809553
# 120508103  495000.0  451103.93750   43896.06250   8.867891   9.730809
# ...             ...           ...           ...        ...        ...
# 68620869   475000.0  503345.75000   28345.75000   5.967526   5.631467
# 85735665   575000.0  570494.31250    4505.68750   0.783598   0.789787
# 125706338  400000.0  400797.50000     797.50000   0.199375   0.198978
# 112739354  450000.0  450911.90625     911.90625   0.202646   0.202236
# 122707001  275000.0  422102.96875  147102.96875  53.491989  34.850020
#
# [4413 rows x 5 columns]

# %%
combined = compare_df.merge(df[columns], how='inner', left_index=True, right_index=True).sort_values(['diff 1 %'],
                                                                                                     ascending=False)
#pd.options.display.float_format = '{:.4f}'.format
combined[['predicted', 'actual', 'Price', 'bedrooms', 'bathrooms']] = combined[
    ['predicted', 'actual', 'Price', 'bedrooms', 'bathrooms']].astype(int)
combined['bedrooms'] = combined['bedrooms'].astype(int)
combined
# Out:
#            actual  predicted    difference    diff 1 %   diff 2 %   Price  \
# 109722224  108000     370763  262763.46875  243.299508  70.870917  108000
# 85667184   122000     382404  260404.90625  213.446644  68.096644  122000
# 122265818  160000     500803  340803.87500  213.002422  68.051365  160000
# 122821142  170000     395524  225524.78125  132.661636  57.019128  170000
# 83639617   190000     433435  243435.84375  128.124128  56.164216  190000
# ...           ...        ...           ...         ...        ...     ...
# 85666800   425000     424838     161.78125    0.038066   0.038081  425000
# 125026085  395000     394851     148.90625    0.037698   0.037712  395000
# 118969124  475000     475161     161.87500    0.034079   0.034067  475000
# 110332301  450000     450056      56.12500    0.012472   0.012471  450000
# 121945712  400000     400014      14.68750    0.003672   0.003672  400000
#
#            bedrooms  bathrooms  nearestStation  location.latitude  \
# 109722224         1          1        0.302667          51.406803
# 85667184          1          1        0.838896          51.540462
# 122265818         3          1        0.166024          51.510420
# 122821142         2          1        0.093936          51.430690
# 83639617          2          2        0.162816          51.491264
# ...             ...        ...             ...                ...
# 85666800          2          1        0.140594          51.498770
# 125026085         1          1        0.381634          51.537204
# 118969124         3          1        0.601066          51.402050
# 110332301         3          1        0.856724          51.574046
# 121945712         1          1        0.322330          51.475891
#
#            location.longitude  latitude_deviation  longitude_deviation  \
# 109722224           -0.261328            0.092917             0.156908
# 85667184            -0.280301            0.040742             0.175881
# 122265818           -0.037730            0.010700             0.066690
# 122821142            0.024020            0.069030             0.128440
# 83639617             0.064660            0.008456             0.169080
# ...                       ...                 ...                  ...
# 85666800            -0.267623            0.000950             0.163203
# 125026085           -0.064744            0.037484             0.039676
# 118969124           -0.144240            0.097670             0.039820
# 110332301            0.146223            0.074326             0.250643
# 121945712           -0.132316            0.023829             0.027896
#
#           tenure.tenureType
# 109722224         LEASEHOLD
# 85667184          LEASEHOLD
# 122265818          FREEHOLD
# 122821142         LEASEHOLD
# 83639617          LEASEHOLD
# ...                     ...
# 85666800          LEASEHOLD
# 125026085         LEASEHOLD
# 118969124          FREEHOLD
# 110332301          FREEHOLD
# 121945712         LEASEHOLD
#
# [4413 rows x 14 columns]

# %%
score = best_estimator_pipe.score(X_test, y_test)
score
# Out:
# 0.33491158839511526

# %%
r2_score(y_test, y_pred)
# Out:
# 0.33491158839511526

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, best_estimator_pipe.predict(X_test), edgecolors=(0, 0, 1))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
ax.set_ylabel('Predicted')
ax.set_xlabel('Actual')
#ax.title.set_text(f'CV Chosen best option ({calculated_best_pipe[1]})')
plt.show()

# %%
def custom_model_and_predictions(model, graph_params, X_train, y_train, X_test):
    graph_model = model
    graph_model.set_params(**graph_params)
    graph_model.fit(X_train, y_train)
    y_pred_graph = model.predict(X_test)

    return model, y_pred_graph


best_model_count = 10 if not quick_mode else 2
best_model_count = 3 if not quick_mode else 1
best_models = {}
best_model_predictions = {}
best_model_scores = {}

showable_increment = total_fits // 4 if not quick_mode else 2
for i in range(0, total_fits, showable_increment):
    if debug_mode or True: print(f'{i} ==> {i}')

    if i == 0:
        fitted_graph_model = crossval_runner.best_estimator_
        y_pred_graph = y_pred
    else:
        graph_pipe_params = cv_results_df_sorted['params'][i]
        print(graph_pipe_params)
        # would always return the best! graph_pipe_params = cv_results_df_sorted.loc[cv_results_df_sorted['rank_test_score'] == 1, 'params'].values[0]

        graph_params = {}
        for key, value in graph_pipe_params.items():
            graph_params[key.replace('model__', '')] = value

        fitted_graph_model, y_pred_graph = custom_model_and_predictions(starter_pipe, graph_pipe_params, X_train,
                                                                        y_train, X_test)

    best_models[i] = fitted_graph_model[-1].get_params()
    best_model_predictions[i] = y_pred_graph
    best_model_scores[i] = fitted_graph_model.score(X_test, y_test)

if debug_mode or True: print(f'{-1} ==> {-1}')
graph_pipe_params = cv_results_df_sorted['params'][total_fits - 1]
print(graph_pipe_params)
graph_params = {}
for key, value in graph_pipe_params.items():
    graph_params[key.replace('model__', '')] = value
fitted_graph_model, y_pred_graph = custom_model_and_predictions(starter_pipe, graph_pipe_params, X_train,
                                                                y_train, X_test)
best_models[-1] = fitted_graph_model[-1].get_params()
best_model_predictions[-1] = y_pred_graph
best_model_scores[-1] = fitted_graph_model.score(X_test, y_test)
# Out:
# 0 ==> 0
# -1 ==> -1
# {'model__verbosity': 2, 'model__tree_method': 'approx', 'model__subsample': 0.5, 'model__objective': 'reg:squarederror', 'model__n_jobs': 3, 'model__n_estimators': 150, 'model__min_child_weight': 5, 'model__max_depth': 10, 'model__max_delta_step': 0, 'model__learning_rate': None, 'model__gamma': 10000, 'model__early_stopping_rounds': None, 'model__booster': 'gblinear'}
# [15:25:20] WARNING: ../src/learner.cc:627:
# Parameters: { "colsample_bylevel", "colsample_bynode", "colsample_bytree", "gamma", "grow_policy", "interaction_constraints", "max_bin", "max_cat_to_onehot", "max_delta_step", "max_depth", "max_leaves", "min_child_weight", "monotone_constraints", "num_parallel_tree", "predictor", "sampling_method", "subsample", "tree_method" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:25:20] WARNING: ../src/learner.cc:627:
# Parameters: { "gamma", "max_delta_step", "max_depth", "min_child_weight", "subsample", "tree_method" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
cv_results_df_sorted
# Out:
#                                              params2  rank_test_score  \
# 0  2/approx/0.1/reg:squarederror/3/100/1/30/0.01/...                1
# 1  2/approx/0.5/reg:squarederror/3/150/5/10/0/Non...                2
#
#    mean_test_score  mean_fit_time  mean_score_time  \
# 0         0.329024       9.563889         0.080158
# 1         0.329024      11.721403         0.106223
#
#                                               params
# 0  {'model__verbosity': 2, 'model__tree_method': ...
# 1  {'model__verbosity': 2, 'model__tree_method': ...

# %%
cv_results_df_sorted['params']
# Out:
# 0    {'model__verbosity': 2, 'model__tree_method': ...
# 1    {'model__verbosity': 2, 'model__tree_method': ...
# Name: params, dtype: object

# %%
total_fits
# Out:
# 2

# %%
best_models
# Out:
# {0: {'objective': 'reg:squarederror',
#   'base_score': 0.5,
#   'booster': 'gblinear',
#   'callbacks': None,
#   'colsample_bylevel': 1,
#   'colsample_bynode': 1,
#   'colsample_bytree': 1,
#   'early_stopping_rounds': None,
#   'enable_categorical': False,
#   'eval_metric': None,
#   'gamma': None,
#   'gpu_id': -1,
#   'grow_policy': 'depthwise',
#   'importance_type': None,
#   'interaction_constraints': '',
#   'learning_rate': 0.5,
#   'max_bin': 256,
#   'max_cat_to_onehot': 4,
#   'max_delta_step': 0.01,
#   'max_depth': 30,
#   'max_leaves': 0,
#   'min_child_weight': 1,
#   'missing': nan,
#   'monotone_constraints': '()',
#   'n_estimators': 100,
#   'n_jobs': 3,
#   'num_parallel_tree': 1,
#   'predictor': 'auto',
#   'random_state': 20,
#   'reg_alpha': 0,
#   'reg_lambda': 1,
#   'sampling_method': 'uniform',
#   'scale_pos_weight': 1,
#   'subsample': 0.1,
#   'tree_method': 'approx',
#   'validate_parameters': 1,
#   'verbosity': 2,
#   'seed': 20},
#  -1: {'objective': 'reg:squarederror',
#   'base_score': 0.5,
#   'booster': 'gblinear',
#   'callbacks': None,
#   'colsample_bylevel': None,
#   'colsample_bynode': None,
#   'colsample_bytree': None,
#   'early_stopping_rounds': None,
#   'enable_categorical': False,
#   'eval_metric': None,
#   'gamma': 10000,
#   'gpu_id': -1,
#   'grow_policy': None,
#   'importance_type': None,
#   'interaction_constraints': None,
#   'learning_rate': 0.5,
#   'max_bin': None,
#   'max_cat_to_onehot': None,
#   'max_delta_step': 0,
#   'max_depth': 10,
#   'max_leaves': None,
#   'min_child_weight': 5,
#   'missing': nan,
#   'monotone_constraints': None,
#   'n_estimators': 150,
#   'n_jobs': 3,
#   'num_parallel_tree': None,
#   'predictor': None,
#   'random_state': 20,
#   'reg_alpha': 0,
#   'reg_lambda': 0,
#   'sampling_method': None,
#   'scale_pos_weight': 1,
#   'subsample': 0.5,
#   'tree_method': 'approx',
#   'validate_parameters': 1,
#   'verbosity': 2,
#   'seed': 20}}

# %%
for i in best_model_scores.keys():
    if i >= 0:
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
        plt.scatter(y_test, best_model_predictions[i])
        # plt.title(str(i) + " " + str(round(best_model_scores[i], 4)) + " for " + str(best_models[i]))
        plt.title(str(i) + " " + str(round(best_model_scores[i], 4)) + " for entry " + str(i))
        plt.show()

plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
plt.scatter(y_test, best_model_predictions[-1])
# plt.title(str(i) + " " + str(round(best_model_scores[i], 4)) + " for " + str(best_models[i]))
plt.title(str(i) + " " + str(round(best_model_scores[-1], 4)) + " for (worst) entry " + str(i))
plt.show()

# %%
if True:
    sns.set_theme(font_scale=2, rc=None)
    sns.set_theme(font_scale=1, rc=None)

    fig, axes = plt.subplots(ncols=3, figsize=(15, 5))

    plt.subplots_adjust(hspace=0.2)
    plt.subplots_adjust(wspace=0.2)

    #.flatten()
    coordinates = axes[0]
    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[0], color='red')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[0].flatten(), ax=axes[0],
                    s=100).set(title=f'"BEST" model')

    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[1], color='red')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[-1].flatten(), ax=axes[1],
                    s=100).set(title=f'"WORST" model')

    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[2], color='red')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[-1].flatten(), ax=axes[2],
                    s=120, color='orange')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[0].flatten(), ax=axes[2],
                    s=30, alpha=0.6, color='black').set(
        title='best (black) vs worst (orange)')
    #title='best (orange) vs worst (black)')

    fig.tight_layout()
    plt.show()

# %%
cv_best_model_fit_time = cv_results_df_sorted.iloc[0]["mean_fit_time"]
#cv_best_model_fit_time = cv_results_df_sorted.iloc[0]["mean_fit_time"]
cv_best_model_fit_time
# Out:
# 9.563888907432556

# %%
cv_best_model_fit_time = cv_results_df_sorted.iloc[0]["mean_fit_time"]

DD2 = "(".join(DATA_DETAIL) + ")" if len(DATA_DETAIL) >= 1 else ""
key = f'{ALGORITHM} - {ALGORITHM_DETAIL}{DD2} (v{VERSION})'.lower()

results = {
    'Score': score,
    'R square Accuracy': R2,
    'Mean Absolute Error Accuracy': MAE,
    'Mean Squared Error Accuracy': MSE,
    'Root Mean Squared Error': RMSE,
    'Training Time': cv_best_model_fit_time,
    'random_state': RANDOM_STATE,
    'date': str(datetime.now()),
    'params': crossval_runner.best_params_
}

if run_env not in ['colab']:
    results_json = get_results()
    update_results(results_json, results, key)

print(key)
results
# Out:
# xg boost - random search (v06)
# {'Score': 0.33491158839511526,
#  'R square Accuracy': 0.33491158839511526,
#  'Mean Absolute Error Accuracy': 71740.57205982324,
#  'Mean Squared Error Accuracy': 7513108476.510005,
#  'Root Mean Squared Error': 86678.18916261464,
#  'Training Time': 9.563888907432556,
#  'random_state': 101,
#  'date': '2022-11-12 15:25:27.685666',
#  'params': {'model__verbosity': 2,
#   'model__tree_method': 'approx',
#   'model__subsample': 0.1,
#   'model__objective': 'reg:squarederror',
#   'model__n_jobs': 3,
#   'model__n_estimators': 100,
#   'model__min_child_weight': 1,
#   'model__max_depth': 30,
#   'model__max_delta_step': 0.01,
#   'model__learning_rate': None,
#   'model__gamma': None,
#   'model__early_stopping_rounds': None,
#   'model__booster': 'gblinear'},
#  'first run': '2022-11-06 22:13:02.393884',
#  'best params': 'MULTIPLE PARAM OPTIONS'}

# %%
crossval_runner.best_estimator_
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('model',
#                  XGBRegressor(base_score=0.5, booster='gblinear',
#                               callbacks=None, colsample_bylevel=1,
#                               colsample_bynode=1, colsample_bytree=1,
#                               early_stopping_rounds=None,
#                               enable_categorical=False, eval_metric=None,
#                               gamma=None, gpu_id=-1, grow_policy='depthwise',
#                               importance_type=None, interaction_constraints='',
#                               learning_rate=0.5, max_bin=256,
#                               max_cat_to_onehot=4, max_delta_step=0.01,
#                               max_depth=30, max_leaves=0, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=100, n_jobs=3, num_parallel_tree=1,
#                               predictor='auto', random_state=20, reg_alpha=0,
#                               reg_lambda=1, ...))])

# %%
with open(f'../../../models/optimised_model_{ALGORITHM}_v{VERSION}{DD2}.pkl', 'wb') as f:
    pickle.dump(crossval_runner.best_estimator_, f)

# %%
feature_importances = crossval_runner.best_estimator_[-1].feature_importances_
#std = np.std([tree.feature_importances_ for tree in model.estimators_], axis = 0)

indices = np.argsort(feature_importances)[::-1]

print('Feature Ranking:')

for f in range(X_train.shape[1]):
    print('%d. features %d (%f)' % (f + 1, indices[f], feature_importances[indices[f]]),
          df_features.columns[indices[f] + 1])
# Out:
# Feature Ranking:
# 1. features 0 (4.143878) bedrooms
# 2. features 8 (2.494557) tenure.tenureType_FREEHOLD
# 3. features 1 (2.255583) bathrooms
# 4. features 3 (0.883761) location.latitude
# 5. features 10 (0.459126) tenure.tenureType_SHARE_OF_FREEHOLD
# 6. features 7 (0.061748) tenure.tenureType_COMMONHOLD
# 7. features 2 (-0.923138) nearestStation
# 8. features 4 (-1.454802) location.longitude
# 9. features 5 (-2.150567) latitude_deviation
# 10. features 6 (-2.191638) longitude_deviation
# 11. features 9 (-2.578508) tenure.tenureType_LEASEHOLD

# %%
feature_importances = crossval_runner.best_estimator_[-1].feature_importances_
indices = np.argsort(feature_importances)

fig, ax = plt.subplots()
ax.barh(range(len(feature_importances)), feature_importances[indices])
ax.set_yticks(range(len(feature_importances)))
_ = ax.set_yticklabels(df_features.columns[[c + 1 for c in indices]])
