# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.neighbors import KNeighborsRegressor
from time import time

ALGORITHM = 'KNN'
ALGORITHM_DETAIL = 'random search'
VERSION = '10'

RANDOM_STATE = 101
TRAINING_SIZE = 0.9

CROSS_VALIDATION_SCORING = 'r2'

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler

pipe = Pipeline([
    #('mms', MinMaxScaler()),
    ('std_scaler', StandardScaler()),
    ('model', KNeighborsRegressor())
])

# %%
from sklearn.impute import SimpleImputer
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
import numpy as np
from pandas import DataFrame
import math
from termcolor import colored

confirm_colab = False

try:
    import google.colab

    IN_COLAB = True
except:
    IN_COLAB = confirm_colab

if not IN_COLAB:
    from functions_20221025C import set_csv_directory, get_combined_dataset, get_columns
    from functions_20221025C import add_supplements, tidy_dataset, feature_engineer, preprocess
    from functions_20221025C import update_results

    set_csv_directory('final_split')

debug_mode = False

# %%
#cutdown_rows = 1000
cutdown_rows = 0

LABEL = 'Price'

columns, booleans, floats, categories, custom, wildcard = get_columns(version=VERSION)

print(colored(f"features", "blue"), "-> ", columns)
columns.insert(0, LABEL)
print(colored(f"label", "green", None, ['bold']), "-> ", LABEL)
# Out:
# features ->  ['bedrooms', 'bathrooms', 'nearestStation', 'location.latitude', 'location.longitude', 'latitude_deviation', 'longitude_deviation', 'tenure.tenureType']
# label ->  Price

# %%
def get_source_dataframe(rows=cutdown_rows, folder_prefix='../../../'):
    retrieval_type = None

    filename = f'df_listings_v{VERSION}.csv'
    remote_pathname = f'https://raw.githubusercontent.com/jayportfolio/capstone_streamlit/main/data/final/{filename}'
    df_pathname_raw = folder_prefix + f'data/source/{filename}'
    df_pathname_tidy = folder_prefix + f'data/final/{filename}'

    if IN_COLAB:
        inDF = pd.read_csv(remote_pathname, on_bad_lines='error', index_col=0)
        retrieval_type = 'tidy'
        print('loaded data from', folder_prefix + remote_pathname)
    else:
        inDF = pd.read_csv(df_pathname_tidy, on_bad_lines='error', index_col=0)
        retrieval_type = 'tidy'
        print('loaded data from', df_pathname_tidy)

    if rows and rows > 0:
        inDF = inDF[:rows]
    return inDF, retrieval_type


def create_train_test_data(df_orig, return_index=False, drop_nulls=True):
    df = df_orig.copy()

    if drop_nulls:
        df.dropna(inplace=True)

    if return_index:
        df.reset_index(inplace=True)

    for column in categories:
        df = pd.concat([df, pd.get_dummies(df[column], prefix=column)], axis=1)
        df.drop([column], axis=1, inplace=True)  # now drop the original column (you don't need it anymore),

    ins = df.pop('index')
    df.insert(1, 'index2', ins)
    df.insert(0, 'index', ins)

    features = df[df.columns[2:]].values
    labels = df.iloc[:, 0:2].values

    if not return_index:
        return train_test_split(features, labels, train_size=0.9, random_state=RANDOM_STATE)
    else:
        X_train1, X_test1, y_train1, y_test1 = train_test_split(features, labels, train_size=0.9,
                                                                random_state=RANDOM_STATE)
        X_train_index = X_train1[:, 0].reshape(-1, 1)
        y_train_index = y_train1[:, 0].reshape(-1, 1)
        X_test_index = X_test1[:, 0].reshape(-1, 1)
        y_test_index = y_test1[:, 0].reshape(-1, 1)
        X_train1 = X_train1[:, 1:]
        y_train1 = y_train1[:, 1].reshape(-1, 1)
        X_test1 = X_test1[:, 1:]
        y_test1 = y_test1[:, 1].reshape(-1, 1)

        return X_train1, X_test1, y_train1, y_test1, X_train_index, X_test_index, y_train_index, y_test_index

# %%
df, retrieval_type = get_source_dataframe()
df_orig = df.copy()

if retrieval_type != 'tidy':
    df = tidy_dataset(df, version=int(VERSION))
    df = feature_engineer(df, version=int(VERSION))

    df = df[columns]

print(df.shape)
# Out:
# loaded data from ../../../data/final/df_listings_v10.csv
# (46871, 59)

# %%
df
# Out:
#               Price  bedrooms  bathrooms  nearestStation  location.latitude  \
# 14520525   550000.0       3.0        1.0        0.274316          51.529950
# 27953107   400000.0       2.0        2.0        0.305845          51.549390
# 33593487   579950.0       2.0        1.0        0.438045          51.447180
# 35271294   370000.0       2.0        1.0        0.399307          51.449568
# 35429088   599950.0       2.0        1.0        0.238187          51.577030
# ...             ...       ...        ...             ...                ...
# 126179018  575000.0       2.0        1.0        0.682879          51.370651
# 126179672  600000.0       3.0        2.0        0.545665          51.357170
# 126180107  419999.0       2.0        1.0        0.191407          51.531415
# 126180704  475000.0       2.0        1.0        0.308609          51.543141
# 126181118  525000.0       2.0        1.0        0.238489          51.424589
#
#            location.longitude  latitude_deviation  longitude_deviation  \
# 14520525            -0.207020            0.030230             0.102600
# 27953107            -0.482600            0.049670             0.378180
# 33593487            -0.338770            0.052540             0.234350
# 35271294            -0.140154            0.050152             0.035734
# 35429088            -0.141230            0.077310             0.036810
# ...                       ...                 ...                  ...
# 126179018           -0.238346            0.129069             0.133926
# 126179672           -0.074740            0.142550             0.029680
# 126180107           -0.052964            0.031695             0.051456
# 126180704            0.011498            0.043421             0.115918
# 126181118           -0.206790            0.075131             0.102370
#
#            tenure.tenureType  feature__1 bedroom  ...  \
# 14520525           LEASEHOLD                   0  ...
# 27953107           LEASEHOLD                   0  ...
# 33593487            FREEHOLD                   0  ...
# 35271294           LEASEHOLD                   0  ...
# 35429088                 NaN                   0  ...
# ...                      ...                 ...  ...
# 126179018           FREEHOLD                   0  ...
# 126179672          LEASEHOLD                   0  ...
# 126180107          LEASEHOLD                   0  ...
# 126180704          LEASEHOLD                   0  ...
# 126181118  SHARE_OF_FREEHOLD                   0  ...
#
#            feature__reception room  feature__separate kitchen  \
# 14520525                         0                          1
# 27953107                         0                          0
# 33593487                         0                          0
# 35271294                         0                          0
# 35429088                         0                          0
# ...                            ...                        ...
# 126179018                        0                          0
# 126179672                        0                          0
# 126180107                        0                          0
# 126180704                        0                          0
# 126181118                        1                          0
#
#            feature__share of freehold  feature__three bedrooms  \
# 14520525                            0                        0
# 27953107                            0                        0
# 33593487                            0                        0
# 35271294                            0                        0
# 35429088                            0                        0
# ...                               ...                      ...
# 126179018                           0                        0
# 126179672                           0                        0
# 126180107                           0                        0
# 126180704                           0                        0
# 126181118                           0                        0
#
#            feature__three double bedrooms  feature__top floor  \
# 14520525                                0                   0
# 27953107                                0                   1
# 33593487                                0                   0
# 35271294                                0                   0
# 35429088                                0                   0
# ...                                   ...                 ...
# 126179018                               0                   0
# 126179672                               0                   0
# 126180107                               0                   0
# 126180704                               0                   0
# 126181118                               0                   0
#
#            feature__two bathrooms  feature__two bedrooms  \
# 14520525                        0                      0
# 27953107                        0                      0
# 33593487                        0                      0
# 35271294                        0                      0
# 35429088                        0                      0
# ...                           ...                    ...
# 126179018                       0                      0
# 126179672                       0                      0
# 126180107                       0                      0
# 126180704                       0                      0
# 126181118                       0                      0
#
#            feature__two double bedrooms  feature__two reception rooms
# 14520525                              0                             0
# 27953107                              1                             0
# 33593487                              0                             0
# 35271294                              0                             0
# 35429088                              0                             0
# ...                                 ...                           ...
# 126179018                             0                             0
# 126179672                             0                             0
# 126180107                             0                             0
# 126180704                             0                             0
# 126181118                             0                             0
#
# [46871 rows x 59 columns]

# %%
df.isnull().sum()
# Out:
# Price                                    0
# bedrooms                                 0
# bathrooms                                0
# nearestStation                           0
# location.latitude                        0
# location.longitude                       0
# latitude_deviation                       0
# longitude_deviation                      0
# tenure.tenureType                     2744
# feature__1 bedroom                       0
# feature__2 bedrooms                      0
# feature__2 double bedrooms               0
# feature__allocated parking               0
# feature__allocated parking space         0
# feature__balcony                         0
# feature__bathroom                        0
# feature__chain free                      0
# feature__close to local amenities        0
# feature__communal garden                 0
# feature__communal gardens                0
# feature__double bedroom                  0
# feature__double glazed                   0
# feature__double glazing                  0
# feature__epc rating c                    0
# feature__epc rating d                    0
# feature__excellent location              0
# feature__excellent transport links       0
# feature__family bathroom                 0
# feature__first floor                     0
# feature__fitted kitchen                  0
# feature__garage                          0
# feature__garden                          0
# feature__gas central heating             0
# feature__great location                  0
# feature__ground floor                    0
# feature__kitchen                         0
# feature__leasehold                       0
# feature__long lease                      0
# feature__modern bathroom                 0
# feature__modern kitchen                  0
# feature__no chain                        0
# feature__no onward chain                 0
# feature__off street parking              0
# feature__one bedroom                     0
# feature__one double bedroom              0
# feature__parking                         0
# feature__private balcony                 0
# feature__private garden                  0
# feature__private rear garden             0
# feature__reception room                  0
# feature__separate kitchen                0
# feature__share of freehold               0
# feature__three bedrooms                  0
# feature__three double bedrooms           0
# feature__top floor                       0
# feature__two bathrooms                   0
# feature__two bedrooms                    0
# feature__two double bedrooms             0
# feature__two reception rooms             0
# dtype: int64

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46871 entries, 14520525 to 126181118
# Data columns (total 59 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Price                               46871 non-null  float64
#  1   bedrooms                            46871 non-null  float64
#  2   bathrooms                           46871 non-null  float64
#  3   nearestStation                      46871 non-null  float64
#  4   location.latitude                   46871 non-null  float64
#  5   location.longitude                  46871 non-null  float64
#  6   latitude_deviation                  46871 non-null  float64
#  7   longitude_deviation                 46871 non-null  float64
#  8   tenure.tenureType                   44127 non-null  object
#  9   feature__1 bedroom                  46871 non-null  int64
#  10  feature__2 bedrooms                 46871 non-null  int64
#  11  feature__2 double bedrooms          46871 non-null  int64
#  12  feature__allocated parking          46871 non-null  int64
#  13  feature__allocated parking space    46871 non-null  int64
#  14  feature__balcony                    46871 non-null  int64
#  15  feature__bathroom                   46871 non-null  int64
#  16  feature__chain free                 46871 non-null  int64
#  17  feature__close to local amenities   46871 non-null  int64
#  18  feature__communal garden            46871 non-null  int64
#  19  feature__communal gardens           46871 non-null  int64
#  20  feature__double bedroom             46871 non-null  int64
#  21  feature__double glazed              46871 non-null  int64
#  22  feature__double glazing             46871 non-null  int64
#  23  feature__epc rating c               46871 non-null  int64
#  24  feature__epc rating d               46871 non-null  int64
#  25  feature__excellent location         46871 non-null  int64
#  26  feature__excellent transport links  46871 non-null  int64
#  27  feature__family bathroom            46871 non-null  int64
#  28  feature__first floor                46871 non-null  int64
#  29  feature__fitted kitchen             46871 non-null  int64
#  30  feature__garage                     46871 non-null  int64
#  31  feature__garden                     46871 non-null  int64
#  32  feature__gas central heating        46871 non-null  int64
#  33  feature__great location             46871 non-null  int64
#  34  feature__ground floor               46871 non-null  int64
#  35  feature__kitchen                    46871 non-null  int64
#  36  feature__leasehold                  46871 non-null  int64
#  37  feature__long lease                 46871 non-null  int64
#  38  feature__modern bathroom            46871 non-null  int64
#  39  feature__modern kitchen             46871 non-null  int64
#  40  feature__no chain                   46871 non-null  int64
#  41  feature__no onward chain            46871 non-null  int64
#  42  feature__off street parking         46871 non-null  int64
#  43  feature__one bedroom                46871 non-null  int64
#  44  feature__one double bedroom         46871 non-null  int64
#  45  feature__parking                    46871 non-null  int64
#  46  feature__private balcony            46871 non-null  int64
#  47  feature__private garden             46871 non-null  int64
#  48  feature__private rear garden        46871 non-null  int64
#  49  feature__reception room             46871 non-null  int64
#  50  feature__separate kitchen           46871 non-null  int64
#  51  feature__share of freehold          46871 non-null  int64
#  52  feature__three bedrooms             46871 non-null  int64
#  53  feature__three double bedrooms      46871 non-null  int64
#  54  feature__top floor                  46871 non-null  int64
#  55  feature__two bathrooms              46871 non-null  int64
#  56  feature__two bedrooms               46871 non-null  int64
#  57  feature__two double bedrooms        46871 non-null  int64
#  58  feature__two reception rooms        46871 non-null  int64
# dtypes: float64(8), int64(50), object(1)
# memory usage: 21.5+ MB
#                Price      bedrooms     bathrooms  nearestStation  \
# count   46871.000000  46871.000000  46871.000000    46871.000000
# mean   425069.390775      1.992469      1.182074        0.438847
# std    107227.324906      0.828837      0.409879        0.325942
# min    100000.000000      1.000000      1.000000        0.000000
# 25%    349950.000000      1.000000      1.000000        0.227169
# 50%    425000.000000      2.000000      1.000000        0.367971
# 75%    515000.000000      3.000000      1.000000        0.559620
# max    600000.000000      7.000000      5.000000        7.197700
#
#        location.latitude  location.longitude  latitude_deviation  \
# count       46871.000000        46871.000000        46871.000000
# mean           51.497049           -0.113269            0.064317
# std             0.077085            0.156489            0.042573
# min            51.298317           -0.498315            0.000000
# 25%            51.438861           -0.210796            0.028876
# 50%            51.499977           -0.102230            0.058595
# 75%            51.556183           -0.010343            0.094362
# max            51.683185            0.279726            0.201403
#
#        longitude_deviation  feature__1 bedroom  feature__2 bedrooms  ...  \
# count         46871.000000        46871.000000         46871.000000  ...
# mean              0.124202            0.010838             0.015169  ...
# std               0.095607            0.103542             0.122402  ...
# min               0.000000            0.000000             0.000000  ...
# 25%               0.043560            0.000000             0.000000  ...
# 50%               0.098984            0.000000             0.000000  ...
# 75%               0.192684            0.000000             0.000000  ...
# max               0.393895            1.000000             2.000000  ...
#
#        feature__reception room  feature__separate kitchen  \
# count             46871.000000               46871.000000
# mean                  0.014487                   0.020268
# std                   0.119843                   0.140918
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.000000
# 50%                   0.000000                   0.000000
# 75%                   0.000000                   0.000000
# max                   2.000000                   1.000000
#
#        feature__share of freehold  feature__three bedrooms  \
# count                46871.000000             46871.000000
# mean                     0.047663                 0.059120
# std                      0.213354                 0.235851
# min                      0.000000                 0.000000
# 25%                      0.000000                 0.000000
# 50%                      0.000000                 0.000000
# 75%                      0.000000                 0.000000
# max                      2.000000                 1.000000
#
#        feature__three double bedrooms  feature__top floor  \
# count                    46871.000000        46871.000000
# mean                         0.012545            0.013206
# std                          0.111301            0.114159
# min                          0.000000            0.000000
# 25%                          0.000000            0.000000
# 50%                          0.000000            0.000000
# 75%                          0.000000            0.000000
# max                          1.000000            1.000000
#
#        feature__two bathrooms  feature__two bedrooms  \
# count            46871.000000           46871.000000
# mean                 0.031512               0.071473
# std                  0.174943               0.257616
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  0.000000               0.000000
# max                  2.000000               1.000000
#
#        feature__two double bedrooms  feature__two reception rooms
# count                  46871.000000                  46871.000000
# mean                       0.095411                      0.016449
# std                        0.293930                      0.127197
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        2.000000                      1.000000
#
# [8 rows x 58 columns]

# %%
old_length = len(df)

df = preprocess(df, version=int(VERSION))

print(f"dataframe contract due to cleaning: {old_length} ==> {len(df)}")
old_length = len(df)

df.describe().T
# Out:
# dataframe contract due to cleaning: 46871 ==> 46871
#                                       count           mean            std  \
# Price                               46871.0  425069.390775  107227.324906
# bedrooms                            46871.0       1.992469       0.828837
# bathrooms                           46871.0       1.182074       0.409879
# nearestStation                      46871.0       0.438847       0.325942
# location.latitude                   46871.0      51.497049       0.077085
# location.longitude                  46871.0      -0.113269       0.156489
# latitude_deviation                  46871.0       0.064317       0.042573
# longitude_deviation                 46871.0       0.124202       0.095607
# feature__1 bedroom                  46871.0       0.010838       0.103542
# feature__2 bedrooms                 46871.0       0.015169       0.122402
# feature__2 double bedrooms          46871.0       0.013569       0.115695
# feature__allocated parking          46871.0       0.026946       0.161928
# feature__allocated parking space    46871.0       0.012993       0.113246
# feature__balcony                    46871.0       0.038617       0.193124
# feature__bathroom                   46871.0       0.026370       0.160502
# feature__chain free                 46871.0       0.120266       0.325800
# feature__close to local amenities   46871.0       0.011948       0.108848
# feature__communal garden            46871.0       0.018071       0.133209
# feature__communal gardens           46871.0       0.030381       0.171760
# feature__double bedroom             46871.0       0.012566       0.111395
# feature__double glazed              46871.0       0.012822       0.112509
# feature__double glazing             46871.0       0.025496       0.157761
# feature__epc rating c               46871.0       0.012140       0.109511
# feature__epc rating d               46871.0       0.013334       0.114704
# feature__excellent location         46871.0       0.013612       0.115874
# feature__excellent transport links  46871.0       0.016385       0.127122
# feature__family bathroom            46871.0       0.014593       0.120097
# feature__first floor                46871.0       0.026520       0.160676
# feature__fitted kitchen             46871.0       0.027224       0.162867
# feature__garage                     46871.0       0.030424       0.172001
# feature__garden                     46871.0       0.021015       0.144178
# feature__gas central heating        46871.0       0.028120       0.165961
# feature__great location             46871.0       0.015660       0.124158
# feature__ground floor               46871.0       0.028760       0.167132
# feature__kitchen                    46871.0       0.022850       0.149427
# feature__leasehold                  46871.0       0.014316       0.118970
# feature__long lease                 46871.0       0.039619       0.195175
# feature__modern bathroom            46871.0       0.015361       0.122986
# feature__modern kitchen             46871.0       0.014465       0.119400
# feature__no chain                   46871.0       0.026669       0.161380
# feature__no onward chain            46871.0       0.057925       0.233604
# feature__off street parking         46871.0       0.047300       0.212684
# feature__one bedroom                46871.0       0.041369       0.199144
# feature__one double bedroom         46871.0       0.027885       0.164645
# feature__parking                    46871.0       0.013398       0.115160
# feature__private balcony            46871.0       0.039662       0.195275
# feature__private garden             46871.0       0.034200       0.181980
# feature__private rear garden        46871.0       0.017367       0.131124
# feature__reception room             46871.0       0.014487       0.119843
# feature__separate kitchen           46871.0       0.020268       0.140918
# feature__share of freehold          46871.0       0.047663       0.213354
# feature__three bedrooms             46871.0       0.059120       0.235851
# feature__three double bedrooms      46871.0       0.012545       0.111301
# feature__top floor                  46871.0       0.013206       0.114159
# feature__two bathrooms              46871.0       0.031512       0.174943
# feature__two bedrooms               46871.0       0.071473       0.257616
# feature__two double bedrooms        46871.0       0.095411       0.293930
# feature__two reception rooms        46871.0       0.016449       0.127197
#
#                                               min            25%  \
# Price                               100000.000000  349950.000000
# bedrooms                                 1.000000       1.000000
# bathrooms                                1.000000       1.000000
# nearestStation                           0.000000       0.227169
# location.latitude                       51.298317      51.438861
# location.longitude                      -0.498315      -0.210796
# latitude_deviation                       0.000000       0.028876
# longitude_deviation                      0.000000       0.043560
# feature__1 bedroom                       0.000000       0.000000
# feature__2 bedrooms                      0.000000       0.000000
# feature__2 double bedrooms               0.000000       0.000000
# feature__allocated parking               0.000000       0.000000
# feature__allocated parking space         0.000000       0.000000
# feature__balcony                         0.000000       0.000000
# feature__bathroom                        0.000000       0.000000
# feature__chain free                      0.000000       0.000000
# feature__close to local amenities        0.000000       0.000000
# feature__communal garden                 0.000000       0.000000
# feature__communal gardens                0.000000       0.000000
# feature__double bedroom                  0.000000       0.000000
# feature__double glazed                   0.000000       0.000000
# feature__double glazing                  0.000000       0.000000
# feature__epc rating c                    0.000000       0.000000
# feature__epc rating d                    0.000000       0.000000
# feature__excellent location              0.000000       0.000000
# feature__excellent transport links       0.000000       0.000000
# feature__family bathroom                 0.000000       0.000000
# feature__first floor                     0.000000       0.000000
# feature__fitted kitchen                  0.000000       0.000000
# feature__garage                          0.000000       0.000000
# feature__garden                          0.000000       0.000000
# feature__gas central heating             0.000000       0.000000
# feature__great location                  0.000000       0.000000
# feature__ground floor                    0.000000       0.000000
# feature__kitchen                         0.000000       0.000000
# feature__leasehold                       0.000000       0.000000
# feature__long lease                      0.000000       0.000000
# feature__modern bathroom                 0.000000       0.000000
# feature__modern kitchen                  0.000000       0.000000
# feature__no chain                        0.000000       0.000000
# feature__no onward chain                 0.000000       0.000000
# feature__off street parking              0.000000       0.000000
# feature__one bedroom                     0.000000       0.000000
# feature__one double bedroom              0.000000       0.000000
# feature__parking                         0.000000       0.000000
# feature__private balcony                 0.000000       0.000000
# feature__private garden                  0.000000       0.000000
# feature__private rear garden             0.000000       0.000000
# feature__reception room                  0.000000       0.000000
# feature__separate kitchen                0.000000       0.000000
# feature__share of freehold               0.000000       0.000000
# feature__three bedrooms                  0.000000       0.000000
# feature__three double bedrooms           0.000000       0.000000
# feature__top floor                       0.000000       0.000000
# feature__two bathrooms                   0.000000       0.000000
# feature__two bedrooms                    0.000000       0.000000
# feature__two double bedrooms             0.000000       0.000000
# feature__two reception rooms             0.000000       0.000000
#
#                                               50%            75%  \
# Price                               425000.000000  515000.000000
# bedrooms                                 2.000000       3.000000
# bathrooms                                1.000000       1.000000
# nearestStation                           0.367971       0.559620
# location.latitude                       51.499977      51.556183
# location.longitude                      -0.102230      -0.010343
# latitude_deviation                       0.058595       0.094362
# longitude_deviation                      0.098984       0.192684
# feature__1 bedroom                       0.000000       0.000000
# feature__2 bedrooms                      0.000000       0.000000
# feature__2 double bedrooms               0.000000       0.000000
# feature__allocated parking               0.000000       0.000000
# feature__allocated parking space         0.000000       0.000000
# feature__balcony                         0.000000       0.000000
# feature__bathroom                        0.000000       0.000000
# feature__chain free                      0.000000       0.000000
# feature__close to local amenities        0.000000       0.000000
# feature__communal garden                 0.000000       0.000000
# feature__communal gardens                0.000000       0.000000
# feature__double bedroom                  0.000000       0.000000
# feature__double glazed                   0.000000       0.000000
# feature__double glazing                  0.000000       0.000000
# feature__epc rating c                    0.000000       0.000000
# feature__epc rating d                    0.000000       0.000000
# feature__excellent location              0.000000       0.000000
# feature__excellent transport links       0.000000       0.000000
# feature__family bathroom                 0.000000       0.000000
# feature__first floor                     0.000000       0.000000
# feature__fitted kitchen                  0.000000       0.000000
# feature__garage                          0.000000       0.000000
# feature__garden                          0.000000       0.000000
# feature__gas central heating             0.000000       0.000000
# feature__great location                  0.000000       0.000000
# feature__ground floor                    0.000000       0.000000
# feature__kitchen                         0.000000       0.000000
# feature__leasehold                       0.000000       0.000000
# feature__long lease                      0.000000       0.000000
# feature__modern bathroom                 0.000000       0.000000
# feature__modern kitchen                  0.000000       0.000000
# feature__no chain                        0.000000       0.000000
# feature__no onward chain                 0.000000       0.000000
# feature__off street parking              0.000000       0.000000
# feature__one bedroom                     0.000000       0.000000
# feature__one double bedroom              0.000000       0.000000
# feature__parking                         0.000000       0.000000
# feature__private balcony                 0.000000       0.000000
# feature__private garden                  0.000000       0.000000
# feature__private rear garden             0.000000       0.000000
# feature__reception room                  0.000000       0.000000
# feature__separate kitchen                0.000000       0.000000
# feature__share of freehold               0.000000       0.000000
# feature__three bedrooms                  0.000000       0.000000
# feature__three double bedrooms           0.000000       0.000000
# feature__top floor                       0.000000       0.000000
# feature__two bathrooms                   0.000000       0.000000
# feature__two bedrooms                    0.000000       0.000000
# feature__two double bedrooms             0.000000       0.000000
# feature__two reception rooms             0.000000       0.000000
#
#                                               max
# Price                               600000.000000
# bedrooms                                 7.000000
# bathrooms                                5.000000
# nearestStation                           7.197700
# location.latitude                       51.683185
# location.longitude                       0.279726
# latitude_deviation                       0.201403
# longitude_deviation                      0.393895
# feature__1 bedroom                       1.000000
# feature__2 bedrooms                      2.000000
# feature__2 double bedrooms               1.000000
# feature__allocated parking               1.000000
# feature__allocated parking space         1.000000
# feature__balcony                         2.000000
# feature__bathroom                        2.000000
# feature__chain free                      2.000000
# feature__close to local amenities        2.000000
# feature__communal garden                 1.000000
# feature__communal gardens                2.000000
# feature__double bedroom                  1.000000
# feature__double glazed                   1.000000
# feature__double glazing                  2.000000
# feature__epc rating c                    1.000000
# feature__epc rating d                    1.000000
# feature__excellent location              1.000000
# feature__excellent transport links       2.000000
# feature__family bathroom                 2.000000
# feature__first floor                     1.000000
# feature__fitted kitchen                  2.000000
# feature__garage                          2.000000
# feature__garden                          2.000000
# feature__gas central heating             2.000000
# feature__great location                  1.000000
# feature__ground floor                    1.000000
# feature__kitchen                         1.000000
# feature__leasehold                       2.000000
# feature__long lease                      2.000000
# feature__modern bathroom                 1.000000
# feature__modern kitchen                  1.000000
# feature__no chain                        2.000000
# feature__no onward chain                 1.000000
# feature__off street parking              2.000000
# feature__one bedroom                     1.000000
# feature__one double bedroom              1.000000
# feature__parking                         2.000000
# feature__private balcony                 2.000000
# feature__private garden                  2.000000
# feature__private rear garden             2.000000
# feature__reception room                  2.000000
# feature__separate kitchen                1.000000
# feature__share of freehold               2.000000
# feature__three bedrooms                  1.000000
# feature__three double bedrooms           1.000000
# feature__top floor                       1.000000
# feature__two bathrooms                   2.000000
# feature__two bedrooms                    1.000000
# feature__two double bedrooms             2.000000
# feature__two reception rooms             1.000000

# %%
df.isna().sum()
# Out:
# Price                                    0
# bedrooms                                 0
# bathrooms                                0
# nearestStation                           0
# location.latitude                        0
# location.longitude                       0
# latitude_deviation                       0
# longitude_deviation                      0
# tenure.tenureType                     2744
# feature__1 bedroom                       0
# feature__2 bedrooms                      0
# feature__2 double bedrooms               0
# feature__allocated parking               0
# feature__allocated parking space         0
# feature__balcony                         0
# feature__bathroom                        0
# feature__chain free                      0
# feature__close to local amenities        0
# feature__communal garden                 0
# feature__communal gardens                0
# feature__double bedroom                  0
# feature__double glazed                   0
# feature__double glazing                  0
# feature__epc rating c                    0
# feature__epc rating d                    0
# feature__excellent location              0
# feature__excellent transport links       0
# feature__family bathroom                 0
# feature__first floor                     0
# feature__fitted kitchen                  0
# feature__garage                          0
# feature__garden                          0
# feature__gas central heating             0
# feature__great location                  0
# feature__ground floor                    0
# feature__kitchen                         0
# feature__leasehold                       0
# feature__long lease                      0
# feature__modern bathroom                 0
# feature__modern kitchen                  0
# feature__no chain                        0
# feature__no onward chain                 0
# feature__off street parking              0
# feature__one bedroom                     0
# feature__one double bedroom              0
# feature__parking                         0
# feature__private balcony                 0
# feature__private garden                  0
# feature__private rear garden             0
# feature__reception room                  0
# feature__separate kitchen                0
# feature__share of freehold               0
# feature__three bedrooms                  0
# feature__three double bedrooms           0
# feature__top floor                       0
# feature__two bathrooms                   0
# feature__two bedrooms                    0
# feature__two double bedrooms             0
# feature__two reception rooms             0
# dtype: int64

# %%
df = df.dropna()
print(f"{old_length} ==> {len(df)}")
old_length = len(df)
df.describe()
# Out:
# 46871 ==> 44127
#                Price      bedrooms    bathrooms  nearestStation  \
# count   44127.000000  44127.000000  44127.00000    44127.000000
# mean   425224.642373      1.990981      1.18134        0.438522
# std    107203.332660      0.827621      0.40893        0.324152
# min    100000.000000      1.000000      1.00000        0.000000
# 25%    349950.000000      1.000000      1.00000        0.227551
# 50%    425000.000000      2.000000      1.00000        0.368351
# 75%    515000.000000      3.000000      1.00000        0.559486
# max    600000.000000      7.000000      5.00000        7.197700
#
#        location.latitude  location.longitude  latitude_deviation  \
# count       44127.000000        44127.000000        44127.000000
# mean           51.496711           -0.113106            0.064544
# std             0.077267            0.155863            0.042583
# min            51.298317           -0.498315            0.000000
# 25%            51.438303           -0.210633            0.029023
# 50%            51.498780           -0.101910            0.058904
# 75%            51.556343           -0.010854            0.094620
# max            51.683185            0.279726            0.201403
#
#        longitude_deviation  feature__1 bedroom  feature__2 bedrooms  ...  \
# count         44127.000000        44127.000000         44127.000000  ...
# mean              0.123699            0.011127             0.015251  ...
# std               0.095220            0.104897             0.122737  ...
# min               0.000000            0.000000             0.000000  ...
# 25%               0.043551            0.000000             0.000000  ...
# 50%               0.098750            0.000000             0.000000  ...
# 75%               0.191727            0.000000             0.000000  ...
# max               0.393895            1.000000             2.000000  ...
#
#        feature__reception room  feature__separate kitchen  \
# count             44127.000000               44127.000000
# mean                  0.014254                   0.020509
# std                   0.118921                   0.141735
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.000000
# 50%                   0.000000                   0.000000
# 75%                   0.000000                   0.000000
# max                   2.000000                   1.000000
#
#        feature__share of freehold  feature__three bedrooms  \
# count                44127.000000             44127.000000
# mean                     0.048428                 0.059374
# std                      0.214989                 0.236326
# min                      0.000000                 0.000000
# 25%                      0.000000                 0.000000
# 50%                      0.000000                 0.000000
# 75%                      0.000000                 0.000000
# max                      2.000000                 1.000000
#
#        feature__three double bedrooms  feature__top floor  \
# count                    44127.000000        44127.000000
# mean                         0.012804            0.013212
# std                          0.112429            0.114182
# min                          0.000000            0.000000
# 25%                          0.000000            0.000000
# 50%                          0.000000            0.000000
# 75%                          0.000000            0.000000
# max                          1.000000            1.000000
#
#        feature__two bathrooms  feature__two bedrooms  \
# count            44127.000000           44127.000000
# mean                 0.031976               0.072586
# std                  0.176195               0.259459
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  0.000000               0.000000
# max                  2.000000               1.000000
#
#        feature__two double bedrooms  feature__two reception rooms
# count                  44127.000000                  44127.000000
# mean                       0.096857                      0.016022
# std                        0.295919                      0.125561
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        2.000000                      1.000000
#
# [8 rows x 58 columns]

# %%
X_train, X_test, y_train, y_test, X_train_index, X_test_index, y_train_index, y_test_index = create_train_test_data(df,
                                                                                                                    return_index=True,
                                                                                                                    drop_nulls=True)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_train_index.shape, X_test_index.shape,
      y_train_index.shape, y_test_index.shape)
#print(type(X_train))
#X_train[0]
# Out:
# (39714, 61) (4413, 61) (39714, 1) (4413, 1) (39714, 1) (4413, 1) (39714, 1) (4413, 1)

# %%
#imputer = SimpleImputer(strategy='mean')
#imputer.fit(X_train[6])
#X_train[6] = imputer.transform(X_train[6])

# %%
options_block = {
    #'objective': 'reg:squarederror',
    #'max_depth': [1, 3, 6, 10, 30],
    #'n_estimators': 100,
    #'tree_method': ['auto', 'approx', 'hist', 'exact'],
    'algorithm' : ['auto','ball_tree','kd_tree','brute'],
    'leaf_size' : [3.30,300,3000],
    'metric' : ['minkowski','precomputed'],
    #'metric_params' : 'abc',
    'n_jobs' : [-1,1,2],
    'n_neighbors' : [3,4,5,7,9,13,21,35],
    'p' : [1,2],
    'weights' : ['uniform','distance']
    #'verbosity': 1
}

 #['algorithm', 'leaf_size', 'metric', 'metric_params', 'n_jobs', 'n_neighbors', 'p', 'weights'].
param_grid = {}
for each in options_block:
    if type(options_block[each]) == list:
        param_grid['model__' + each] = options_block[each]
    elif options_block[each] == None:
        #print (f'skipping {each} because value is {options_block[each]}')
        param_grid['model__' + each] = [options_block[each]]
    else:
        param_grid['model__' + each] = [options_block[each]]
#param_grid

cv = 3
n_jobs = 1
verbose = 1
refit = True

#grid = RandomizedSearchCV(estimator=model, param_grid=param_grid, scoring='r2', verbose=1, n_jobs=-1)

# temp override
cv = 2

gs = RandomizedSearchCV(pipe, param_grid, cv=cv, n_jobs=n_jobs,
                        verbose=verbose, scoring=CROSS_VALIDATION_SCORING, refit=refit,
                        return_train_score=True, n_iter=30),
gs

grid_result = gs[0].fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 30 candidates, totalling 60 fits
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 26 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_regression.py", line 210, in fit
#     return self._fit(X, y)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 498, in _fit
#     X = _check_precomputed(X)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 191, in _check_precomputed
#     check_non_negative(X, whom="precomputed distance matrix.")
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/utils/validation.py", line 1372, in check_non_negative
#     raise ValueError("Negative values in data passed to %s" % whom)
# ValueError: Negative values in data passed to precomputed distance matrix.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_regression.py", line 210, in fit
#     return self._fit(X, y)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 446, in _fit
#     self._check_algorithm_metric()
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 381, in _check_algorithm_metric
#     raise ValueError(
# ValueError: Metric 'precomputed' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['kd_tree']) to get valid options. Metric can also be a callable function.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_regression.py", line 210, in fit
#     return self._fit(X, y)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 446, in _fit
#     self._check_algorithm_metric()
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/neighbors/_base.py", line 381, in _check_algorithm_metric
#     raise ValueError(
# ValueError: Metric 'precomputed' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['ball_tree']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.43735083 0.49314037 0.411771          nan        nan        nan
#  0.50153492        nan        nan 0.42540837 0.35377555 0.46140239
#  0.50298343        nan 0.41809223 0.41807365        nan        nan
#         nan 0.45514543 0.45084352        nan 0.47383217 0.45461351
#  0.45084699        nan 0.41807059        nan        nan 0.41178072]
#   warnings.warn(
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the train scores are non-finite: [0.66616823 0.99938656 0.70906848        nan        nan        nan
#  0.99938656        nan        nan 0.99938043 0.68302275 0.49263162
#  0.99938656        nan 0.99938636 0.99938636        nan        nan
#         nan 0.99938407 0.99938656        nan 0.99938636 0.99938656
#  0.99938656        nan 0.99938636        nan        nan 0.70906198]
#   warnings.warn(

# %%
pipe = grid_result.best_estimator_
timings = []

t0 = time()
pipe.fit(X_train, y_train)
timings.append(time() - t0)

print(timings)
average_time = sum(timings) / len(timings)
print(average_time)
# Out:
# [0.04976773262023926]
# 0.04976773262023926

# %%
def print_results(results):
    print(f'BEST PARAMS: {results.best_params_}')

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean, 3)} (+/-{round(std * 2, 3)}) for {params}')


print_results(grid_result)
print('Best Index: ', grid_result.best_index_)
print('Best Score: ', grid_result.best_score_)
print('Best Params: ', grid_result.best_params_)
#print('Best Model: ', grid_result.)
#print('Best Params: ', grid_result.best_params_)[out]
### Best Score:  0.4883436188936269
### Best Params:  {'alpha': 0.01}
# Out:
# BEST PARAMS: {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 35, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'auto'}
# 0.437 (+/-0.006) for {'model__weights': 'uniform', 'model__p': 1, 'model__n_neighbors': 4, 'model__n_jobs': 1, 'model__metric': 'minkowski', 'model__leaf_size': 3000, 'model__algorithm': 'kd_tree'}
# 0.493 (+/-0.0) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 7, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3.3, 'model__algorithm': 'brute'}
# 0.412 (+/-0.005) for {'model__weights': 'uniform', 'model__p': 1, 'model__n_neighbors': 3, 'model__n_jobs': 2, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'ball_tree'}
# nan (+/-nan) for {'model__weights': 'uniform', 'model__p': 2, 'model__n_neighbors': 21, 'model__n_jobs': -1, 'model__metric': 'precomputed', 'model__leaf_size': 3.3, 'model__algorithm': 'auto'}
# nan (+/-nan) for {'model__weights': 'uniform', 'model__p': 1, 'model__n_neighbors': 5, 'model__n_jobs': 2, 'model__metric': 'precomputed', 'model__leaf_size': 3000, 'model__algorithm': 'auto'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 21, 'model__n_jobs': -1, 'model__metric': 'precomputed', 'model__leaf_size': 3000, 'model__algorithm': 'kd_tree'}
# 0.502 (+/-0.001) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 9, 'model__n_jobs': 2, 'model__metric': 'minkowski', 'model__leaf_size': 3.3, 'model__algorithm': 'ball_tree'}
# nan (+/-nan) for {'model__weights': 'uniform', 'model__p': 2, 'model__n_neighbors': 35, 'model__n_jobs': 1, 'model__metric': 'precomputed', 'model__leaf_size': 3.3, 'model__algorithm': 'kd_tree'}
# nan (+/-nan) for {'model__weights': 'uniform', 'model__p': 2, 'model__n_neighbors': 9, 'model__n_jobs': 2, 'model__metric': 'precomputed', 'model__leaf_size': 300, 'model__algorithm': 'ball_tree'}
# 0.425 (+/-0.002) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 3, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3000, 'model__algorithm': 'ball_tree'}
# 0.354 (+/-0.005) for {'model__weights': 'uniform', 'model__p': 2, 'model__n_neighbors': 3, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3000, 'model__algorithm': 'auto'}
# 0.461 (+/-0.001) for {'model__weights': 'uniform', 'model__p': 1, 'model__n_neighbors': 35, 'model__n_jobs': 1, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'brute'}
# 0.503 (+/-0.002) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 35, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'auto'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 3, 'model__n_jobs': 1, 'model__metric': 'precomputed', 'model__leaf_size': 3000, 'model__algorithm': 'kd_tree'}
# 0.418 (+/-0.002) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 5, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3000, 'model__algorithm': 'kd_tree'}
# 0.418 (+/-0.002) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 5, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3.3, 'model__algorithm': 'auto'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 5, 'model__n_jobs': 1, 'model__metric': 'precomputed', 'model__leaf_size': 3.3, 'model__algorithm': 'ball_tree'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 5, 'model__n_jobs': 1, 'model__metric': 'precomputed', 'model__leaf_size': 3000, 'model__algorithm': 'auto'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 13, 'model__n_jobs': 2, 'model__metric': 'precomputed', 'model__leaf_size': 3.3, 'model__algorithm': 'ball_tree'}
# 0.455 (+/-0.003) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 4, 'model__n_jobs': 2, 'model__metric': 'minkowski', 'model__leaf_size': 3000, 'model__algorithm': 'kd_tree'}
# 0.451 (+/-0.004) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 21, 'model__n_jobs': 1, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'auto'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 3, 'model__n_jobs': 2, 'model__metric': 'precomputed', 'model__leaf_size': 3.3, 'model__algorithm': 'kd_tree'}
# 0.474 (+/-0.002) for {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 5, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3000, 'model__algorithm': 'brute'}
# 0.455 (+/-0.002) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 13, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'ball_tree'}
# 0.451 (+/-0.004) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 21, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'ball_tree'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 7, 'model__n_jobs': 1, 'model__metric': 'precomputed', 'model__leaf_size': 3000, 'model__algorithm': 'brute'}
# 0.418 (+/-0.002) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 5, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3.3, 'model__algorithm': 'ball_tree'}
# nan (+/-nan) for {'model__weights': 'uniform', 'model__p': 2, 'model__n_neighbors': 21, 'model__n_jobs': 2, 'model__metric': 'precomputed', 'model__leaf_size': 3.3, 'model__algorithm': 'auto'}
# nan (+/-nan) for {'model__weights': 'distance', 'model__p': 2, 'model__n_neighbors': 3, 'model__n_jobs': -1, 'model__metric': 'precomputed', 'model__leaf_size': 3000, 'model__algorithm': 'brute'}
# 0.412 (+/-0.005) for {'model__weights': 'uniform', 'model__p': 1, 'model__n_neighbors': 3, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 3000, 'model__algorithm': 'kd_tree'}
# Best Index:  12
# Best Score:  0.5029834280643952
# Best Params:  {'model__weights': 'distance', 'model__p': 1, 'model__n_neighbors': 35, 'model__n_jobs': -1, 'model__metric': 'minkowski', 'model__leaf_size': 300, 'model__algorithm': 'auto'}

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

y_pred = y_pred.reshape((-1, 1))

R2 = r2_score(y_test, y_pred)
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = math.sqrt(MSE)
print('-' * 10 + ALGORITHM + '-' * 10)
print('R square Accuracy', R2)
print('Mean Absolute Error Accuracy', MAE)
print('Mean Squared Error Accuracy', MSE)
print('Root Mean Squared Error', RMSE)
# Out:
# ----------KNN----------
# R square Accuracy 0.533822783000381
# Mean Absolute Error Accuracy 57566.899870473564
# Mean Squared Error Accuracy 5266126938.137675
# Root Mean Squared Error 72568.08484545858

# %%
if debug_mode:
    print(y_test_index.reshape((-1, 1)).shape);
    print(y_pred.reshape((-1, 1)).shape);
    print(y_test.shape);
    print(y_test_index.shape);
    print(y_pred.shape);
    print(y_test.shape)

# %%
compare = np.hstack((y_test_index, y_test, y_pred))
compare_df = DataFrame(compare, columns=['reference', 'actual', 'predicted'])
compare_df['difference'] = abs(compare_df['actual'] - compare_df['predicted'])
compare_df['diff 1 %'] = abs((compare_df['actual'] - compare_df['predicted']) / compare_df['actual'] * 100)
compare_df['diff 2 %'] = abs((compare_df['actual'] - compare_df['predicted']) / compare_df['predicted']) * 100
compare_df['reference'] = compare_df['reference'].astype(str)
compare_df.set_index('reference', inplace=True)
compare_df
# Out:
#                actual      predicted    difference   diff 1 %   diff 2 %
# reference
# 85490754.0   400000.0  375000.000000  25000.000000   6.250000   6.666667
# 119328242.0  369950.0  390218.186603  20268.186603   5.478629   5.194065
# 125716790.0  350000.0  343881.174518   6118.825482   1.748236   1.779343
# 122440040.0  549000.0  528435.684936  20564.315064   3.745777   3.891545
# 120508103.0  495000.0  494961.105148     38.894852   0.007858   0.007858
# ...               ...            ...           ...        ...        ...
# 68620869.0   475000.0  537649.488469  62649.488469  13.189366  11.652478
# 85735665.0   575000.0  546326.760181  28673.239819   4.986650   5.248368
# 125706338.0  400000.0  407107.573835   7107.573835   1.776893   1.745871
# 112739354.0  450000.0  516107.280252  66107.280252  14.690507  12.808825
# 122707001.0  275000.0  275000.000000      0.000000   0.000000   0.000000
#
# [4413 rows x 5 columns]

# %%
compare_df.merge(df[columns], how='inner', left_index=True, right_index=True).sort_values(['diff 1 %'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [actual, predicted, difference, diff 1 %, diff 2 %, Price, bedrooms, bathrooms, nearestStation, location.latitude, location.longitude, latitude_deviation, longitude_deviation, tenure.tenureType]
# Index: []

# %%
score = pipe.score(X_test, y_test)
score
# Out:
# 0.533822783000381

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.533822783000381

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(y_test, pipe.predict(X_test), edgecolors=(0, 0, 1))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
ax.set_ylabel('Predicted')
ax.set_xlabel('Actual')
#ax.title.set_text(f'CV Chosen best option ({calculated_best_pipe[1]})')
plt.show()

# %%
if False:
    def score_summary(self, sort_by='mean_score'):
        def row(key, scores, params):
            d = {
                'estimator': key,
                'min_score': min(scores),
                'max_score': max(scores),
                'mean_score': np.mean(scores),
                'std_score': np.std(scores),
            }
            #return pd.Series({**params, **d})
            return pd.Series({**params, **d, **{'params_full': str(params)}})

        rows = []
        for k in self.grid_searches:
            print(k)
            params = self.grid_searches[k].cv_results_['params']
            scores = []
            for i in range(self.grid_searches[k].cv):
                key = "split{}_test_score".format(i)
                r = self.grid_searches[k].cv_results_[key]
                scores.append(r.reshape(len(params), 1))

            all_scores = np.hstack(scores)
            for p, s in zip(params, all_scores):
                rows.append((row(k, s, p)))

        df = pd.concat(rows, axis=1).T.sort_values([sort_by], ascending=False)

        columns = ['estimator', 'min_score', 'mean_score', 'max_score', 'std_score']
        columns = columns + [c for c in df.columns if c not in columns]

        return df[columns]


    import seaborn as sns

    score_summary = score_summary(self=gs, sort_by='max_score')

# %%
if False:
    #sns.set(rc={"figure.figsize": (10, 10)})
    sns.set_theme(font_scale=2, rc=None)
    sns.set_theme(font_scale=1, rc=None)

    #total_graphs = len(score_summary)
    # max_horizontal = 4
    # index2 = 0
    # resultant_rows = math.ceil(total_graphs / max_horizontal)
    # #subplots_adjust()
    #
    # #fig, axes = plt.subplots(nrows=resultant_rows, ncols=max_horizontal)
    fig, axes = plt.subplots(ncols=3, figsize=(15, 5))

    plt.subplots_adjust(hspace=0.2)
    plt.subplots_adjust(wspace=0.2)

    best_estimator = score_summary.iloc[0]
    worst_estimator = score_summary.iloc[-1]

    name_best = best_estimator["estimator"]
    params_str = best_estimator["params_full"]
    params_best = ast.literal_eval(params_str)

    name_worst = worst_estimator["estimator"]
    params_str = worst_estimator["params_full"]
    params_worst = ast.literal_eval(params_str)

    KNeighborsRegressor().set_params()

    best_pipe = make_pipe(name_best)
    worst_pipe = make_pipe(name_worst)

    coordinates = axes[0]
    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[0], color='red')
    sns.scatterplot(x=y_test, y=best_pipe.set_params(**params_best).fit(X_train, y_train).predict(X_test), ax=axes[0],
                    s=100).set(
        title=f'"BEST" model: {name_best} \n{params_best}')

    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[1], color='red')
    sns.scatterplot(x=y_test, y=worst_pipe.set_params(**params_worst).fit(X_train, y_train).predict(X_test), ax=axes[1],
                    s=100).set(
        title=f'"WORST" model: {name_worst} \n{params_worst}')

    sns.scatterplot(x=y_test, y=worst_pipe.set_params(**params_worst).fit(X_train, y_train).predict(X_test), ax=axes[2],
                    s=100, color='orange')
    sns.scatterplot(x=y_test, y=best_pipe.set_params(**params_best).fit(X_train, y_train).predict(X_test), ax=axes[2],
                    s=100, alpha=0.6, color='black').set(
        title='best (black) vs worst (orange)')

    fig.tight_layout()
    plt.show()

if False:
    max_horizontal = 3

    #sns.set()
    #sns.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)
    sns.set(rc={"figure.figsize": (20, 20)})
    sns.set_theme(font_scale=2, rc=None)
    sns.set_theme(font_scale=1, rc=None)

    total_graphs = len(score_summary)
    index2 = 0
    resultant_rows = math.ceil(total_graphs / max_horizontal)
    #subplots_adjust()

    #fig, axes = plt.subplots(nrows=resultant_rows, ncols=max_horizontal)
    fig, axes = plt.subplots(nrows=2, ncols=max_horizontal, figsize=(15, 10))

    plt.subplots_adjust(hspace=0.2)
    plt.subplots_adjust(wspace=0.2)

    for (key, next_estimator), index in zip(score_summary.iterrows(), range(total_graphs)):
        if index % (max_horizontal * 2) == 0 and index != 0:
            index2 = 0
            fig.tight_layout()
            plt.show()
            #fig, axes = plt.subplots(nrows=resultant_rows, ncols=max_horizontal)
            fig, axes = plt.subplots(nrows=2, ncols=max_horizontal, figsize=(15, 10))

        name_next = next_estimator["estimator"]
        params_str = next_estimator["params_full"]
        params_next = ast.literal_eval(params_str)
        #print("next", params_next)

        if 'noscale' in name_next:
            pipe = Pipeline(steps=[
                ('preprocessor', features_noscale_preprocessor),  # preprocess features
                ('estimator', models_and_params[name_next]["model"]),
            ])  # start the training
        else:
            pipe = Pipeline(steps=[
                ('preprocessor', features_preprocessor),
                ('estimator', models_and_params[name_next]["model"]),  # preprocess features
            ])  # start the training

        # 0 ==> 0,0
        # 1 ==> 0,1
        # 2 ==> 1,0
        x_coor = index2 // max_horizontal
        y_coor = index2 % max_horizontal

        coordinates = axes[x_coor][y_coor]
        #sns.lineplot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], hue='red', lw=3)
        sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=coordinates, color='red')
        sns.scatterplot(x=y_test, y=pipe.set_params(**params_next).fit(X_train, y_train).predict(X_test),
                        ax=coordinates, s=100).set(
            title=f'({index}) {"BEST" if index == 0 else "next"} model: {name_next} \n{params_next}')
        #if index == 11: break
        index2 += 1

    fig.tight_layout()
    plt.show()

# %%
from datetime import datetime

results = {
    'Score': score,
    'R square Accuracy': R2,
    'Mean Absolute Error Accuracy': MAE,
    'Mean Squared Error Accuracy': MSE,
    'Root Mean Squared Error': RMSE,
    'Training Time': average_time,
    'random_state': RANDOM_STATE,
    'date': str(datetime.now()),
    'params': grid_result.best_params_
}
import json

if not IN_COLAB:

    results_filename = '../../../results/results.json'

    with open(results_filename) as f:
        raw_audit = f.read()

    results_json = json.loads(raw_audit)

    key = f'{ALGORITHM} - {ALGORITHM_DETAIL} (v{VERSION})'.lower()
    updated_results_json = update_results(key, results_json, results)

    with open(results_filename, 'w') as file:
        file.write(json.dumps(updated_results_json, indent=4, sort_keys=True))

results
# Out:
# {'Score': 0.533822783000381,
#  'R square Accuracy': 0.533822783000381,
#  'Mean Absolute Error Accuracy': 57566.899870473564,
#  'Mean Squared Error Accuracy': 5266126938.137675,
#  'Root Mean Squared Error': 72568.08484545858,
#  'Training Time': 0.04976773262023926,
#  'random_state': 101,
#  'date': '2022-10-25 23:09:05.395933',
#  'params': {'model__weights': 'distance',
#   'model__p': 1,
#   'model__n_neighbors': 35,
#   'model__n_jobs': -1,
#   'model__metric': 'minkowski',
#   'model__leaf_size': 300,
#   'model__algorithm': 'auto'},
#  'first run': '2022-10-25 23:09:05.397959',
#  'best params': {'model__weights': 'distance',
#   'model__p': 1,
#   'model__n_neighbors': 35,
#   'model__n_jobs': -1,
#   'model__metric': 'minkowski',
#   'model__leaf_size': 300,
#   'model__algorithm': 'auto'},
#  'best score': 0.533822783000381,
#  'best time': 0.04976773262023926,
#  'suboptimal': 'pending'}

# %%
import pickle

with open(f'../../../models/optimised_model_{ALGORITHM}_v{VERSION}.pkl', 'wb') as f:
    pickle.dump(grid_result.best_estimator_, f)
