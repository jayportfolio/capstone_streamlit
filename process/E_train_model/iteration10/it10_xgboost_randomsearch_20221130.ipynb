# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage: Decide which algorithm and version of the data we are going to use for model training
#
# Additionally, choose:
# * if we'll skip scaling the data
# * if we'll use full categories instead of dummies
# * what fraction of the data we'll use for testing (0.1)
# * if the data split will be randomised (it won't!)

# %%
ALGORITHM = 'Linear Regression (Ridge)'
#ALGORITHM = 'KNN'
#ALGORITHM = 'Decision Tree'
#ALGORITHM = 'Random Forest'
#ALGORITHM = 'XG Boost (tree)'
#ALGORITHM = 'CatBoost'
#ALGORITHM = 'Light Gradient Boosting'

ALGORITHM_DETAIL = 'random search'
DATA_DETAIL = []
#DATA_DETAIL = ['linear']
#DATA_DETAIL = ['explore param']
#DATA_DETAIL = ['no scale','no dummies']
#DATA_DETAIL = ['no dummies']
#VERSION = '06'
VERSION = '10'

RANDOM_STATE = 101
TRAINING_SIZE = 0.9

CROSS_VALIDATION_SCORING = 'r2'

print(f'ALGORITHM: {ALGORITHM}')
print(f'ALGORITHM_DETAIL: {ALGORITHM_DETAIL}')
print(f'DATA_DETAIL: {DATA_DETAIL}')
print(f'DATA VERSION: {VERSION}')
# Out:
# ALGORITHM: Linear Regression (Ridge)
# ALGORITHM_DETAIL: random search
# DATA_DETAIL: []
# DATA VERSION: 10

# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage: loading all dependencies

# %%
#%pip install catboost
#%pip install lightgbm

# %%
from sklearn.impute import SimpleImputer
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
import numpy as np
from pandas import DataFrame
import math
from termcolor import colored
from time import time
import sklearn
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
import seaborn as sns
import pickle

import json
from datetime import datetime
import matplotlib.pyplot as plt

with open('../../z_envs/_envs.json') as f:
    env_vars = json.loads(f.read())
print(env_vars)

try:
    import google.colab

    run_env = 'colab'
except:
    try:
        run_env = env_vars['notebook_environment']
    except:
        run_env = 'unknown'

use_gpu = env_vars.get('use_gpu', False)
debug_mode = env_vars.get('debug_mode', False)
quick_mode = env_vars.get('quick_mode', False)
OVERRIDE_CV = env_vars.get('quick_override_cv_splits', None) if quick_mode else None
OVERRIDE_N_ITER = env_vars.get('quick_override_n_iter', None) if quick_mode else None
OVERRIDE_JOBS = env_vars.get('quick_override_n_jobs', None) if quick_mode else None
#if quick_mode:OVERRIDE_CV, OVERRIDE_N_ITER = 2, 10

already_timed = False
no_dummies = 'no dummies' in DATA_DETAIL
no_scaling = 'no scaling' in DATA_DETAIL
not_catboost = 'catboost' not in ALGORITHM.lower() or not no_dummies

if run_env not in ['colab', 'gradient', 'cloud']:
    cloud_run = False
    from functions_b__get_the_data_20221116 import set_csv_directory
    set_csv_directory('final_split')
else:
    cloud_run = True
    import sys
    import os

    module_path = os.path.abspath(os.path.join('..', '..', '..'))
    if module_path not in sys.path:
        #sys.path.append(module_path+"\\zfunctions")
        sys.path.append(module_path)

from functions_0__common_20221116 import get_columns
from functions_b__get_the_data_20221116 import get_combined_dataset
from functions_d1__prepare_cleanse_data_20221116 import tidy_dataset
from functions_d2__transform_enrich_data_20221116 import preprocess, feature_engineer
from functions_d3__prepare_store_data_20221116 import create_train_test_data
from functions_e__train_model_20221116 import get_chosen_model, make_modelling_pipeline, get_cv_params, fit_model_with_cross_validation, get_hyperparameters
from functions_f_evaluate_model_20221116 import get_best_estimator_average_time, get_results, update_results
# Out:
# {'notebook_environment': 'local', 'use_gpu': False, 'debug_mode': False, 'quick_mode': False, 'quick_override_cv_splits': 2, 'quick_override_n_iter': 10, 'quick_override_n_jobs': 3}

# %%
if 'forest' in ALGORITHM.lower():
    OVERRIDE_N_ITER = 5
    if use_gpu:
        OVERRIDE_JOBS = 8
else:
    OVERRIDE_N_ITER = 25

if run_env == 'local' or True:
    if ALGORITHM.lower() in ['random forest','xg boost','xg boost (linear)','xg boost (tree)' ]:
        OVERRIDE_N_ITER = 1
    elif 'linear regression' in ALGORITHM.lower():
        OVERRIDE_N_ITER = 15
    else:
        OVERRIDE_N_ITER = 5

# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage: defining the model pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler


def make_pipeline():
    return Pipeline([
        #('mms', MinMaxScaler()),
        ('std_scaler', StandardScaler()),
        ('model', get_chosen_model(ALGORITHM))
    ])


starter_pipe = make_pipeline()
starter_pipe
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()), ('model', Ridge())])

# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage: get the data

# %%
#cutdown_rows = 1000
cutdown_rows = 0

LABEL = 'Price'

columns, booleans, floats, categories, custom, wildcard = get_columns(version=VERSION)

print(colored(f"features", "blue"), "-> ", columns)
columns.insert(0, LABEL)
print(colored(f"label", "green", None, ['bold']), "-> ", LABEL)
# Out:
# features ->  ['bedrooms', 'bathrooms', 'nearestStation', 'location.latitude', 'location.longitude', 'latitude_deviation', 'longitude_deviation', 'tenure.tenureType']
# label ->  Price

# %%
def get_source_dataframe(rows=cutdown_rows, folder_prefix='../../../'):
    retrieval_type = None

    filename = f'df_listings_v{VERSION}.csv'
    remote_pathname = f'https://raw.githubusercontent.com/jayportfolio/capstone_streamlit/main/data/final/{filename}'
    df_pathname_raw = folder_prefix + f'data/source/{filename}'
    df_pathname_tidy = folder_prefix + f'data/final/{filename}'

    if cloud_run:
        inDF = pd.read_csv(remote_pathname, on_bad_lines='error', index_col=0)
        print('loaded data from', folder_prefix + remote_pathname)
    else:
        inDF = pd.read_csv(df_pathname_tidy, on_bad_lines='error', index_col=0)
        retrieval_type = 'tidy'
        print('loaded data from', df_pathname_tidy)

    if rows and rows > 0:
        inDF = inDF[:rows]
    return inDF, retrieval_type

# %%
df, retrieval_type = get_source_dataframe(folder_prefix='../../../')
df_orig = df.copy()

if retrieval_type != 'tidy':
    df = tidy_dataset(df, version=int(VERSION))
    df = feature_engineer(df, version=int(VERSION))

    df = df[columns]

print(df.shape)
# Out:
# loaded data from ../../../data/final/df_listings_v10.csv
# (46871, 59)

# %%
df.head(30)
# Out:
#              Price  bedrooms  bathrooms  nearestStation  location.latitude  \
# 14520525  550000.0       3.0        1.0        0.274316          51.529950
# 27953107  400000.0       2.0        2.0        0.305845          51.549390
# 33593487  579950.0       2.0        1.0        0.438045          51.447180
# 35271294  370000.0       2.0        1.0        0.399307          51.449568
# 35429088  599950.0       2.0        1.0        0.238187          51.577030
# 44749111  475000.0       2.0        1.0        0.410550          51.370050
# 46204665  435000.0       3.0        2.0        0.314779          51.539070
# 49020666  200000.0       1.0        1.0        0.875911          51.539959
# 49036279  275000.0       2.0        1.0        0.474368          51.541780
# 49303873  450000.0       3.0        2.0        0.577040          51.524880
# 52064391  349950.0       2.0        2.0        0.212734          51.470800
# 52187854  450000.0       1.0        1.0        0.446802          51.527199
# 52675628  490000.0       2.0        2.0        0.215040          51.501114
# 52845963  200000.0       2.0        1.0        0.650562          51.398040
# 52913496  220000.0       1.0        1.0        0.945991          51.539383
# 53609433  489995.0       1.0        1.0        0.087081          51.532620
# 53649578  284950.0       1.0        1.0        0.806597          51.479890
# 53938989  450000.0       2.0        1.0        0.775203          51.658287
# 54713232  332000.0       2.0        1.0        0.319226          51.612300
# 54904122  365000.0       2.0        1.0        0.260722          51.593595
# 54991934  430000.0       3.0        1.0        0.497268          51.528720
# 55043230  260000.0       1.0        1.0        0.384607          51.544430
# 55187658  430000.0       2.0        2.0        0.289033          51.507570
# 55531367  599950.0       2.0        1.0        0.406725          51.467410
# 55768232  550000.0       2.0        1.0        0.478349          51.472890
# 55805965  280000.0       2.0        1.0        0.742859          51.520910
# 55839051  599950.0       2.0        1.0        0.259168          51.579186
# 55940994  385000.0       2.0        2.0        0.403987          51.376930
# 56449305  380000.0       2.0        1.0        0.310271          51.600483
# 57221413  475000.0       3.0        2.0        0.409784          51.497260
#
#           location.longitude  latitude_deviation  longitude_deviation  \
# 14520525           -0.207020            0.030230             0.102600
# 27953107           -0.482600            0.049670             0.378180
# 33593487           -0.338770            0.052540             0.234350
# 35271294           -0.140154            0.050152             0.035734
# 35429088           -0.141230            0.077310             0.036810
# 44749111           -0.212410            0.129670             0.107990
# 46204665           -0.198935            0.039350             0.094515
# 49020666           -0.380863            0.040239             0.276443
# 49036279            0.037890            0.042060             0.142310
# 49303873            0.187200            0.025160             0.291620
# 52064391           -0.361820            0.028920             0.257400
# 52187854           -0.202898            0.027479             0.098478
# 52675628            0.026315            0.001394             0.130735
# 52845963           -0.076812            0.101680             0.027608
# 52913496           -0.382239            0.039663             0.277819
# 53609433           -0.107860            0.032900             0.003440
# 53649578           -0.078500            0.019830             0.025920
# 53938989           -0.207902            0.158567             0.103482
# 54713232           -0.119860            0.112580             0.015440
# 54904122            0.022046            0.093875             0.126466
# 54991934            0.039180            0.029000             0.143600
# 55043230            0.014500            0.044710             0.118920
# 55187658            0.078030            0.007850             0.182450
# 55531367           -0.079170            0.032310             0.025250
# 55768232           -0.078940            0.026830             0.025480
# 55805965            0.022680            0.021190             0.127100
# 55839051           -0.209020            0.079466             0.104600
# 55940994           -0.238870            0.122790             0.134450
# 56449305           -0.062096            0.100763             0.042324
# 57221413           -0.422530            0.002460             0.318110
#
#           tenure.tenureType  feature__1 bedroom  ...  feature__reception room  \
# 14520525          LEASEHOLD                   0  ...                        0
# 27953107          LEASEHOLD                   0  ...                        0
# 33593487           FREEHOLD                   0  ...                        0
# 35271294          LEASEHOLD                   0  ...                        0
# 35429088                NaN                   0  ...                        0
# 44749111           FREEHOLD                   0  ...                        0
# 46204665          LEASEHOLD                   0  ...                        0
# 49020666          LEASEHOLD                   0  ...                        0
# 49036279          LEASEHOLD                   0  ...                        0
# 49303873           FREEHOLD                   0  ...                        0
# 52064391          LEASEHOLD                   0  ...                        0
# 52187854          LEASEHOLD                   0  ...                        0
# 52675628                NaN                   0  ...                        0
# 52845963          LEASEHOLD                   0  ...                        0
# 52913496          LEASEHOLD                   0  ...                        0
# 53609433          LEASEHOLD                   0  ...                        0
# 53649578                NaN                   0  ...                        0
# 53938989           FREEHOLD                   0  ...                        0
# 54713232  SHARE_OF_FREEHOLD                   0  ...                        0
# 54904122  SHARE_OF_FREEHOLD                   0  ...                        0
# 54991934           FREEHOLD                   0  ...                        0
# 55043230          LEASEHOLD                   0  ...                        0
# 55187658          LEASEHOLD                   0  ...                        0
# 55531367                NaN                   0  ...                        0
# 55768232                NaN                   0  ...                        0
# 55805965          LEASEHOLD                   0  ...                        0
# 55839051          LEASEHOLD                   0  ...                        0
# 55940994          LEASEHOLD                   0  ...                        0
# 56449305           FREEHOLD                   0  ...                        1
# 57221413           FREEHOLD                   0  ...                        0
#
#           feature__separate kitchen  feature__share of freehold  \
# 14520525                          1                           0
# 27953107                          0                           0
# 33593487                          0                           0
# 35271294                          0                           0
# 35429088                          0                           0
# 44749111                          0                           0
# 46204665                          0                           0
# 49020666                          0                           0
# 49036279                          0                           0
# 49303873                          0                           0
# 52064391                          0                           0
# 52187854                          0                           0
# 52675628                          0                           0
# 52845963                          0                           0
# 52913496                          0                           0
# 53609433                          0                           0
# 53649578                          0                           0
# 53938989                          0                           0
# 54713232                          0                           0
# 54904122                          0                           1
# 54991934                          0                           0
# 55043230                          0                           0
# 55187658                          0                           0
# 55531367                          0                           0
# 55768232                          0                           0
# 55805965                          0                           0
# 55839051                          0                           0
# 55940994                          0                           0
# 56449305                          0                           0
# 57221413                          0                           0
#
#           feature__three bedrooms  feature__three double bedrooms  \
# 14520525                        0                               0
# 27953107                        0                               0
# 33593487                        0                               0
# 35271294                        0                               0
# 35429088                        0                               0
# 44749111                        0                               0
# 46204665                        1                               0
# 49020666                        0                               0
# 49036279                        0                               0
# 49303873                        0                               0
# 52064391                        0                               0
# 52187854                        0                               0
# 52675628                        0                               0
# 52845963                        0                               0
# 52913496                        0                               0
# 53609433                        0                               0
# 53649578                        0                               0
# 53938989                        0                               0
# 54713232                        0                               0
# 54904122                        0                               0
# 54991934                        0                               0
# 55043230                        0                               0
# 55187658                        0                               0
# 55531367                        0                               0
# 55768232                        0                               0
# 55805965                        0                               0
# 55839051                        0                               0
# 55940994                        0                               0
# 56449305                        0                               0
# 57221413                        1                               0
#
#           feature__top floor  feature__two bathrooms  feature__two bedrooms  \
# 14520525                   0                       0                      0
# 27953107                   1                       0                      0
# 33593487                   0                       0                      0
# 35271294                   0                       0                      0
# 35429088                   0                       0                      0
# 44749111                   0                       0                      0
# 46204665                   0                       0                      0
# 49020666                   0                       0                      0
# 49036279                   0                       0                      0
# 49303873                   0                       0                      0
# 52064391                   0                       0                      1
# 52187854                   0                       0                      0
# 52675628                   0                       0                      0
# 52845963                   0                       0                      0
# 52913496                   0                       0                      0
# 53609433                   0                       0                      0
# 53649578                   0                       0                      0
# 53938989                   0                       0                      0
# 54713232                   0                       0                      0
# 54904122                   0                       0                      0
# 54991934                   0                       0                      0
# 55043230                   0                       0                      0
# 55187658                   0                       0                      0
# 55531367                   0                       0                      0
# 55768232                   0                       0                      0
# 55805965                   0                       0                      0
# 55839051                   0                       0                      0
# 55940994                   0                       0                      1
# 56449305                   0                       0                      1
# 57221413                   0                       0                      0
#
#           feature__two double bedrooms  feature__two reception rooms
# 14520525                             0                             0
# 27953107                             1                             0
# 33593487                             0                             0
# 35271294                             0                             0
# 35429088                             0                             0
# 44749111                             0                             0
# 46204665                             0                             0
# 49020666                             0                             0
# 49036279                             0                             0
# 49303873                             0                             0
# 52064391                             0                             0
# 52187854                             0                             0
# 52675628                             0                             0
# 52845963                             0                             0
# 52913496                             0                             0
# 53609433                             0                             0
# 53649578                             0                             0
# 53938989                             0                             0
# 54713232                             0                             0
# 54904122                             0                             0
# 54991934                             0                             0
# 55043230                             0                             0
# 55187658                             0                             0
# 55531367                             1                             0
# 55768232                             0                             0
# 55805965                             0                             0
# 55839051                             0                             0
# 55940994                             0                             0
# 56449305                             0                             0
# 57221413                             0                             0
#
# [30 rows x 59 columns]

# %%
df.isnull().sum()
# Out:
# Price                                    0
# bedrooms                                 0
# bathrooms                                0
# nearestStation                           0
# location.latitude                        0
# location.longitude                       0
# latitude_deviation                       0
# longitude_deviation                      0
# tenure.tenureType                     2744
# feature__1 bedroom                       0
# feature__2 bedrooms                      0
# feature__2 double bedrooms               0
# feature__allocated parking               0
# feature__allocated parking space         0
# feature__balcony                         0
# feature__bathroom                        0
# feature__chain free                      0
# feature__close to local amenities        0
# feature__communal garden                 0
# feature__communal gardens                0
# feature__double bedroom                  0
# feature__double glazed                   0
# feature__double glazing                  0
# feature__epc rating c                    0
# feature__epc rating d                    0
# feature__excellent location              0
# feature__excellent transport links       0
# feature__family bathroom                 0
# feature__first floor                     0
# feature__fitted kitchen                  0
# feature__garage                          0
# feature__garden                          0
# feature__gas central heating             0
# feature__great location                  0
# feature__ground floor                    0
# feature__kitchen                         0
# feature__leasehold                       0
# feature__long lease                      0
# feature__modern bathroom                 0
# feature__modern kitchen                  0
# feature__no chain                        0
# feature__no onward chain                 0
# feature__off street parking              0
# feature__one bedroom                     0
# feature__one double bedroom              0
# feature__parking                         0
# feature__private balcony                 0
# feature__private garden                  0
# feature__private rear garden             0
# feature__reception room                  0
# feature__separate kitchen                0
# feature__share of freehold               0
# feature__three bedrooms                  0
# feature__three double bedrooms           0
# feature__top floor                       0
# feature__two bathrooms                   0
# feature__two bedrooms                    0
# feature__two double bedrooms             0
# feature__two reception rooms             0
# dtype: int64

# %%
df.info()
df.describe()
df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46871 entries, 14520525 to 126181118
# Data columns (total 59 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Price                               46871 non-null  float64
#  1   bedrooms                            46871 non-null  float64
#  2   bathrooms                           46871 non-null  float64
#  3   nearestStation                      46871 non-null  float64
#  4   location.latitude                   46871 non-null  float64
#  5   location.longitude                  46871 non-null  float64
#  6   latitude_deviation                  46871 non-null  float64
#  7   longitude_deviation                 46871 non-null  float64
#  8   tenure.tenureType                   44127 non-null  object
#  9   feature__1 bedroom                  46871 non-null  int64
#  10  feature__2 bedrooms                 46871 non-null  int64
#  11  feature__2 double bedrooms          46871 non-null  int64
#  12  feature__allocated parking          46871 non-null  int64
#  13  feature__allocated parking space    46871 non-null  int64
#  14  feature__balcony                    46871 non-null  int64
#  15  feature__bathroom                   46871 non-null  int64
#  16  feature__chain free                 46871 non-null  int64
#  17  feature__close to local amenities   46871 non-null  int64
#  18  feature__communal garden            46871 non-null  int64
#  19  feature__communal gardens           46871 non-null  int64
#  20  feature__double bedroom             46871 non-null  int64
#  21  feature__double glazed              46871 non-null  int64
#  22  feature__double glazing             46871 non-null  int64
#  23  feature__epc rating c               46871 non-null  int64
#  24  feature__epc rating d               46871 non-null  int64
#  25  feature__excellent location         46871 non-null  int64
#  26  feature__excellent transport links  46871 non-null  int64
#  27  feature__family bathroom            46871 non-null  int64
#  28  feature__first floor                46871 non-null  int64
#  29  feature__fitted kitchen             46871 non-null  int64
#  30  feature__garage                     46871 non-null  int64
#  31  feature__garden                     46871 non-null  int64
#  32  feature__gas central heating        46871 non-null  int64
#  33  feature__great location             46871 non-null  int64
#  34  feature__ground floor               46871 non-null  int64
#  35  feature__kitchen                    46871 non-null  int64
#  36  feature__leasehold                  46871 non-null  int64
#  37  feature__long lease                 46871 non-null  int64
#  38  feature__modern bathroom            46871 non-null  int64
#  39  feature__modern kitchen             46871 non-null  int64
#  40  feature__no chain                   46871 non-null  int64
#  41  feature__no onward chain            46871 non-null  int64
#  42  feature__off street parking         46871 non-null  int64
#  43  feature__one bedroom                46871 non-null  int64
#  44  feature__one double bedroom         46871 non-null  int64
#  45  feature__parking                    46871 non-null  int64
#  46  feature__private balcony            46871 non-null  int64
#  47  feature__private garden             46871 non-null  int64
#  48  feature__private rear garden        46871 non-null  int64
#  49  feature__reception room             46871 non-null  int64
#  50  feature__separate kitchen           46871 non-null  int64
#  51  feature__share of freehold          46871 non-null  int64
#  52  feature__three bedrooms             46871 non-null  int64
#  53  feature__three double bedrooms      46871 non-null  int64
#  54  feature__top floor                  46871 non-null  int64
#  55  feature__two bathrooms              46871 non-null  int64
#  56  feature__two bedrooms               46871 non-null  int64
#  57  feature__two double bedrooms        46871 non-null  int64
#  58  feature__two reception rooms        46871 non-null  int64
# dtypes: float64(8), int64(50), object(1)
# memory usage: 21.5+ MB
#                                       count           mean            std  \
# Price                               46871.0  425069.390775  107227.324906
# bedrooms                            46871.0       1.992469       0.828837
# bathrooms                           46871.0       1.182074       0.409879
# nearestStation                      46871.0       0.438847       0.325942
# location.latitude                   46871.0      51.497049       0.077085
# location.longitude                  46871.0      -0.113269       0.156489
# latitude_deviation                  46871.0       0.064317       0.042573
# longitude_deviation                 46871.0       0.124202       0.095607
# feature__1 bedroom                  46871.0       0.010838       0.103542
# feature__2 bedrooms                 46871.0       0.015169       0.122402
# feature__2 double bedrooms          46871.0       0.013569       0.115695
# feature__allocated parking          46871.0       0.026946       0.161928
# feature__allocated parking space    46871.0       0.012993       0.113246
# feature__balcony                    46871.0       0.038617       0.193124
# feature__bathroom                   46871.0       0.026370       0.160502
# feature__chain free                 46871.0       0.120266       0.325800
# feature__close to local amenities   46871.0       0.011948       0.108848
# feature__communal garden            46871.0       0.018071       0.133209
# feature__communal gardens           46871.0       0.030381       0.171760
# feature__double bedroom             46871.0       0.012566       0.111395
# feature__double glazed              46871.0       0.012822       0.112509
# feature__double glazing             46871.0       0.025496       0.157761
# feature__epc rating c               46871.0       0.012140       0.109511
# feature__epc rating d               46871.0       0.013334       0.114704
# feature__excellent location         46871.0       0.013612       0.115874
# feature__excellent transport links  46871.0       0.016385       0.127122
# feature__family bathroom            46871.0       0.014593       0.120097
# feature__first floor                46871.0       0.026520       0.160676
# feature__fitted kitchen             46871.0       0.027224       0.162867
# feature__garage                     46871.0       0.030424       0.172001
# feature__garden                     46871.0       0.021015       0.144178
# feature__gas central heating        46871.0       0.028120       0.165961
# feature__great location             46871.0       0.015660       0.124158
# feature__ground floor               46871.0       0.028760       0.167132
# feature__kitchen                    46871.0       0.022850       0.149427
# feature__leasehold                  46871.0       0.014316       0.118970
# feature__long lease                 46871.0       0.039619       0.195175
# feature__modern bathroom            46871.0       0.015361       0.122986
# feature__modern kitchen             46871.0       0.014465       0.119400
# feature__no chain                   46871.0       0.026669       0.161380
# feature__no onward chain            46871.0       0.057925       0.233604
# feature__off street parking         46871.0       0.047300       0.212684
# feature__one bedroom                46871.0       0.041369       0.199144
# feature__one double bedroom         46871.0       0.027885       0.164645
# feature__parking                    46871.0       0.013398       0.115160
# feature__private balcony            46871.0       0.039662       0.195275
# feature__private garden             46871.0       0.034200       0.181980
# feature__private rear garden        46871.0       0.017367       0.131124
# feature__reception room             46871.0       0.014487       0.119843
# feature__separate kitchen           46871.0       0.020268       0.140918
# feature__share of freehold          46871.0       0.047663       0.213354
# feature__three bedrooms             46871.0       0.059120       0.235851
# feature__three double bedrooms      46871.0       0.012545       0.111301
# feature__top floor                  46871.0       0.013206       0.114159
# feature__two bathrooms              46871.0       0.031512       0.174943
# feature__two bedrooms               46871.0       0.071473       0.257616
# feature__two double bedrooms        46871.0       0.095411       0.293930
# feature__two reception rooms        46871.0       0.016449       0.127197
#
#                                               min            25%  \
# Price                               100000.000000  349950.000000
# bedrooms                                 1.000000       1.000000
# bathrooms                                1.000000       1.000000
# nearestStation                           0.000000       0.227169
# location.latitude                       51.298317      51.438861
# location.longitude                      -0.498315      -0.210796
# latitude_deviation                       0.000000       0.028876
# longitude_deviation                      0.000000       0.043560
# feature__1 bedroom                       0.000000       0.000000
# feature__2 bedrooms                      0.000000       0.000000
# feature__2 double bedrooms               0.000000       0.000000
# feature__allocated parking               0.000000       0.000000
# feature__allocated parking space         0.000000       0.000000
# feature__balcony                         0.000000       0.000000
# feature__bathroom                        0.000000       0.000000
# feature__chain free                      0.000000       0.000000
# feature__close to local amenities        0.000000       0.000000
# feature__communal garden                 0.000000       0.000000
# feature__communal gardens                0.000000       0.000000
# feature__double bedroom                  0.000000       0.000000
# feature__double glazed                   0.000000       0.000000
# feature__double glazing                  0.000000       0.000000
# feature__epc rating c                    0.000000       0.000000
# feature__epc rating d                    0.000000       0.000000
# feature__excellent location              0.000000       0.000000
# feature__excellent transport links       0.000000       0.000000
# feature__family bathroom                 0.000000       0.000000
# feature__first floor                     0.000000       0.000000
# feature__fitted kitchen                  0.000000       0.000000
# feature__garage                          0.000000       0.000000
# feature__garden                          0.000000       0.000000
# feature__gas central heating             0.000000       0.000000
# feature__great location                  0.000000       0.000000
# feature__ground floor                    0.000000       0.000000
# feature__kitchen                         0.000000       0.000000
# feature__leasehold                       0.000000       0.000000
# feature__long lease                      0.000000       0.000000
# feature__modern bathroom                 0.000000       0.000000
# feature__modern kitchen                  0.000000       0.000000
# feature__no chain                        0.000000       0.000000
# feature__no onward chain                 0.000000       0.000000
# feature__off street parking              0.000000       0.000000
# feature__one bedroom                     0.000000       0.000000
# feature__one double bedroom              0.000000       0.000000
# feature__parking                         0.000000       0.000000
# feature__private balcony                 0.000000       0.000000
# feature__private garden                  0.000000       0.000000
# feature__private rear garden             0.000000       0.000000
# feature__reception room                  0.000000       0.000000
# feature__separate kitchen                0.000000       0.000000
# feature__share of freehold               0.000000       0.000000
# feature__three bedrooms                  0.000000       0.000000
# feature__three double bedrooms           0.000000       0.000000
# feature__top floor                       0.000000       0.000000
# feature__two bathrooms                   0.000000       0.000000
# feature__two bedrooms                    0.000000       0.000000
# feature__two double bedrooms             0.000000       0.000000
# feature__two reception rooms             0.000000       0.000000
#
#                                               50%            75%  \
# Price                               425000.000000  515000.000000
# bedrooms                                 2.000000       3.000000
# bathrooms                                1.000000       1.000000
# nearestStation                           0.367971       0.559620
# location.latitude                       51.499977      51.556183
# location.longitude                      -0.102230      -0.010343
# latitude_deviation                       0.058595       0.094362
# longitude_deviation                      0.098984       0.192684
# feature__1 bedroom                       0.000000       0.000000
# feature__2 bedrooms                      0.000000       0.000000
# feature__2 double bedrooms               0.000000       0.000000
# feature__allocated parking               0.000000       0.000000
# feature__allocated parking space         0.000000       0.000000
# feature__balcony                         0.000000       0.000000
# feature__bathroom                        0.000000       0.000000
# feature__chain free                      0.000000       0.000000
# feature__close to local amenities        0.000000       0.000000
# feature__communal garden                 0.000000       0.000000
# feature__communal gardens                0.000000       0.000000
# feature__double bedroom                  0.000000       0.000000
# feature__double glazed                   0.000000       0.000000
# feature__double glazing                  0.000000       0.000000
# feature__epc rating c                    0.000000       0.000000
# feature__epc rating d                    0.000000       0.000000
# feature__excellent location              0.000000       0.000000
# feature__excellent transport links       0.000000       0.000000
# feature__family bathroom                 0.000000       0.000000
# feature__first floor                     0.000000       0.000000
# feature__fitted kitchen                  0.000000       0.000000
# feature__garage                          0.000000       0.000000
# feature__garden                          0.000000       0.000000
# feature__gas central heating             0.000000       0.000000
# feature__great location                  0.000000       0.000000
# feature__ground floor                    0.000000       0.000000
# feature__kitchen                         0.000000       0.000000
# feature__leasehold                       0.000000       0.000000
# feature__long lease                      0.000000       0.000000
# feature__modern bathroom                 0.000000       0.000000
# feature__modern kitchen                  0.000000       0.000000
# feature__no chain                        0.000000       0.000000
# feature__no onward chain                 0.000000       0.000000
# feature__off street parking              0.000000       0.000000
# feature__one bedroom                     0.000000       0.000000
# feature__one double bedroom              0.000000       0.000000
# feature__parking                         0.000000       0.000000
# feature__private balcony                 0.000000       0.000000
# feature__private garden                  0.000000       0.000000
# feature__private rear garden             0.000000       0.000000
# feature__reception room                  0.000000       0.000000
# feature__separate kitchen                0.000000       0.000000
# feature__share of freehold               0.000000       0.000000
# feature__three bedrooms                  0.000000       0.000000
# feature__three double bedrooms           0.000000       0.000000
# feature__top floor                       0.000000       0.000000
# feature__two bathrooms                   0.000000       0.000000
# feature__two bedrooms                    0.000000       0.000000
# feature__two double bedrooms             0.000000       0.000000
# feature__two reception rooms             0.000000       0.000000
#
#                                               max
# Price                               600000.000000
# bedrooms                                 7.000000
# bathrooms                                5.000000
# nearestStation                           7.197700
# location.latitude                       51.683185
# location.longitude                       0.279726
# latitude_deviation                       0.201403
# longitude_deviation                      0.393895
# feature__1 bedroom                       1.000000
# feature__2 bedrooms                      2.000000
# feature__2 double bedrooms               1.000000
# feature__allocated parking               1.000000
# feature__allocated parking space         1.000000
# feature__balcony                         2.000000
# feature__bathroom                        2.000000
# feature__chain free                      2.000000
# feature__close to local amenities        2.000000
# feature__communal garden                 1.000000
# feature__communal gardens                2.000000
# feature__double bedroom                  1.000000
# feature__double glazed                   1.000000
# feature__double glazing                  2.000000
# feature__epc rating c                    1.000000
# feature__epc rating d                    1.000000
# feature__excellent location              1.000000
# feature__excellent transport links       2.000000
# feature__family bathroom                 2.000000
# feature__first floor                     1.000000
# feature__fitted kitchen                  2.000000
# feature__garage                          2.000000
# feature__garden                          2.000000
# feature__gas central heating             2.000000
# feature__great location                  1.000000
# feature__ground floor                    1.000000
# feature__kitchen                         1.000000
# feature__leasehold                       2.000000
# feature__long lease                      2.000000
# feature__modern bathroom                 1.000000
# feature__modern kitchen                  1.000000
# feature__no chain                        2.000000
# feature__no onward chain                 1.000000
# feature__off street parking              2.000000
# feature__one bedroom                     1.000000
# feature__one double bedroom              1.000000
# feature__parking                         2.000000
# feature__private balcony                 2.000000
# feature__private garden                  2.000000
# feature__private rear garden             2.000000
# feature__reception room                  2.000000
# feature__separate kitchen                1.000000
# feature__share of freehold               2.000000
# feature__three bedrooms                  1.000000
# feature__three double bedrooms           1.000000
# feature__top floor                       1.000000
# feature__two bathrooms                   2.000000
# feature__two bedrooms                    1.000000
# feature__two double bedrooms             2.000000
# feature__two reception rooms             1.000000

# %%
old_length = len(df)

df = preprocess(df, version=VERSION)

print(f"dataframe contract due to cleaning: {old_length} ==> {len(df)}")
old_length = len(df)

df.describe().T
# Out:
# dataframe contract due to cleaning: 46871 ==> 46871
#                                       count           mean            std  \
# Price                               46871.0  425069.390775  107227.324906
# bedrooms                            46871.0       1.992469       0.828837
# bathrooms                           46871.0       1.182074       0.409879
# nearestStation                      46871.0       0.438847       0.325942
# location.latitude                   46871.0      51.497049       0.077085
# location.longitude                  46871.0      -0.113269       0.156489
# latitude_deviation                  46871.0       0.064317       0.042573
# longitude_deviation                 46871.0       0.124202       0.095607
# feature__1 bedroom                  46871.0       0.010838       0.103542
# feature__2 bedrooms                 46871.0       0.015169       0.122402
# feature__2 double bedrooms          46871.0       0.013569       0.115695
# feature__allocated parking          46871.0       0.026946       0.161928
# feature__allocated parking space    46871.0       0.012993       0.113246
# feature__balcony                    46871.0       0.038617       0.193124
# feature__bathroom                   46871.0       0.026370       0.160502
# feature__chain free                 46871.0       0.120266       0.325800
# feature__close to local amenities   46871.0       0.011948       0.108848
# feature__communal garden            46871.0       0.018071       0.133209
# feature__communal gardens           46871.0       0.030381       0.171760
# feature__double bedroom             46871.0       0.012566       0.111395
# feature__double glazed              46871.0       0.012822       0.112509
# feature__double glazing             46871.0       0.025496       0.157761
# feature__epc rating c               46871.0       0.012140       0.109511
# feature__epc rating d               46871.0       0.013334       0.114704
# feature__excellent location         46871.0       0.013612       0.115874
# feature__excellent transport links  46871.0       0.016385       0.127122
# feature__family bathroom            46871.0       0.014593       0.120097
# feature__first floor                46871.0       0.026520       0.160676
# feature__fitted kitchen             46871.0       0.027224       0.162867
# feature__garage                     46871.0       0.030424       0.172001
# feature__garden                     46871.0       0.021015       0.144178
# feature__gas central heating        46871.0       0.028120       0.165961
# feature__great location             46871.0       0.015660       0.124158
# feature__ground floor               46871.0       0.028760       0.167132
# feature__kitchen                    46871.0       0.022850       0.149427
# feature__leasehold                  46871.0       0.014316       0.118970
# feature__long lease                 46871.0       0.039619       0.195175
# feature__modern bathroom            46871.0       0.015361       0.122986
# feature__modern kitchen             46871.0       0.014465       0.119400
# feature__no chain                   46871.0       0.026669       0.161380
# feature__no onward chain            46871.0       0.057925       0.233604
# feature__off street parking         46871.0       0.047300       0.212684
# feature__one bedroom                46871.0       0.041369       0.199144
# feature__one double bedroom         46871.0       0.027885       0.164645
# feature__parking                    46871.0       0.013398       0.115160
# feature__private balcony            46871.0       0.039662       0.195275
# feature__private garden             46871.0       0.034200       0.181980
# feature__private rear garden        46871.0       0.017367       0.131124
# feature__reception room             46871.0       0.014487       0.119843
# feature__separate kitchen           46871.0       0.020268       0.140918
# feature__share of freehold          46871.0       0.047663       0.213354
# feature__three bedrooms             46871.0       0.059120       0.235851
# feature__three double bedrooms      46871.0       0.012545       0.111301
# feature__top floor                  46871.0       0.013206       0.114159
# feature__two bathrooms              46871.0       0.031512       0.174943
# feature__two bedrooms               46871.0       0.071473       0.257616
# feature__two double bedrooms        46871.0       0.095411       0.293930
# feature__two reception rooms        46871.0       0.016449       0.127197
#
#                                               min            25%  \
# Price                               100000.000000  349950.000000
# bedrooms                                 1.000000       1.000000
# bathrooms                                1.000000       1.000000
# nearestStation                           0.000000       0.227169
# location.latitude                       51.298317      51.438861
# location.longitude                      -0.498315      -0.210796
# latitude_deviation                       0.000000       0.028876
# longitude_deviation                      0.000000       0.043560
# feature__1 bedroom                       0.000000       0.000000
# feature__2 bedrooms                      0.000000       0.000000
# feature__2 double bedrooms               0.000000       0.000000
# feature__allocated parking               0.000000       0.000000
# feature__allocated parking space         0.000000       0.000000
# feature__balcony                         0.000000       0.000000
# feature__bathroom                        0.000000       0.000000
# feature__chain free                      0.000000       0.000000
# feature__close to local amenities        0.000000       0.000000
# feature__communal garden                 0.000000       0.000000
# feature__communal gardens                0.000000       0.000000
# feature__double bedroom                  0.000000       0.000000
# feature__double glazed                   0.000000       0.000000
# feature__double glazing                  0.000000       0.000000
# feature__epc rating c                    0.000000       0.000000
# feature__epc rating d                    0.000000       0.000000
# feature__excellent location              0.000000       0.000000
# feature__excellent transport links       0.000000       0.000000
# feature__family bathroom                 0.000000       0.000000
# feature__first floor                     0.000000       0.000000
# feature__fitted kitchen                  0.000000       0.000000
# feature__garage                          0.000000       0.000000
# feature__garden                          0.000000       0.000000
# feature__gas central heating             0.000000       0.000000
# feature__great location                  0.000000       0.000000
# feature__ground floor                    0.000000       0.000000
# feature__kitchen                         0.000000       0.000000
# feature__leasehold                       0.000000       0.000000
# feature__long lease                      0.000000       0.000000
# feature__modern bathroom                 0.000000       0.000000
# feature__modern kitchen                  0.000000       0.000000
# feature__no chain                        0.000000       0.000000
# feature__no onward chain                 0.000000       0.000000
# feature__off street parking              0.000000       0.000000
# feature__one bedroom                     0.000000       0.000000
# feature__one double bedroom              0.000000       0.000000
# feature__parking                         0.000000       0.000000
# feature__private balcony                 0.000000       0.000000
# feature__private garden                  0.000000       0.000000
# feature__private rear garden             0.000000       0.000000
# feature__reception room                  0.000000       0.000000
# feature__separate kitchen                0.000000       0.000000
# feature__share of freehold               0.000000       0.000000
# feature__three bedrooms                  0.000000       0.000000
# feature__three double bedrooms           0.000000       0.000000
# feature__top floor                       0.000000       0.000000
# feature__two bathrooms                   0.000000       0.000000
# feature__two bedrooms                    0.000000       0.000000
# feature__two double bedrooms             0.000000       0.000000
# feature__two reception rooms             0.000000       0.000000
#
#                                               50%            75%  \
# Price                               425000.000000  515000.000000
# bedrooms                                 2.000000       3.000000
# bathrooms                                1.000000       1.000000
# nearestStation                           0.367971       0.559620
# location.latitude                       51.499977      51.556183
# location.longitude                      -0.102230      -0.010343
# latitude_deviation                       0.058595       0.094362
# longitude_deviation                      0.098984       0.192684
# feature__1 bedroom                       0.000000       0.000000
# feature__2 bedrooms                      0.000000       0.000000
# feature__2 double bedrooms               0.000000       0.000000
# feature__allocated parking               0.000000       0.000000
# feature__allocated parking space         0.000000       0.000000
# feature__balcony                         0.000000       0.000000
# feature__bathroom                        0.000000       0.000000
# feature__chain free                      0.000000       0.000000
# feature__close to local amenities        0.000000       0.000000
# feature__communal garden                 0.000000       0.000000
# feature__communal gardens                0.000000       0.000000
# feature__double bedroom                  0.000000       0.000000
# feature__double glazed                   0.000000       0.000000
# feature__double glazing                  0.000000       0.000000
# feature__epc rating c                    0.000000       0.000000
# feature__epc rating d                    0.000000       0.000000
# feature__excellent location              0.000000       0.000000
# feature__excellent transport links       0.000000       0.000000
# feature__family bathroom                 0.000000       0.000000
# feature__first floor                     0.000000       0.000000
# feature__fitted kitchen                  0.000000       0.000000
# feature__garage                          0.000000       0.000000
# feature__garden                          0.000000       0.000000
# feature__gas central heating             0.000000       0.000000
# feature__great location                  0.000000       0.000000
# feature__ground floor                    0.000000       0.000000
# feature__kitchen                         0.000000       0.000000
# feature__leasehold                       0.000000       0.000000
# feature__long lease                      0.000000       0.000000
# feature__modern bathroom                 0.000000       0.000000
# feature__modern kitchen                  0.000000       0.000000
# feature__no chain                        0.000000       0.000000
# feature__no onward chain                 0.000000       0.000000
# feature__off street parking              0.000000       0.000000
# feature__one bedroom                     0.000000       0.000000
# feature__one double bedroom              0.000000       0.000000
# feature__parking                         0.000000       0.000000
# feature__private balcony                 0.000000       0.000000
# feature__private garden                  0.000000       0.000000
# feature__private rear garden             0.000000       0.000000
# feature__reception room                  0.000000       0.000000
# feature__separate kitchen                0.000000       0.000000
# feature__share of freehold               0.000000       0.000000
# feature__three bedrooms                  0.000000       0.000000
# feature__three double bedrooms           0.000000       0.000000
# feature__top floor                       0.000000       0.000000
# feature__two bathrooms                   0.000000       0.000000
# feature__two bedrooms                    0.000000       0.000000
# feature__two double bedrooms             0.000000       0.000000
# feature__two reception rooms             0.000000       0.000000
#
#                                               max
# Price                               600000.000000
# bedrooms                                 7.000000
# bathrooms                                5.000000
# nearestStation                           7.197700
# location.latitude                       51.683185
# location.longitude                       0.279726
# latitude_deviation                       0.201403
# longitude_deviation                      0.393895
# feature__1 bedroom                       1.000000
# feature__2 bedrooms                      2.000000
# feature__2 double bedrooms               1.000000
# feature__allocated parking               1.000000
# feature__allocated parking space         1.000000
# feature__balcony                         2.000000
# feature__bathroom                        2.000000
# feature__chain free                      2.000000
# feature__close to local amenities        2.000000
# feature__communal garden                 1.000000
# feature__communal gardens                2.000000
# feature__double bedroom                  1.000000
# feature__double glazed                   1.000000
# feature__double glazing                  2.000000
# feature__epc rating c                    1.000000
# feature__epc rating d                    1.000000
# feature__excellent location              1.000000
# feature__excellent transport links       2.000000
# feature__family bathroom                 2.000000
# feature__first floor                     1.000000
# feature__fitted kitchen                  2.000000
# feature__garage                          2.000000
# feature__garden                          2.000000
# feature__gas central heating             2.000000
# feature__great location                  1.000000
# feature__ground floor                    1.000000
# feature__kitchen                         1.000000
# feature__leasehold                       2.000000
# feature__long lease                      2.000000
# feature__modern bathroom                 1.000000
# feature__modern kitchen                  1.000000
# feature__no chain                        2.000000
# feature__no onward chain                 1.000000
# feature__off street parking              2.000000
# feature__one bedroom                     1.000000
# feature__one double bedroom              1.000000
# feature__parking                         2.000000
# feature__private balcony                 2.000000
# feature__private garden                  2.000000
# feature__private rear garden             2.000000
# feature__reception room                  2.000000
# feature__separate kitchen                1.000000
# feature__share of freehold               2.000000
# feature__three bedrooms                  1.000000
# feature__three double bedrooms           1.000000
# feature__top floor                       1.000000
# feature__two bathrooms                   2.000000
# feature__two bedrooms                    1.000000
# feature__two double bedrooms             2.000000
# feature__two reception rooms             1.000000

# %%
df.isna().sum()
# Out:
# Price                                    0
# bedrooms                                 0
# bathrooms                                0
# nearestStation                           0
# location.latitude                        0
# location.longitude                       0
# latitude_deviation                       0
# longitude_deviation                      0
# tenure.tenureType                     2744
# feature__1 bedroom                       0
# feature__2 bedrooms                      0
# feature__2 double bedrooms               0
# feature__allocated parking               0
# feature__allocated parking space         0
# feature__balcony                         0
# feature__bathroom                        0
# feature__chain free                      0
# feature__close to local amenities        0
# feature__communal garden                 0
# feature__communal gardens                0
# feature__double bedroom                  0
# feature__double glazed                   0
# feature__double glazing                  0
# feature__epc rating c                    0
# feature__epc rating d                    0
# feature__excellent location              0
# feature__excellent transport links       0
# feature__family bathroom                 0
# feature__first floor                     0
# feature__fitted kitchen                  0
# feature__garage                          0
# feature__garden                          0
# feature__gas central heating             0
# feature__great location                  0
# feature__ground floor                    0
# feature__kitchen                         0
# feature__leasehold                       0
# feature__long lease                      0
# feature__modern bathroom                 0
# feature__modern kitchen                  0
# feature__no chain                        0
# feature__no onward chain                 0
# feature__off street parking              0
# feature__one bedroom                     0
# feature__one double bedroom              0
# feature__parking                         0
# feature__private balcony                 0
# feature__private garden                  0
# feature__private rear garden             0
# feature__reception room                  0
# feature__separate kitchen                0
# feature__share of freehold               0
# feature__three bedrooms                  0
# feature__three double bedrooms           0
# feature__top floor                       0
# feature__two bathrooms                   0
# feature__two bedrooms                    0
# feature__two double bedrooms             0
# feature__two reception rooms             0
# dtype: int64

# %%
df = df.dropna()
print(f"{old_length} ==> {len(df)}")
old_length = len(df)
df.describe()
# Out:
# 46871 ==> 44127
#                Price      bedrooms    bathrooms  nearestStation  \
# count   44127.000000  44127.000000  44127.00000    44127.000000
# mean   425224.642373      1.990981      1.18134        0.438522
# std    107203.332660      0.827621      0.40893        0.324152
# min    100000.000000      1.000000      1.00000        0.000000
# 25%    349950.000000      1.000000      1.00000        0.227551
# 50%    425000.000000      2.000000      1.00000        0.368351
# 75%    515000.000000      3.000000      1.00000        0.559486
# max    600000.000000      7.000000      5.00000        7.197700
#
#        location.latitude  location.longitude  latitude_deviation  \
# count       44127.000000        44127.000000        44127.000000
# mean           51.496711           -0.113106            0.064544
# std             0.077267            0.155863            0.042583
# min            51.298317           -0.498315            0.000000
# 25%            51.438303           -0.210633            0.029023
# 50%            51.498780           -0.101910            0.058904
# 75%            51.556343           -0.010854            0.094620
# max            51.683185            0.279726            0.201403
#
#        longitude_deviation  feature__1 bedroom  feature__2 bedrooms  ...  \
# count         44127.000000        44127.000000         44127.000000  ...
# mean              0.123699            0.011127             0.015251  ...
# std               0.095220            0.104897             0.122737  ...
# min               0.000000            0.000000             0.000000  ...
# 25%               0.043551            0.000000             0.000000  ...
# 50%               0.098750            0.000000             0.000000  ...
# 75%               0.191727            0.000000             0.000000  ...
# max               0.393895            1.000000             2.000000  ...
#
#        feature__reception room  feature__separate kitchen  \
# count             44127.000000               44127.000000
# mean                  0.014254                   0.020509
# std                   0.118921                   0.141735
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.000000
# 50%                   0.000000                   0.000000
# 75%                   0.000000                   0.000000
# max                   2.000000                   1.000000
#
#        feature__share of freehold  feature__three bedrooms  \
# count                44127.000000             44127.000000
# mean                     0.048428                 0.059374
# std                      0.214989                 0.236326
# min                      0.000000                 0.000000
# 25%                      0.000000                 0.000000
# 50%                      0.000000                 0.000000
# 75%                      0.000000                 0.000000
# max                      2.000000                 1.000000
#
#        feature__three double bedrooms  feature__top floor  \
# count                    44127.000000        44127.000000
# mean                         0.012804            0.013212
# std                          0.112429            0.114182
# min                          0.000000            0.000000
# 25%                          0.000000            0.000000
# 50%                          0.000000            0.000000
# 75%                          0.000000            0.000000
# max                          1.000000            1.000000
#
#        feature__two bathrooms  feature__two bedrooms  \
# count            44127.000000           44127.000000
# mean                 0.031976               0.072586
# std                  0.176195               0.259459
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  0.000000               0.000000
# max                  2.000000               1.000000
#
#        feature__two double bedrooms  feature__two reception rooms
# count                  44127.000000                  44127.000000
# mean                       0.096857                      0.016022
# std                        0.295919                      0.125561
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        2.000000                      1.000000
#
# [8 rows x 58 columns]

# %%
X_train, X_test, y_train, y_test, X_train_index, X_test_index, y_train_index, y_test_index, df_features, df_labels = create_train_test_data(
    df,
    categories=categories,
    RANDOM_STATE=RANDOM_STATE, return_index=True,
    drop_nulls=True,
    no_dummies=no_dummies
)

print(X_train[0])

if 'forest' in ALGORITHM.lower() or ALGORITHM.lower()=='light gradient boosting':
    y_train_orig = y_train
    y_train = y_train.ravel()
    print(y_train_orig, y_train)
    
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape, X_train_index.shape, X_test_index.shape,
      y_train_index.shape, y_test_index.shape)
# Out:
# [3.00000000e+00 3.00000000e+00 3.16613257e-01 5.14597600e+01
#  1.29390000e-01 3.99600000e-02 2.33810000e-01 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  0.00000000e+00]
# (39714, 61) (4413, 61) (39714, 1) (4413, 1) (39714, 1) (4413, 1) (39714, 1) (4413, 1)

# %%
#imputer = SimpleImputer(strategy='mean')
#imputer.fit(X_train[6])
#X_train[6] = imputer.transform(X_train[6])

# %%
starter_model = starter_pipe[-1]
default_model_params = starter_model.get_params()

print("default_model_params:\n", default_model_params)
print("---------------------")
print("sklearn.metrics.get_scorer_names():\n",sklearn.metrics.get_scorer_names())
# Out:
# default_model_params:
#  {'alpha': 1.0, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': 'deprecated', 'positive': False, 'random_state': None, 'solver': 'auto', 'tol': 0.001}
# ---------------------
# sklearn.metrics.get_scorer_names():
#  ['accuracy', 'adjusted_mutual_info_score', 'adjusted_rand_score', 'average_precision', 'balanced_accuracy', 'completeness_score', 'explained_variance', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'fowlkes_mallows_score', 'homogeneity_score', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted', 'matthews_corrcoef', 'max_error', 'mutual_info_score', 'neg_brier_score', 'neg_log_loss', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_gamma_deviance', 'neg_mean_poisson_deviance', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_median_absolute_error', 'neg_root_mean_squared_error', 'normalized_mutual_info_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'r2', 'rand_score', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'roc_auc', 'roc_auc_ovo', 'roc_auc_ovo_weighted', 'roc_auc_ovr', 'roc_auc_ovr_weighted', 'top_k_accuracy', 'v_measure_score']

# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage:
# * #### retrieve the hyperparameters for this model, and
# * #### train the model

# %%
options_block = get_hyperparameters(ALGORITHM, use_gpu, prefix='../../../')

if 'explore param' in DATA_DETAIL:
    def automl_step(param_options, vary):
        for key2, value in param_options.items():
            #print(key2, value, vary)
            if key2 != vary and key2 != 'model__' + vary:
                param_options[key2] = [param_options[key2][0]]
        return param_options

    #options_block = automl_step(options_block, "model__epochs")
    explore_param = "alpha"
    options_block = automl_step(options_block, explore_param)

param_options, cv, n_jobs, refit, n_iter, verbose = get_cv_params(options_block, debug_mode=debug_mode,
                                                                  override_cv=OVERRIDE_CV,
                                                                  override_niter=OVERRIDE_N_ITER,
                                                                  override_njobs=OVERRIDE_JOBS)

if 'forest' in ALGORITHM.lower() or True: #JH
    verbose = 2

print("cv:", cv, "n_jobs:", n_jobs, "refit:", refit, "n_iter:", n_iter, "verbose:", verbose)

if not_catboost and len(param_options.keys()) > 2 and not already_timed and debug_mode:
    already_timed = True
    # %timeit starter_pipe.fit(X_train, y_train)


print('\n\nHyperparameters:')
param_options if not_catboost else options_block
# Out:
# cv: 3 n_jobs: 3 refit: True n_iter: 15 verbose: 2
#
#
# Hyperparameters:
# {'model__alpha': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
#  'model__fit_intercept': [True, False],
#  'model__max_iter': [10000, 1000, 100, 100000, 1000000],
#  'model__positive': [False],
#  'model__copy_X': [True, False],
#  'model__solver': ['auto',
#   'svd',
#   'cholesky',
#   'lsqr',
#   'sparse_cg',
#   'sag',
#   'saga',
#   'lbfgs'],
#  'model__tol': [1e-05, 0.0001, 0.001, 0.01],
#  'model__random_state': [101]}

# %%
def fit_model_with_cross_validation(gs, X_train, y_train, fits):
    pipe_start = time()
    cv_result = gs.fit(X_train, y_train)
    gs.fit(X_train, y_train)
    pipe_end = time()
    average_time = round((pipe_end - pipe_start) / (fits), 2)

    print(f"Total fit/CV time      : {int(pipe_end - pipe_start)} seconds   ({pipe_start} ==> {pipe_end})")
    print()
    print(
        f'average fit/score time = {round(cv_result.cv_results_["mean_fit_time"].mean(), 2)}s/{round(cv_result.cv_results_["mean_score_time"].mean(), 2)}s')
    print(
        f'max fit/score time     = {round(cv_result.cv_results_["mean_fit_time"].max(), 2)}s/{round(cv_result.cv_results_["mean_score_time"].max(), 2)}s')
    print(f'refit time             = {round(cv_result.refit_time_, 2)}s')

    #return cv_result, average_time, cv_result.refit_time_, len(cv_result.cv_results_["mean_fit_time"])
    return average_time, cv_result.refit_time_, len(cv_result.cv_results_["mean_fit_time"])


if not_catboost:
    if ALGORITHM_DETAIL == 'grid search':
        crossval_runner = GridSearchCV(
            estimator=starter_pipe,
            param_grid=param_options,
            cv=cv, n_jobs=n_jobs, # get the AVX/AVX2 info if use n_jobs > 2
            verbose=verbose, scoring=CROSS_VALIDATION_SCORING,
            refit=refit,
            return_train_score=True, #n_iter=n_iter,
            #error_score='raise'
        )
    else:
        crossval_runner = RandomizedSearchCV(
            estimator=starter_pipe,
            param_distributions=param_options,
            cv=cv, n_jobs=n_jobs,  # get the AVX/AVX2 info if use n_jobs > 2
            verbose=verbose, scoring=CROSS_VALIDATION_SCORING,
            refit=refit,
            return_train_score=True,  #n_iter=n_iter,
            n_iter=n_iter,  # 1, #3
            #error_score='raise'
    )
    cv_average_fit_time, cv_best_model_fit_time, total_fits = fit_model_with_cross_validation(
        crossval_runner, X_train, y_train, fits=cv * n_iter)

else:
    from catboost import CatBoostRegressor, Pool

    #pool = Pool(df, cat_features=['tenure.tenureType'], label=df['Price'].values)
    pool_Xtrain = Pool(X_train, cat_features=[7], label=y_train)
    #pool_Xtest = Pool(X_train, cat_features=[7], label=y_train)
    pool_Xtest = Pool(X_test, cat_features=[7], label=y_test)
    import sys
    starter_model = model=CatBoostRegressor(iterations=3, depth=3, learning_rate=0.1, loss_function='RMSE', objective='RMSE')

    output = starter_model.randomized_search(options_block, # param_options,
                                    X=pool_Xtrain, # X_train,
                                    #y=y_train,
                                    #cat_features=[],
                                    cv=5,
                                    n_iter=100,
                                    partition_random_seed=101,
                                    calc_cv_statistics=True,
                                    #search_by_train_test_split=True,
                                    refit=True,
                                    shuffle=True,
                                    stratified=None,
                                    #train_size=0.8,
                                    #train_size=1,
                                    verbose=True,
                                    plot=True,
                                    log_cout=sys.stdout,
                                    log_cerr=sys.stderr)

    cat_params, cat_cv_results = output['params'], output['cv_results']
    crossval_runner = {"best_params_": cat_params, "cv_results_": cat_cv_results, "best_estimator_": None}
crossval_runner
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.3s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   1.2s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.001; total time=   2.0s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.7s
# [CV] END model__alpha=0.0001, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.01; total time=   0.5s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=auto, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=auto, model__tol=1e-05; total time=   0.2s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.1s
# [CV] END model__alpha=1000, model__copy_X=True, model__fit_intercept=True, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   0.7s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   0.9s
# [CV] END model__alpha=1, model__copy_X=True, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.5s
# [CV] END model__alpha=1, model__copy_X=True, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.6s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.001; total time=   0.9s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   1.0s
# [CV] END model__alpha=1000, model__copy_X=True, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.001; total time=   0.2s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=1, model__copy_X=True, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.0001; total time=   0.2s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=0.0001, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.0001; total time=   0.8s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.1s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.1s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.1s
# [CV] END model__alpha=1e-05, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=1e-05; total time=   0.3s
# [CV] END model__alpha=1e-05, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=1e-05; total time=   0.3s
# [CV] END model__alpha=100, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   0.5s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.4s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   2.2s
# [CV] END model__alpha=1, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.001; total time=   0.5s
# [CV] END model__alpha=1, model__copy_X=False, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=1e-05; total time=   0.2s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.4s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   1.2s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.001; total time=   3.9s
# [CV] END model__alpha=1000, model__copy_X=True, model__fit_intercept=True, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   0.8s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   0.5s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=1, model__copy_X=True, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.5s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.001; total time=   0.7s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.001; total time=   0.7s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   1.3s
# [CV] END model__alpha=1000, model__copy_X=True, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.001; total time=   0.3s
# [CV] END model__alpha=1, model__copy_X=True, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.0001; total time=   0.2s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=0.0001, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.0001; total time=   1.1s
# [CV] END model__alpha=1e-05, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=1e-05; total time=   0.4s
# [CV] END model__alpha=100, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=1000, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   0.6s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.4s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   1.5s
# [CV] END model__alpha=1, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.001; total time=   0.7s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=10, model__copy_X=True, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   0.3s
# [CV] END model__alpha=10, model__copy_X=True, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   0.5s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   1.5s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   4.0s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=auto, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=auto, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=auto, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=0.1, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.001; total time=   0.5s
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 6 fits failed out of a total of 45.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py", line 1130, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py", line 806, in fit
#     raise ValueError(
# ValueError: 'lbfgs' solver can be used only when positive=True. Please use another solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [         nan -15.23944146   0.46850246          nan -15.23945465
#    0.46850237 -15.23944144 -15.23943168   0.46850204   0.46850237
#    0.46850241 -15.23944146 -15.23945562 -15.23943171   0.46849652]
#   warnings.warn(
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the train scores are non-finite: [         nan -15.2340358    0.47139012          nan -15.23405018
#    0.47139012 -15.2340358  -15.23404711   0.47139012   0.47139012
#    0.47139012 -15.2340358  -15.23405028 -15.23404711   0.47138997]
#   warnings.warn(
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.3s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   1.2s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.001; total time=   0.9s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.6s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.5s
# [CV] END model__alpha=0.0001, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.01; total time=   0.7s
# [CV] END model__alpha=0.0001, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.01; total time=   0.7s
# [CV] END model__alpha=10, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=auto, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=0.0001; total time=   0.1s
# [CV] END model__alpha=1000, model__copy_X=True, model__fit_intercept=True, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   1.1s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   3.4s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   2.0s
# [CV] END model__alpha=1000, model__copy_X=True, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.001; total time=   0.2s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=1, model__copy_X=True, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.0001; total time=   0.2s
# [CV] END model__alpha=0.001, model__copy_X=True, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=0.0001, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=0.01; total time=   0.1s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.0001; total time=   2.2s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.0001; total time=   0.5s
# [CV] END model__alpha=0.01, model__copy_X=True, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.01; total time=   0.3s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   1.0s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=100, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.0s
# [CV] END model__alpha=1, model__copy_X=False, model__fit_intercept=False, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.001; total time=   0.5s
# [CV] END model__alpha=1, model__copy_X=False, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sparse_cg, model__tol=1e-05; total time=   0.2s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=0.001; total time=   0.1s
# [CV] END model__alpha=10, model__copy_X=True, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   1.8s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=True, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=0.0001; total time=   0.1s
# [CV] END model__alpha=0.0001, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=1e-05; total time=   3.0s
# [CV] END model__alpha=0.1, model__copy_X=False, model__fit_intercept=True, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.01; total time=   0.5s
# [CV] END model__alpha=0.0001, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   0.6s
# [CV] END model__alpha=0.0001, model__copy_X=False, model__fit_intercept=False, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=sag, model__tol=0.01; total time=   2.0s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=False, model__max_iter=100, model__positive=False, model__random_state=101, model__solver=cholesky, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=0.001, model__copy_X=False, model__fit_intercept=False, model__max_iter=1000, model__positive=False, model__random_state=101, model__solver=lsqr, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=0.0001, model__copy_X=False, model__fit_intercept=True, model__max_iter=100000, model__positive=False, model__random_state=101, model__solver=svd, model__tol=0.001; total time=   0.5s
# [CV] END model__alpha=1000, model__copy_X=True, model__fit_intercept=False, model__max_iter=1000000, model__positive=False, model__random_state=101, model__solver=lbfgs, model__tol=1e-05; total time=   0.1s
# [CV] END model__alpha=0.01, model__copy_X=False, model__fit_intercept=True, model__max_iter=10000, model__positive=False, model__random_state=101, model__solver=saga, model__tol=0.001; total time=   0.5s
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 6 fits failed out of a total of 45.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py", line 1130, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "/home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py", line 806, in fit
#     raise ValueError(
# ValueError: 'lbfgs' solver can be used only when positive=True. Please use another solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [-15.23944146 -15.23944288   0.46850236          nan   0.46849651
#  -15.2401518  -15.23944105   0.46850236   0.46850292   0.46850292
#    0.46850344          nan   0.4685016  -15.23944288   0.46850104]
#   warnings.warn(
# /home/guava/PycharmProjects/capstone_streamlit/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the train scores are non-finite: [-15.2340358  -15.23403582   0.47139012          nan   0.47138997
#  -15.23501027 -15.2340358    0.47139012   0.47137882   0.47137882
#    0.47139001          nan   0.47139001 -15.23403582   0.47139005]
#   warnings.warn(
# Total fit/CV time      : 15 seconds   (1670005501.646118 ==> 1670005517.0908952)
#
# average fit/score time = 0.34s/0.01s
# max fit/score time     = 1.59s/0.02s
# refit time             = 0.37s
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('std_scaler', StandardScaler()),
#                                              ('model', Ridge())]),
#                    n_iter=15, n_jobs=3,
#                    param_distributions={'model__alpha': [1e-05, 0.0001, 0.001,
#                                                          0.01, 0.1, 1, 10, 100,
#                                                          1000],
#                                         'model__copy_X': [True, False],
#                                         'model__fit_intercept': [True, False],
#                                         'model__max_iter': [10000, 1000, 100,
#                                                             100000, 1000000],
#                                         'model__positive': [False],
#                                         'model__random_state': [101],
#                                         'model__solver': ['auto', 'svd',
#                                                           'cholesky', 'lsqr',
#                                                           'sparse_cg', 'sag',
#                                                           'saga', 'lbfgs'],
#                                         'model__tol': [1e-05, 0.0001, 0.001,
#                                                        0.01]},
#                    return_train_score=True, scoring='r2', verbose=2)

# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage: Get the results and print some graphs

# %%
if not_catboost:
    best_estimator_pipe = crossval_runner.best_estimator_

    if not_catboost and debug_mode:
        crossval_runner.cv_results_

# %%
starter_model
if True:
    print(starter_model)
if not not_catboost:
    print(cat_params)
    print(cat_cv_results)
# Out:
# Ridge()

# %%
if not_catboost:
    crossval_runner.best_params_
else:
    crossval_runner["best_params_"]

# %%
if not_catboost:
    cv_results_df = pd.DataFrame(crossval_runner.cv_results_).sort_values('rank_test_score')

cv_results_df if not_catboost else ''
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 10       0.273845      0.020942         0.009153        0.002008
# 8        0.252600      0.011983         0.007238        0.000292
# 9        0.216481      0.003023         0.007291        0.000265
# 7        0.070162      0.007033         0.012378        0.003570
# 2        0.462080      0.111768         0.011756        0.001334
# 12       0.479358      0.074229         0.007814        0.001593
# 14       0.463967      0.089707         0.006078        0.000734
# 4        0.431027      0.051737         0.008048        0.001607
# 6        1.585500      0.575728         0.011412        0.001431
# 0        0.125551      0.022233         0.014282        0.005456
# 1        0.133611      0.022043         0.015889        0.005674
# 13       0.067224      0.002179         0.009155        0.001525
# 5        0.372819      0.004957         0.007751        0.001395
# 3        0.052027      0.001445         0.000000        0.000000
# 11       0.041852      0.002752         0.000000        0.000000
#
#    param_model__tol param_model__solver param_model__random_state  \
# 10             0.01                 svd                       101
# 8              0.01                 svd                       101
# 9            0.0001                 svd                       101
# 7             0.001            cholesky                       101
# 2             0.001                 svd                       101
# 12           0.0001                saga                       101
# 14            0.001                 sag                       101
# 4             0.001                saga                       101
# 6           0.00001                 sag                       101
# 0           0.00001            cholesky                       101
# 1           0.00001                lsqr                       101
# 13          0.00001                lsqr                       101
# 5             0.001                saga                       101
# 3           0.00001               lbfgs                       101
# 11          0.00001               lbfgs                       101
#
#    param_model__positive param_model__max_iter param_model__fit_intercept  \
# 10                 False                100000                       True
# 8                  False                   100                       True
# 9                  False                  1000                       True
# 7                  False                   100                       True
# 2                  False                100000                       True
# 12                 False                  1000                       True
# 14                 False               1000000                       True
# 4                  False                 10000                       True
# 6                  False                  1000                      False
# 0                  False                   100                      False
# 1                  False                  1000                      False
# 13                 False                100000                      False
# 5                  False                 10000                      False
# 3                  False               1000000                      False
# 11                 False                  1000                      False
#
#     ... split1_test_score split2_test_score mean_test_score  std_test_score  \
# 10  ...          0.469186          0.470766        0.468503        0.002180
# 8   ...          0.469200          0.470813        0.468503        0.002227
# 9   ...          0.469200          0.470813        0.468503        0.002227
# 7   ...          0.469183          0.470759        0.468502        0.002175
# 2   ...          0.469183          0.470759        0.468502        0.002175
# 12  ...          0.469181          0.470765        0.468502        0.002179
# 14  ...          0.469187          0.470755        0.468501        0.002175
# 4   ...          0.469176          0.470757        0.468497        0.002177
# 6   ...        -15.284632        -15.126242      -15.239441        0.080584
# 0   ...        -15.284633        -15.126242      -15.239441        0.080584
# 1   ...        -15.284637        -15.126255      -15.239443        0.080575
# 13  ...        -15.284637        -15.126255      -15.239443        0.080575
# 5   ...        -15.282081        -15.129955      -15.240152        0.078660
# 3   ...               NaN               NaN             NaN             NaN
# 11  ...               NaN               NaN             NaN             NaN
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 10                1            0.472739            0.471119
# 8                 2            0.472728            0.471107
# 9                 2            0.472728            0.471107
# 7                 4            0.472739            0.471119
# 2                 5            0.472739            0.471119
# 12                6            0.472738            0.471119
# 14                7            0.472739            0.471119
# 4                 8            0.472738            0.471119
# 6                 9          -15.206562          -15.215542
# 0                10          -15.206562          -15.215542
# 1                11          -15.206562          -15.215542
# 13               12          -15.206562          -15.215542
# 5                13          -15.207516          -15.216519
# 3                14                 NaN                 NaN
# 11               15                 NaN                 NaN
#
#     split2_train_score  mean_train_score  std_train_score
# 10            0.470313          0.471390         0.001009
# 8             0.470301          0.471379         0.001009
# 9             0.470301          0.471379         0.001009
# 7             0.470313          0.471390         0.001009
# 2             0.470313          0.471390         0.001009
# 12            0.470313          0.471390         0.001009
# 14            0.470313          0.471390         0.001009
# 4             0.470313          0.471390         0.001009
# 6           -15.280003        -15.234036         0.032710
# 0           -15.280003        -15.234036         0.032710
# 1           -15.280003        -15.234036         0.032710
# 13          -15.280003        -15.234036         0.032710
# 5           -15.280996        -15.235010         0.032724
# 3                  NaN               NaN              NaN
# 11                 NaN               NaN              NaN
#
# [15 rows x 24 columns]

# %%
if not_catboost and debug_mode:
    xx = [c for c in cv_results_df.columns if 'param' in c]
    xx.insert(0, 'rank_test_score')
    xx.insert(0, 'mean_test_score')
cv_results_df[xx].head(7) if not_catboost and debug_mode else ''
# Out:
# ''

# %%
cv_results_df[xx].tail(7) if not_catboost and debug_mode else ''
# Out:
# ''

# %%
key = f'{ALGORITHM} (v{VERSION})'.lower()

if not_catboost:
    cv_results_df['params2'] = cv_results_df['params'].apply(lambda l: '/'.join([str(c) for c in l.values()]))

    cv_columns = ['params2', 'rank_test_score', 'mean_test_score', 'mean_fit_time', 'mean_score_time', 'params']
    # if 'Neural' not in ALGORITHM:
    #     cv_columns.insert(2, 'mean_train_score')
    cv_results_df_full_sorted = cv_results_df.sort_values('rank_test_score')[cv_columns].reset_index(drop=True)


cv_results_df_full_sorted if not_catboost else ''
# Out:
#                                           params2  rank_test_score  \
# 0          0.01/svd/101/False/100000/True/True/10                1
# 1            0.01/svd/101/False/100/True/True/100                2
# 2         0.0001/svd/101/False/1000/True/True/100                2
# 3    0.001/cholesky/101/False/100/True/True/0.001                4
# 4    0.001/svd/101/False/100000/True/False/0.0001                5
# 5        0.0001/saga/101/False/1000/True/False/10                6
# 6        0.001/sag/101/False/1000000/True/False/1                7
# 7      0.001/saga/101/False/10000/True/False/0.01                8
# 8       1e-05/sag/101/False/1000/False/True/0.001                9
# 9   1e-05/cholesky/101/False/100/False/False/0.01               10
# 10    1e-05/lsqr/101/False/1000/False/False/0.001               11
# 11  1e-05/lsqr/101/False/100000/False/False/1e-05               12
# 12     0.001/saga/101/False/10000/False/True/1000               13
# 13  1e-05/lbfgs/101/False/1000000/False/True/1000               14
# 14     1e-05/lbfgs/101/False/1000/False/False/100               15
#
#     mean_test_score  mean_fit_time  mean_score_time  \
# 0          0.468503       0.273845         0.009153
# 1          0.468503       0.252600         0.007238
# 2          0.468503       0.216481         0.007291
# 3          0.468502       0.070162         0.012378
# 4          0.468502       0.462080         0.011756
# 5          0.468502       0.479358         0.007814
# 6          0.468501       0.463967         0.006078
# 7          0.468497       0.431027         0.008048
# 8        -15.239441       1.585500         0.011412
# 9        -15.239441       0.125551         0.014282
# 10       -15.239443       0.133611         0.015889
# 11       -15.239443       0.067224         0.009155
# 12       -15.240152       0.372819         0.007751
# 13              NaN       0.052027         0.000000
# 14              NaN       0.041852         0.000000
#
#                                                params
# 0   {'model__tol': 0.01, 'model__solver': 'svd', '...
# 1   {'model__tol': 0.01, 'model__solver': 'svd', '...
# 2   {'model__tol': 0.0001, 'model__solver': 'svd',...
# 3   {'model__tol': 0.001, 'model__solver': 'choles...
# 4   {'model__tol': 0.001, 'model__solver': 'svd', ...
# 5   {'model__tol': 0.0001, 'model__solver': 'saga'...
# 6   {'model__tol': 0.001, 'model__solver': 'sag', ...
# 7   {'model__tol': 0.001, 'model__solver': 'saga',...
# 8   {'model__tol': 1e-05, 'model__solver': 'sag', ...
# 9   {'model__tol': 1e-05, 'model__solver': 'choles...
# 10  {'model__tol': 1e-05, 'model__solver': 'lsqr',...
# 11  {'model__tol': 1e-05, 'model__solver': 'lsqr',...
# 12  {'model__tol': 0.001, 'model__solver': 'saga',...
# 13  {'model__tol': 1e-05, 'model__solver': 'lbfgs'...
# 14  {'model__tol': 1e-05, 'model__solver': 'lbfgs'...

# %%
if not_catboost:

    cv_results_df_sorted = cv_results_df_full_sorted[cv_results_df_full_sorted['mean_test_score'] > -2]
    if len(cv_results_df_sorted) != len(cv_results_df_full_sorted):
        print(-len(cv_results_df_sorted) + len(cv_results_df_full_sorted), "fits were total failures")
        total_fits = len(cv_results_df_sorted)

cv_results_df_sorted if not_catboost else ''
# Out:
# 7 fits were total failures
#                                         params2  rank_test_score  \
# 0        0.01/svd/101/False/100000/True/True/10                1
# 1          0.01/svd/101/False/100/True/True/100                2
# 2       0.0001/svd/101/False/1000/True/True/100                2
# 3  0.001/cholesky/101/False/100/True/True/0.001                4
# 4  0.001/svd/101/False/100000/True/False/0.0001                5
# 5      0.0001/saga/101/False/1000/True/False/10                6
# 6      0.001/sag/101/False/1000000/True/False/1                7
# 7    0.001/saga/101/False/10000/True/False/0.01                8
#
#    mean_test_score  mean_fit_time  mean_score_time  \
# 0         0.468503       0.273845         0.009153
# 1         0.468503       0.252600         0.007238
# 2         0.468503       0.216481         0.007291
# 3         0.468502       0.070162         0.012378
# 4         0.468502       0.462080         0.011756
# 5         0.468502       0.479358         0.007814
# 6         0.468501       0.463967         0.006078
# 7         0.468497       0.431027         0.008048
#
#                                               params
# 0  {'model__tol': 0.01, 'model__solver': 'svd', '...
# 1  {'model__tol': 0.01, 'model__solver': 'svd', '...
# 2  {'model__tol': 0.0001, 'model__solver': 'svd',...
# 3  {'model__tol': 0.001, 'model__solver': 'choles...
# 4  {'model__tol': 0.001, 'model__solver': 'svd', ...
# 5  {'model__tol': 0.0001, 'model__solver': 'saga'...
# 6  {'model__tol': 0.001, 'model__solver': 'sag', ...
# 7  {'model__tol': 0.001, 'model__solver': 'saga',...

# %%
#pd.set_option('display.max_columns', None)

# %%
if not_catboost:
    orig_debug_mode, orig_display_df_cols = debug_mode, pd.get_option('display.max_columns')
    debug_mode = True
    pd.set_option('display.max_columns', None)
    if debug_mode:
        debug_cols = ['rank_test_score', 'mean_test_score', 'mean_fit_time', 'mean_score_time']
        debug_cols.extend([c for c in cv_results_df.columns if 'param' in c and c != 'params'])

    cv_results_df_summary = cv_results_df[debug_cols].head(7)
    cv_results_df_summary.set_index('rank_test_score', inplace=True)

cv_results_df_summary if debug_mode else ''
# Out:
#                  mean_test_score  mean_fit_time  mean_score_time  \
# rank_test_score
# 1                       0.468503       0.273845         0.009153
# 2                       0.468503       0.252600         0.007238
# 2                       0.468503       0.216481         0.007291
# 4                       0.468502       0.070162         0.012378
# 5                       0.468502       0.462080         0.011756
# 6                       0.468502       0.479358         0.007814
# 7                       0.468501       0.463967         0.006078
#
#                 param_model__tol param_model__solver  \
# rank_test_score
# 1                           0.01                 svd
# 2                           0.01                 svd
# 2                         0.0001                 svd
# 4                          0.001            cholesky
# 5                          0.001                 svd
# 6                         0.0001                saga
# 7                          0.001                 sag
#
#                 param_model__random_state param_model__positive  \
# rank_test_score
# 1                                     101                 False
# 2                                     101                 False
# 2                                     101                 False
# 4                                     101                 False
# 5                                     101                 False
# 6                                     101                 False
# 7                                     101                 False
#
#                 param_model__max_iter param_model__fit_intercept  \
# rank_test_score
# 1                              100000                       True
# 2                                 100                       True
# 2                                1000                       True
# 4                                 100                       True
# 5                              100000                       True
# 6                                1000                       True
# 7                             1000000                       True
#
#                 param_model__copy_X param_model__alpha  \
# rank_test_score
# 1                              True                 10
# 2                              True                100
# 2                              True                100
# 4                              True              0.001
# 5                             False             0.0001
# 6                             False                 10
# 7                             False                  1
#
#                                                       params2
# rank_test_score
# 1                      0.01/svd/101/False/100000/True/True/10
# 2                        0.01/svd/101/False/100/True/True/100
# 2                     0.0001/svd/101/False/1000/True/True/100
# 4                0.001/cholesky/101/False/100/True/True/0.001
# 5                0.001/svd/101/False/100000/True/False/0.0001
# 6                    0.0001/saga/101/False/1000/True/False/10
# 7                    0.001/sag/101/False/1000000/True/False/1

# %%
if not_catboost:
    debug_mode = orig_debug_mode
    pd.set_option('display.max_columns', orig_display_df_cols)

# %%
if not_catboost:
    def print_results(cross_validation_result):
        means = cross_validation_result.cv_results_['mean_test_score']
        stds = cross_validation_result.cv_results_['std_test_score']
        params = cross_validation_result.cv_results_['params']
        times = cross_validation_result.cv_results_['std_test_score']

        print("params:" + "/".join([c.replace("model__", "") for c in params[0].keys()]))
        print()
        for mean, std, param, time in zip(means, stds, params, times):
            #param2 = "/".join(list(param.values()))
            param2 = "/".join(list([str(c) for c in param.values()]))
            print(f'{round(mean, 3)} (+/-{round(std * 2, 3)}) in {round(time, 4)}s for {param2}')


print_results(crossval_runner) if debug_mode else ''
# Out:
# ''

# %%
#pool_Xtest.shape
#pool_Xtrain.shape
X_train[0]
X_test[0]
# Out:
# array([ 1.000000e+00,  1.000000e+00,  6.959676e-01,  5.147824e+01,
#        -8.707000e-02,  2.148000e-02,  1.735000e-02,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  1.000000e+00,
#         0.000000e+00])

# %%
if not_catboost:
    y_pred = best_estimator_pipe.predict(X_test)
else:
    y_pred = starter_model.predict(pool_Xtest)

# %%
r_2_score = r2_score(y_test, y_pred)
if not_catboost:
    score = r_2_score
    default_score = best_estimator_pipe.score(X_test, y_test)
else:
    score = r_2_score
    default_score = starter_model.score(X_test, y_test)
score
# Out:
# 0.4707818387829007

# %%
y_pred = y_pred.reshape((-1, 1))

R2 = r_2_score
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = math.sqrt(MSE)
print('-' * 10 + ALGORITHM + '-' * 10)
print('R square Accuracy', R2)
print('Mean Absolute Error Accuracy', MAE)
print('Mean Squared Error Accuracy', MSE)
print('Root Mean Squared Error', RMSE)
# Out:
# ----------Linear Regression (Ridge)----------
# R square Accuracy 0.4707818387829007
# Mean Absolute Error Accuracy 62597.27585807666
# Mean Squared Error Accuracy 5978263015.241543
# Root Mean Squared Error 77319.22797882518

# %%
if debug_mode:
    print(y_test_index.reshape((-1, 1)).shape);
    print(y_pred.reshape((-1, 1)).shape);
    print(y_test.shape);
    print(y_test_index.shape);
    print(y_pred.shape);
    print(y_test.shape)

# %%
compare = np.hstack((y_test_index, y_test, y_pred))
compare_df = DataFrame(compare, columns=['reference', 'actual', 'predicted'])
compare_df['difference'] = abs(compare_df['actual'] - compare_df['predicted'])
compare_df['diff 1 %'] = abs((compare_df['actual'] - compare_df['predicted']) / compare_df['actual'] * 100)
compare_df['diff 2 %'] = abs((compare_df['actual'] - compare_df['predicted']) / compare_df['predicted']) * 100
compare_df['reference'] = compare_df['reference'].astype(int)
compare_df.set_index('reference', inplace=True)
compare_df
# Out:
#              actual      predicted     difference   diff 1 %   diff 2 %
# reference
# 85490754   400000.0  407851.869675    7851.869675   1.962967   1.925177
# 119328242  369950.0  337311.535296   32638.464704   8.822399   9.676059
# 125716790  350000.0  421024.629275   71024.629275  20.292751  16.869471
# 122440040  549000.0  464053.344005   84946.655995  15.472979  18.305364
# 120508103  495000.0  500401.426013    5401.426013   1.091197   1.079419
# ...             ...            ...            ...        ...        ...
# 68620869   475000.0  535902.383608   60902.383608  12.821554  11.364455
# 85735665   575000.0  648215.205896   73215.205896  12.733079  11.294892
# 125706338  400000.0  418777.710474   18777.710474   4.694428   4.483933
# 112739354  450000.0  511860.904651   61860.904651  13.746868  12.085491
# 122707001  275000.0  412704.740620  137704.740620  50.074451  33.366406
#
# [4413 rows x 5 columns]

# %%
combined = compare_df.merge(df[columns], how='inner', left_index=True, right_index=True).sort_values(['diff 1 %'],
                                                                                                     ascending=False)
#pd.options.display.float_format = '{:.4f}'.format
combined[['predicted', 'actual', 'Price', 'bedrooms', 'bathrooms']] = combined[
    ['predicted', 'actual', 'Price', 'bedrooms', 'bathrooms']].astype(int)
combined['bedrooms'] = combined['bedrooms'].astype(int)
combined
# Out:
#            actual  predicted     difference    diff 1 %   diff 2 %   Price  \
# 122265818  160000     585106  425106.669623  265.691669  72.654559  160000
# 85667184   122000     369945  247945.121512  203.233706  67.022136  122000
# 109722224  108000     325373  217373.698972  201.271943  66.807397  108000
# 83639617   190000     439075  249075.346361  131.092288  56.727245  190000
# 85536395   230000     486014  256014.557584  111.310677  52.676315  230000
# ...           ...        ...            ...         ...        ...     ...
# 121142594  550000     549798     201.158815    0.036574   0.036588  550000
# 85595439   350000     349898     101.361810    0.028961   0.028969  350000
# 124349789  399950     399861      88.202915    0.022053   0.022058  399950
# 125029556  277500     277462      37.344683    0.013458   0.013459  277500
# 121493438  425000     425043      43.394542    0.010210   0.010209  425000
#
#            bedrooms  bathrooms  nearestStation  location.latitude  \
# 122265818         3          1        0.166024          51.510420
# 85667184          1          1        0.838896          51.540462
# 109722224         1          1        0.302667          51.406803
# 83639617          2          2        0.162816          51.491264
# 85536395          2          2        0.162859          51.362150
# ...             ...        ...             ...                ...
# 121142594         3          2        0.517776          51.397980
# 85595439          2          1        0.197553          51.651395
# 124349789         2          1        0.102379          51.392490
# 125029556         1          1        0.496114          51.502880
# 121493438         2          1        0.778270          51.602871
#
#            location.longitude  latitude_deviation  longitude_deviation  \
# 122265818           -0.037730            0.010700             0.066690
# 85667184            -0.280301            0.040742             0.175881
# 109722224           -0.261328            0.092917             0.156908
# 83639617             0.064660            0.008456             0.169080
# 85536395            -0.150440            0.137570             0.046020
# ...                       ...                 ...                  ...
# 121142594           -0.112410            0.101740             0.007990
# 85595439            -0.094822            0.151675             0.009598
# 124349789           -0.302166            0.107230             0.197746
# 125029556           -0.474902            0.003160             0.370482
# 121493438           -0.142737            0.103151             0.038317
#
#            tenure.tenureType
# 122265818           FREEHOLD
# 85667184           LEASEHOLD
# 109722224          LEASEHOLD
# 83639617           LEASEHOLD
# 85536395            FREEHOLD
# ...                      ...
# 121142594           FREEHOLD
# 85595439           LEASEHOLD
# 124349789  SHARE_OF_FREEHOLD
# 125029556          LEASEHOLD
# 121493438          LEASEHOLD
#
# [4413 rows x 14 columns]

# %%
best_model_fig, best_model_ax = plt.subplots()
best_model_ax.scatter(y_test, y_pred, edgecolors=(0, 0, 1))
best_model_ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
best_model_ax.set_ylabel('Predicted')
best_model_ax.set_xlabel('Actual')
#ax.title.set_text(f'CV Chosen best option ({calculated_best_pipe[1]})')

plt.show()

# %%
if not_catboost:
    def custom_model_and_predictions(model, graph_params, X_train, y_train, X_test):
        graph_model = model
        graph_model.set_params(**graph_params)
        graph_model.fit(X_train, y_train)
        y_pred_graph = model.predict(X_test)

        return model, y_pred_graph


    best_model_count = 10 if not quick_mode else 2
    best_model_count = 3 if not quick_mode else 1
    best_models = {}
    best_model_predictions = {}
    best_model_scores = {}

    showable_increment = total_fits // (4 if not quick_mode else 2)
    if showable_increment==0:showable_increment=1
    for i in range(0, total_fits, showable_increment):
        if debug_mode or True: print(f'{i} ==> {i}')

        if i == 0:
            fitted_graph_model = crossval_runner.best_estimator_
            y_pred_graph = y_pred
        else:
            graph_pipe_params = cv_results_df_sorted['params'][i]
            print(graph_pipe_params)
            # would always return the best! graph_pipe_params = cv_results_df_sorted.loc[cv_results_df_sorted['rank_test_score'] == 1, 'params'].values[0]

            graph_params = {}
            for key2, value in graph_pipe_params.items():
                graph_params[key2.replace('model__', '')] = value

            fitted_graph_model, y_pred_graph = custom_model_and_predictions(make_pipeline(), graph_pipe_params, X_train,
                                                                            y_train, X_test)

        best_models[i] = fitted_graph_model[-1].get_params()
        best_model_predictions[i] = y_pred_graph
        best_model_scores[i] = fitted_graph_model.score(X_test, y_test)

    if debug_mode or True: print(f'{-1} ==> {-1}')
    graph_pipe_params = cv_results_df_sorted['params'][total_fits - 1]
    print(graph_pipe_params)
    graph_params = {}
    for key2, value in graph_pipe_params.items():
        graph_params[key2.replace('model__', '')] = value
    fitted_graph_model, y_pred_graph = custom_model_and_predictions(make_pipeline(), graph_pipe_params, X_train,
                                                                    y_train, X_test)
    best_models[-1] = fitted_graph_model[-1].get_params()
    best_model_predictions[-1] = y_pred_graph
    best_model_scores[-1] = fitted_graph_model.score(X_test, y_test)
# Out:
# 0 ==> 0
# 2 ==> 2
# {'model__tol': 0.0001, 'model__solver': 'svd', 'model__random_state': 101, 'model__positive': False, 'model__max_iter': 1000, 'model__fit_intercept': True, 'model__copy_X': True, 'model__alpha': 100}
# 4 ==> 4
# {'model__tol': 0.001, 'model__solver': 'svd', 'model__random_state': 101, 'model__positive': False, 'model__max_iter': 100000, 'model__fit_intercept': True, 'model__copy_X': False, 'model__alpha': 0.0001}
# 6 ==> 6
# {'model__tol': 0.001, 'model__solver': 'sag', 'model__random_state': 101, 'model__positive': False, 'model__max_iter': 1000000, 'model__fit_intercept': True, 'model__copy_X': False, 'model__alpha': 1}
# -1 ==> -1
# {'model__tol': 0.001, 'model__solver': 'saga', 'model__random_state': 101, 'model__positive': False, 'model__max_iter': 10000, 'model__fit_intercept': True, 'model__copy_X': False, 'model__alpha': 0.01}

# %%
cv_results_df_sorted if not_catboost else ''
# Out:
#                                         params2  rank_test_score  \
# 0        0.01/svd/101/False/100000/True/True/10                1
# 1          0.01/svd/101/False/100/True/True/100                2
# 2       0.0001/svd/101/False/1000/True/True/100                2
# 3  0.001/cholesky/101/False/100/True/True/0.001                4
# 4  0.001/svd/101/False/100000/True/False/0.0001                5
# 5      0.0001/saga/101/False/1000/True/False/10                6
# 6      0.001/sag/101/False/1000000/True/False/1                7
# 7    0.001/saga/101/False/10000/True/False/0.01                8
#
#    mean_test_score  mean_fit_time  mean_score_time  \
# 0         0.468503       0.273845         0.009153
# 1         0.468503       0.252600         0.007238
# 2         0.468503       0.216481         0.007291
# 3         0.468502       0.070162         0.012378
# 4         0.468502       0.462080         0.011756
# 5         0.468502       0.479358         0.007814
# 6         0.468501       0.463967         0.006078
# 7         0.468497       0.431027         0.008048
#
#                                               params
# 0  {'model__tol': 0.01, 'model__solver': 'svd', '...
# 1  {'model__tol': 0.01, 'model__solver': 'svd', '...
# 2  {'model__tol': 0.0001, 'model__solver': 'svd',...
# 3  {'model__tol': 0.001, 'model__solver': 'choles...
# 4  {'model__tol': 0.001, 'model__solver': 'svd', ...
# 5  {'model__tol': 0.0001, 'model__solver': 'saga'...
# 6  {'model__tol': 0.001, 'model__solver': 'sag', ...
# 7  {'model__tol': 0.001, 'model__solver': 'saga',...

# %%
cv_results_df_sorted['params']  if not_catboost and debug_mode else ''
# Out:
# ''

# %%
cv_results_df_sorted['params'][0] if not_catboost else ''
# Out:
# {'model__tol': 0.01,
#  'model__solver': 'svd',
#  'model__random_state': 101,
#  'model__positive': False,
#  'model__max_iter': 100000,
#  'model__fit_intercept': True,
#  'model__copy_X': True,
#  'model__alpha': 10}

# %%
best_models if not_catboost else ''
# Out:
# {0: {'alpha': 10,
#   'copy_X': True,
#   'fit_intercept': True,
#   'max_iter': 100000,
#   'normalize': 'deprecated',
#   'positive': False,
#   'random_state': 101,
#   'solver': 'svd',
#   'tol': 0.01},
#  2: {'alpha': 100,
#   'copy_X': True,
#   'fit_intercept': True,
#   'max_iter': 1000,
#   'normalize': 'deprecated',
#   'positive': False,
#   'random_state': 101,
#   'solver': 'svd',
#   'tol': 0.0001},
#  4: {'alpha': 0.0001,
#   'copy_X': False,
#   'fit_intercept': True,
#   'max_iter': 100000,
#   'normalize': 'deprecated',
#   'positive': False,
#   'random_state': 101,
#   'solver': 'svd',
#   'tol': 0.001},
#  6: {'alpha': 1,
#   'copy_X': False,
#   'fit_intercept': True,
#   'max_iter': 1000000,
#   'normalize': 'deprecated',
#   'positive': False,
#   'random_state': 101,
#   'solver': 'sag',
#   'tol': 0.001},
#  -1: {'alpha': 0.01,
#   'copy_X': False,
#   'fit_intercept': True,
#   'max_iter': 10000,
#   'normalize': 'deprecated',
#   'positive': False,
#   'random_state': 101,
#   'solver': 'saga',
#   'tol': 0.001}}

# %%
if not_catboost:
    for i in best_model_scores.keys():
        if i >= 0:
            plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
            plt.scatter(y_test, best_model_predictions[i])
            # plt.title(str(i) + " " + str(round(best_model_scores[i], 4)) + " for " + str(best_models[i]))
            if len(best_models[i].keys()) < 30:
                plt.title(str(i) + " " + str(round(best_model_scores[i], 4)) + " for " + str(best_models[i]))
            else:
                plt.title(str(i) + " " + str(round(best_model_scores[i], 4)) + " for entry " + str(i))
            plt.show()

    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
    plt.scatter(y_test, best_model_predictions[-1])
    # plt.title(str(i) + " " + str(round(best_model_scores[i], 4)) + " for " + str(best_models[i]))
    if len(best_models[i].keys()) < 30:
        plt.title(str(i) + " " + str(round(best_model_scores[-1], 4)) + " for " + str(best_models[-1]))
    else:
        plt.title(str(i) + " " + str(round(best_model_scores[-1], 4)) + " for (worst) entry " + str(i))

    plt.show()

# %%
if not_catboost:
    sns.set_theme(font_scale=2, rc=None)
    sns.set_theme(font_scale=1, rc=None)

    worst_and_best_model_fig, axes = plt.subplots(ncols=3, figsize=(15, 5))

    plt.subplots_adjust(hspace=0.2)
    plt.subplots_adjust(wspace=0.2)

    #.flatten()
    coordinates = axes[0]
    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[0], color='red')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[0].flatten(), ax=axes[0],
                    s=100).set(title=f'"BEST" model')

    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[1], color='red')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[-1].flatten(), ax=axes[1],
                    s=100).set(title=f'"WORST" model')

    sns.lineplot(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], ax=axes[2], color='red')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[-1].flatten(), ax=axes[2],
                    s=120, color='orange')
    sns.scatterplot(x=y_test.flatten(), y=best_model_predictions[0].flatten(), ax=axes[2],
                    s=30, alpha=0.6, color='black').set(
        title='best (black) vs worst (orange)')
    #title='best (orange) vs worst (black)')


    best_model_fig.tight_layout()
    plt.show()

# %%
if not_catboost:
    cv_best_model_fit_time = cv_results_df_sorted.iloc[0]["mean_fit_time"]
cv_best_model_fit_time if not_catboost else ''
# Out:
# 0.27384455998738605

# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage: Evaluate the model

# %%
# <catboost.core.CatBoostRegressor object at 0x7fb167387490>
# {'depth': 6}
# defaultdict(<class 'list'>, {'iterations': [0, 1, 2],
# 'test-RMSE-mean': [396884.9605444017, 359548.6632536235, 326027.84885587444],
# 'test-RMSE-std': [308.9495320039113, 260.0967808594464, 219.65856329246023],
# 'train-RMSE-mean': [396884.77936957515, 359542.3612912551, 326018.9404460669],
# 'train-RMSE-std': [91.44140078375503, 86.77961380623475, 69.4038638987425]})

cv_best_model_fit_time = cv_results_df_sorted.iloc[0]["mean_fit_time"] if not_catboost else 999

DD2 = "(" + ",".join(DATA_DETAIL) + ")" if len(DATA_DETAIL) >= 1 else ""

method =  f"{ALGORITHM_DETAIL}{DD2}"

new_results = {
    '_score': score,
    'R square Accuracy': R2,
    'Mean Absolute Error Accuracy': MAE,
    'Mean Squared Error Accuracy': MSE,
    'Root Mean Squared Error': RMSE,
    '_train time': cv_best_model_fit_time,
    'random_state': RANDOM_STATE,
    'date': str(datetime.now()),
    '_params': crossval_runner.best_params_ if not_catboost else cat_params,
    '_method':method,
    'run_env': run_env
}

if run_env not in ['colab']:
    old_results_json = get_results()
    try:
        old_best_score = old_results_json[key]['best score']
    except:
        print(f"haven't scored this model yet: {ALGORITHM}")
        old_best_score = -999
    this_model_is_best = update_results(old_results_json, new_results, key)

print(key)
new_results
# Out:
# linear regression (ridge) (v10)
# {'_score': 0.4707818387829007,
#  'R square Accuracy': 0.4707818387829007,
#  'Mean Absolute Error Accuracy': 62597.27585807666,
#  'Mean Squared Error Accuracy': 5978263015.241543,
#  'Root Mean Squared Error': 77319.22797882518,
#  '_train time': 0.27384455998738605,
#  'random_state': 101,
#  'date': '2022-12-02 18:25:23.343493',
#  '_params': {'model__tol': 0.01,
#   'model__solver': 'svd',
#   'model__random_state': 101,
#   'model__positive': False,
#   'model__max_iter': 100000,
#   'model__fit_intercept': True,
#   'model__copy_X': True,
#   'model__alpha': 10},
#  '_method': 'random search',
#  'run_env': 'local',
#  'first run': '2022-12-01 14:21:36.707990',
#  'best is shared': False,
#  'silver score': 0.4708062463391607,
#  'silver time': 0.08964244524637859,
#  'silver params': {'model__alpha': 0.0001,
#   'model__copy_X': False,
#   'model__fit_intercept': True,
#   'model__max_iter': 10000,
#   'model__positive': False,
#   'model__random_state': 101,
#   'model__solver': 'lsqr',
#   'model__tol': 0.001},
#  'silver method': 'random search',
#  'silver run date': '2022-12-01 15:02:10.080074',
#  'best score': 0.4708062463710102,
#  'best time': 0.23905722300211588,
#  'best params': {'model__alpha': 1e-05,
#   'model__copy_X': True,
#   'model__fit_intercept': True,
#   'model__max_iter': 10000,
#   'model__positive': False,
#   'model__random_state': 101,
#   'model__solver': 'lsqr',
#   'model__tol': 0.001},
#  'best method': 'random search',
#  'best run date': '2022-12-01 19:50:08.050622',
#  'suboptimal': 'suboptimal'}

# %%
crossval_runner.best_estimator_  if not_catboost else ''
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('model',
#                  Ridge(alpha=10, max_iter=100000, random_state=101,
#                        solver='svd', tol=0.01))])

# %%
if this_model_is_best:
    with open(f'../../../models/optimised_model_{ALGORITHM}_v{VERSION}{DD2}.pkl', 'wb') as f:
        if not_catboost:
            pickle.dump(crossval_runner.best_estimator_, f)
        else:
            pickle.dump(starter_model, f)
        print('pickled new version of model')
        print(f"{old_results_json[key]['_score']} is new best score (it's better than {old_best_score})")
        #print(results_json[key]['_score'], 'is an improvement on', results_json[key]['second best score'])
else:
    print("not updated saved model, the previous run was better")
    print(f"{old_results_json[key]['_score']} is worse than or equal to '{old_best_score}")
# Out:
# not updated saved model, the previous run was better
# 0.4707818387829007 is worse than or equal to '0.4708062463710102

# %%
from bs4 import BeautifulSoup


def include_in_html_report(type, text_list=None, fig=None, content=None):
    writePath_html = r'model_results/%s.html' % key
    writePath_md = r'model_results/%s.md' % key


    if type == 'header':
        with open(writePath_html, 'w') as f1:
            headers = f'<h1>Results from {ALGORITHM}</h1>'
            f1.write(headers)
        with open(writePath_md, 'w') as f2:
            headers = f'# Results from {ALGORITHM}\n'
            f2.write(headers)
    else:
        with open(writePath_html, 'a') as f1:
            f1.write(f'<h3>{text_list}</h3>')
        with open(writePath_md, 'a') as f2:
            f2.write(f'### {text_list}\n')

        if type=='dataframe':
            with open(writePath_html, 'a') as f1:
                dfAsString = content.to_html()
                f1.write(dfAsString)
            with open(writePath_md, 'a') as f2:
                dfAsString = content.to_markdown()
                f2.write(dfAsString + '\n')
        elif type=='graph':
            filename = key + "_" + content
            fig.savefig(f'model_results/artifacts/{filename.replace(" ","_")}')

            with open(writePath_html, 'a') as f1:
                dfAsString = f'<img src="artifacts/{filename.replace(" ","_")}"/>'
                f1.write(dfAsString)

            with open(writePath_md, 'a') as f2:
                #dfAsString = f'(./model_results/artifacts/{filename}) \n'
                dfAsString = f'![detail](./artifacts/{filename.replace(" ","_")})'
                f2.write(dfAsString)
                f2.write('\n')
        elif type=='json':

            # html_content_parsed = [[cell.text for cell in row("td")]
            #              for row in BeautifulSoup(content,features="html.parser")("tr")]
            #
            # html_content_dictionary = {element[0]:element[1:] for element in html_content_parsed}

            #xxxprint(json.dumps(html_content_dictionary, indent=4))



            with open(writePath_html, 'a') as f1:
                #f.write(json.dumps(html_content_dictionary, indent=4))
                soup = BeautifulSoup(content, "html.parser")
                f1.write(str(soup.prettify()))

        elif type=='text':
            with open(writePath_html, 'a') as f1:
                f1.write(content)
            with open(writePath_md, 'a') as f2:
                f2.write(content + '\n')

        with open(writePath_html, 'a') as f1:
            f1.write('<hr>')


include_in_html_report("header")

include_in_html_report(type="text",text_list="Summary", content=f"{old_results_json[key]['_score']} is new best score (it's better than {old_best_score})")
include_in_html_report(type="text",text_list="Summary", content="not updated saved model, the previous run was better")
include_in_html_report(type="text",text_list=None, content=f"{old_results_json[key]['_score']} is worse than or equal to '{old_best_score}")

#include_in_html_report(type="dataframe",text_list="Tuned Models ranked by performance", content=cv_results_df_sorted)

include_in_html_report(type='dataframe',text_list='Tuned Models ranked by performance, with parameter details',content=cv_results_df_summary)

include_in_html_report(type='graph', text_list='Best and worst models obtained by tuning', fig=worst_and_best_model_fig, content="best_and_worst.png")

include_in_html_report(type='graph', text_list='Comparing model predictions to actual property values', fig=best_model_fig, content='best_model_correlation.png')

#include_in_html_report(type="dataframe",text_list="Summary", content=pd.DataFrame(data=new_results))


def print_and_report(text_list, title):
    include_in_html_report("text",content=title)
    for each in text_list:
        print(each)
        include_in_html_report("text",text_list="",content=each)

# if not_catboost:
#     print_and_report([
#         'Best Index:' + str(crossval_runner.best_index_) + '<br>',
#         'Best Score:' + str(crossval_runner.best_score_) + '<br>',
#         'Best Params: ' + str(crossval_runner.best_params_) + '<br>'
#     ], "Best Model Details")

# %% [markdown]
# <code style="background:blue;color:blue">**********************************************************************************************************</code>
#
# ## Stage: Investigate the feature importances (if applicable)

# %%
if 'tree' in ALGORITHM.lower() or 'forest' in ALGORITHM.lower() or 'boost' in ALGORITHM.lower():
    feature_importances = crossval_runner.best_estimator_[-1].feature_importances_ if not_catboost else starter_model.get_feature_importance()
    #std = np.std([tree.feature_importances_ for tree in model.estimators_], axis = 0)

    indices = np.argsort(feature_importances)[::-1]

    print('Feature Ranking:')

    for f in range(X_train.shape[1]):
        print('%d. features %d (%f)' % (f + 1, indices[f], feature_importances[indices[f]]),
              df_features.columns[indices[f] + 1])
else:
    print(f'{ALGORITHM} does not have feature_importances, skipping')
# Out:
# Linear Regression (Ridge) does not have feature_importances, skipping

# %%
if 'tree' in ALGORITHM.lower() or 'forest' in ALGORITHM.lower() or 'boost' in ALGORITHM.lower():
    indices = np.argsort(feature_importances)

    best_model_fig, best_model_ax = plt.subplots(figsize=(20, 20))
    best_model_ax.barh(range(len(feature_importances)), feature_importances[indices])
    best_model_ax.set_yticks(range(len(feature_importances)))
    _ = best_model_ax.set_yticklabels(df_features.columns[[c + 1 for c in indices]])
else:
    print(f'{ALGORITHM} does not have feature_importances, skipping')
# Out:
# Linear Regression (Ridge) does not have feature_importances, skipping

# %%
# import html2text as ht
# import os
# import sys
#
# from pathlib import Path
#
# text_maker = ht.HTML2Text()
#
# with open(f'model_results/{key}.html','r',encoding='UTF-8') as f:
#     htmlpage = f.read()
#
# text = text_maker.handle(htmlpage)
#
# with open(f'model_results/{key} [conversion].md','w') as f:
#     f.write(text)
